# %%
from statsmodels.tsa.stattools import grangercausalitytests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Sub0-RAW.csv')

# %%
df.head()
# Out:
#        Dates  Year  Month  Day    Hours  Precipitation  Temperature  Outflow
# 0  10/1/1980  1980     10    1  0:00:00            0.0      102.992      5.0
# 1  10/1/1980  1980     10    1  1:00:00            0.0       97.790      5.0
# 2  10/1/1980  1980     10    1  2:00:00            0.0       92.588      5.0
# 3  10/1/1980  1980     10    1  3:00:00            0.0       87.404      5.0
# 4  10/1/1980  1980     10    1  4:00:00            0.0       85.172      5.0

# %%
df_with_temp = df.filter(['Outflow','Temperature'], axis=1)
df_with_temp
# Out:
#         Outflow  Temperature
# 0           5.0      102.992
# 1           5.0       97.790
# 2           5.0       92.588
# 3           5.0       87.404
# 4           5.0       85.172
# ...         ...          ...
# 185539     30.0       54.284
# 185540     29.0       55.670
# 185541     29.0       57.074
# 185542     31.0       57.056
# 185543     38.0       57.020
#
# [185544 rows x 2 columns]

# %%
timesteps = 18

# %%
gc_flow_temp = grangercausalitytests(df_with_temp, timesteps)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.2757  , p=0.1314  , df_denom=185540, df_num=1
# ssr based chi2 test:   chi2=2.2758  , p=0.1314  , df=1
# likelihood ratio test: chi2=2.2758  , p=0.1314  , df=1
# parameter F test:         F=2.2757  , p=0.1314  , df_denom=185540, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=197.7809, p=0.0000  , df_denom=185537, df_num=2
# ssr based chi2 test:   chi2=395.5725, p=0.0000  , df=2
# likelihood ratio test: chi2=395.1514, p=0.0000  , df=2
# parameter F test:         F=197.7809, p=0.0000  , df_denom=185537, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=11.1770 , p=0.0000  , df_denom=185534, df_num=3
# ssr based chi2 test:   chi2=33.5322 , p=0.0000  , df=3
# likelihood ratio test: chi2=33.5292 , p=0.0000  , df=3
# parameter F test:         F=11.1770 , p=0.0000  , df_denom=185534, df_num=3
#
# Granger Causality
# ...

# %%
df_with_pre = df.filter(['Outflow','Precipitation'], axis=1)
df_with_pre
# Out:
#         Outflow  Precipitation
# 0           5.0            0.0
# 1           5.0            0.0
# 2           5.0            0.0
# 3           5.0            0.0
# 4           5.0            0.0
# ...         ...            ...
# 185539     30.0            0.0
# 185540     29.0            0.0
# 185541     29.0            0.0
# 185542     31.0            0.0
# 185543     38.0            0.0
#
# [185544 rows x 2 columns]

# %%
gc_flow_temp = grangercausalitytests(df_with_pre, timesteps)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=58.5275 , p=0.0000  , df_denom=185540, df_num=1
# ssr based chi2 test:   chi2=58.5284 , p=0.0000  , df=1
# likelihood ratio test: chi2=58.5192 , p=0.0000  , df=1
# parameter F test:         F=58.5275 , p=0.0000  , df_denom=185540, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=99.1619 , p=0.0000  , df_denom=185537, df_num=2
# ssr based chi2 test:   chi2=198.3292, p=0.0000  , df=2
# likelihood ratio test: chi2=198.2233, p=0.0000  , df=2
# parameter F test:         F=99.1619 , p=0.0000  , df_denom=185537, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=55.7779 , p=0.0000  , df_denom=185534, df_num=3
# ssr based chi2 test:   chi2=167.3401, p=0.0000  , df=3
# likelihood ratio test: chi2=167.2647, p=0.0000  , df=3
# parameter F test:         F=55.7779 , p=0.0000  , df_denom=185534, df_num=3
#
# Granger Causality
# ...

# %%
#import modules
import numpy as np
import pandas as pd
import time
from keras import backend as K 
from keras.engine.training import Model
from keras.utils import to_categorical, plot_model
from keras.models import Sequential, load_model
from sklearn.preprocessing import MinMaxScaler
from keras.layers.convolutional import Conv1D, Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers import Dropout, Activation, Flatten
from keras.layers import LSTM, Dense, Input
from keras.optimizers import SGD
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tqdm import tqdm_notebook
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('./Sub0-RAW.csv')
df.head()
# Out:
#        Dates  Year  Month  Day    Hours  Precipitation  Temperature  Outflow
# 0  10/1/1980  1980     10    1  0:00:00            0.0      102.992      5.0
# 1  10/1/1980  1980     10    1  1:00:00            0.0       97.790      5.0
# 2  10/1/1980  1980     10    1  2:00:00            0.0       92.588      5.0
# 3  10/1/1980  1980     10    1  3:00:00            0.0       87.404      5.0
# 4  10/1/1980  1980     10    1  4:00:00            0.0       85.172      5.0

# %%
train_cols = ["Precipitation","Temperature","Outflow"]
label_cols = ["Outflow(t+1)"]

# %%
new_df = df.filter(train_cols, axis=1)

# %%
#Min Max scalr normalizing
xtrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
xtest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))

# %%
#function to shift the time_series data for getting labels
def lag_seq(df, n_seq):
    for i in range(n_seq):
        df['Outflow(t+%d)' %(i+1)] = new_df['Outflow'].shift(-(i+1))
    return df

#calling function to create lag dataframe
lag_df = lag_seq(new_df, 1)
lag_df.dropna(inplace=True)

#Splitting training and test data
df_train, df_test = train_test_split(lag_df, train_size=0.8, test_size=0.2, shuffle=False)
x_train = df_train.loc[:,train_cols].values
y_train = df_train.loc[:,label_cols].values
x_test = df_test.loc[:,train_cols].values
y_test = df_test.loc[:,label_cols].values

# %%
# checking mse for train set that are greater than threshold
threshold = 250
timesteps = 18
train_values_above_thres = []
train_labels_above_theres = []

for i in range(timesteps, x_train.shape[0]):
    if (y_train[i] > threshold):
        train_values_above_thres.append(x_train[i-timesteps:i])
        train_labels_above_theres.append(y_train[i]) 
        
X_train_abv_thres = np.array(train_values_above_thres)
Y_train_abv_thres = np.array(train_labels_above_theres)

tsamples, ta, tb = X_train_abv_thres.shape
x_train_for_normalization = X_train_abv_thres.reshape((tsamples,ta*tb)) # since normalization requires 2d array
x_train_for_normalization.shape

X_Train_abv_thres = xtrain_min_max_scaler.fit_transform(x_train_for_normalization)
Y_Train_abv_thres = ytrain_min_max_scaler.fit_transform(Y_train_abv_thres)

X_Train_abv_thres = X_Train_abv_thres.reshape((tsamples, ta, tb))

# %%
# checking mse for test set that are greater than threshold
threshold = 250
timesteps = 18
test_values_above_thres = []
test_labels_above_theres = []

for i in range(timesteps, x_test.shape[0]):
    if (y_test[i] > threshold):
        test_values_above_thres.append(x_test[i-timesteps:i])
        test_labels_above_theres.append(y_test[i]) 
        
X_test_abv_thres = np.array(test_values_above_thres)
Y_test_abv_thres = np.array(test_labels_above_theres)

tsamples, ta, tb = X_test_abv_thres.shape
x_test_for_normalization = X_test_abv_thres.reshape((tsamples,ta*tb)) # since normalization requires 2d array
x_test_for_normalization.shape

X_Test_abv_thres = xtest_min_max_scaler.fit_transform(x_test_for_normalization)
Y_Test_abv_thres = ytest_min_max_scaler.fit_transform(Y_test_abv_thres)

X_Test_abv_thres = X_Test_abv_thres.reshape((tsamples, ta, tb))

# %%
X_Train_abv_thres.shape, X_Test_abv_thres.shape
# Out:
# ((1678, 18, 3), (553, 18, 3))

# %%
Y_Train_abv_thres.shape, Y_Test_abv_thres.shape
# Out:
# ((1678, 1), (553, 1))

# %%
Y_Test_abv_thres
# Out:
# array([[5.21270222e-02],
#        [1.53385261e-01],
#        [2.31875374e-01],
#        [2.69622528e-01],
#        [2.60635111e-01],
#        [2.28879569e-01],
#        [2.00119832e-01],
#        [1.73157579e-01],
#        [1.48591971e-01],
#        [1.25823847e-01],
#        [1.05452367e-01],
#        [8.62792091e-02],
#        [7.30976633e-02],
#        [6.65068904e-02],
#        [6.53085680e-02],
#        [6.53085680e-02],
#        [6.35110845e-02],
#        [5.69203116e-02],
#        [4.49370881e-02],
#        [3.05572199e-02],
#        [1.67765129e-02],
#        [4.19412822e-03],
#        [1.19832235e-02],
#        [1.61773517e-02],
#        [1.01857400e-02],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [2.99580587e-03],
#        [2.75614140e-02],
#        [9.76632714e-02],
#        [1.46794488e-01],
#        [1.62372678e-01],
#        [1.50988616e-01],
#        [1.29418814e-01],
#        [1.07849011e-01],
#        [8.80766926e-02],
#        [6.95026962e-02],
#        [5.27261833e-02],
#        [3.71479928e-02],
#        [2.33672858e-02],
#        [1.07849011e-02],
#        [2.03714799e-02],
#        [7.07010186e-02],
#        [1.47393649e-01],
#        [2.42660276e-01],
#        [3.48112642e-01],
#        [4.46974236e-01],
#        [5.12881965e-01],
#        [5.29658478e-01],
#        [5.09886159e-01],
#        [4.76333134e-01],
#        [4.34991013e-01],
#        [3.91252247e-01],
#        [3.49910126e-01],
#        [3.11563811e-01],
#        [2.77411624e-01],
#        [2.53445177e-01],
#        [2.70221690e-01],
#        [3.55901738e-01],
#        [5.03295386e-01],
#        [6.80047933e-01],
#        [8.45416417e-01],
#        [9.58657879e-01],
#        [1.00000000e+00],
#        [9.85020971e-01],
#        [9.43079688e-01],
#        [8.95745956e-01],
#        [8.53804673e-01],
#        [8.17855003e-01],
#        [7.84901138e-01],
#        [7.48951468e-01],
#        [7.03415219e-01],
#        [6.45895746e-01],
#        [5.84182145e-01],
#        [5.27860995e-01],
#        [4.75733972e-01],
#        [4.27801078e-01],
#        [3.83463152e-01],
#        [3.43319353e-01],
#        [3.05572199e-01],
#        [2.71420012e-01],
#        [2.39664470e-01],
#        [2.10305572e-01],
#        [1.88735770e-01],
#        [1.77351708e-01],
#        [1.73756741e-01],
#        [1.72558418e-01],
#        [1.68963451e-01],
#        [1.58777711e-01],
#        [1.41402037e-01],
#        [1.19832235e-01],
#        [1.00059916e-01],
#        [8.20850809e-02],
#        [6.59077292e-02],
#        [5.03295386e-02],
#        [3.65488316e-02],
#        [2.33672858e-02],
#        [1.13840623e-02],
#        [5.99161174e-04],
#        [1.61773517e-02],
#        [7.84901138e-02],
#        [1.35410425e-01],
#        [1.74955063e-01],
#        [1.99520671e-01],
#        [2.34272019e-01],
#        [2.99580587e-01],
#        [3.90053925e-01],
#        [4.85320551e-01],
#        [5.66207310e-01],
#        [6.11144398e-01],
#        [6.16536848e-01],
#        [5.96165368e-01],
#        [5.62612343e-01],
#        [5.20071899e-01],
#        [4.71539844e-01],
#        [4.24206111e-01],
#        [3.80467346e-01],
#        [3.40323547e-01],
#        [3.03175554e-01],
#        [2.69023367e-01],
#        [2.37866986e-01],
#        [2.09107250e-01],
#        [1.82744158e-01],
#        [1.62971839e-01],
#        [1.54583583e-01],
#        [1.70760935e-01],
#        [2.21090473e-01],
#        [2.92989814e-01],
#        [3.66087478e-01],
#        [4.20011983e-01],
#        [4.42780108e-01],
#        [4.31396046e-01],
#        [3.99640503e-01],
#        [3.64889155e-01],
#        [3.30137807e-01],
#        [2.95985620e-01],
#        [2.65428400e-01],
#        [2.37866986e-01],
#        [2.12103056e-01],
#        [1.88735770e-01],
#        [1.65967645e-01],
#        [1.43798682e-01],
#        [1.23427202e-01],
#        [1.03654883e-01],
#        [8.56800479e-02],
#        [6.95026962e-02],
#        [5.45236669e-02],
#        [4.13421210e-02],
#        [3.35530258e-02],
#        [3.17555422e-02],
#        [3.77471540e-02],
#        [4.67345716e-02],
#        [5.45236669e-02],
#        [5.69203116e-02],
#        [5.21270222e-02],
#        [4.19412822e-02],
#        [2.87597364e-02],
#        [1.73756741e-02],
#        [5.99161174e-03],
#        [5.63211504e-02],
#        [1.06650689e-01],
#        [1.31216297e-01],
#        [1.25823847e-01],
#        [1.06051528e-01],
#        [9.04733373e-02],
#        [7.84901138e-02],
#        [7.07010186e-02],
#        [6.41102457e-02],
#        [5.69203116e-02],
#        [4.73337328e-02],
#        [3.59496705e-02],
#        [2.33672858e-02],
#        [1.19832235e-02],
#        [5.99161174e-04],
#        [2.69622528e-02],
#        [6.89035351e-02],
#        [9.10724985e-02],
#        [9.22708209e-02],
#        [8.08867585e-02],
#        [6.65068904e-02],
#        [5.21270222e-02],
#        [3.71479928e-02],
#        [2.39664470e-02],
#        [1.25823847e-02],
#        [1.79748352e-03],
#        [6.65068904e-02],
#        [1.46794488e-01],
#        [2.00718993e-01],
#        [2.16297184e-01],
#        [1.98921510e-01],
#        [1.71959257e-01],
#        [1.47992810e-01],
#        [1.27621330e-01],
#        [1.12642301e-01],
#        [1.06051528e-01],
#        [1.06051528e-01],
#        [1.08448173e-01],
#        [1.07249850e-01],
#        [1.01258238e-01],
#        [8.74775315e-02],
#        [7.01018574e-02],
#        [5.33253445e-02],
#        [3.77471540e-02],
#        [2.39664470e-02],
#        [1.07849011e-02],
#        [3.11563811e-02],
#        [1.04254044e-01],
#        [1.69562612e-01],
#        [2.13900539e-01],
#        [2.31875374e-01],
#        [2.22887957e-01],
#        [1.97723188e-01],
#        [1.70161774e-01],
#        [1.44397843e-01],
#        [1.22228880e-01],
#        [1.01258238e-01],
#        [8.20850809e-02],
#        [6.47094068e-02],
#        [4.85320551e-02],
#        [3.41521869e-02],
#        [2.03714799e-02],
#        [7.78909527e-03],
#        [1.19832235e-03],
#        [1.19832235e-02],
#        [1.61773517e-02],
#        [1.19832235e-02],
#        [1.79748352e-03],
#        [1.25823847e-02],
#        [5.75194727e-02],
#        [8.92750150e-02],
#        [9.88615938e-02],
#        [8.98741762e-02],
#        [7.18993409e-02],
#        [5.63211504e-02],
#        [4.37387657e-02],
#        [3.53505093e-02],
#        [3.23547034e-02],
#        [3.23547034e-02],
#        [3.23547034e-02],
#        [2.99580587e-02],
#        [2.39664470e-02],
#        [1.43798682e-02],
#        [3.59496705e-03],
#        [1.97723188e-02],
#        [6.71060515e-02],
#        [9.04733373e-02],
#        [8.56800479e-02],
#        [6.65068904e-02],
#        [5.03295386e-02],
#        [3.83463152e-02],
#        [2.93588975e-02],
#        [2.39664470e-02],
#        [1.91731576e-02],
#        [1.37807070e-02],
#        [6.59077292e-03],
#        [2.39664470e-03],
#        [1.25823847e-02],
#        [1.79748352e-02],
#        [1.79748352e-02],
#        [1.43798682e-02],
#        [9.58657879e-03],
#        [4.19412822e-03],
#        [5.99161174e-04],
#        [8.38825644e-03],
#        [1.97723188e-02],
#        [3.29538646e-02],
#        [4.73337328e-02],
#        [5.81186339e-02],
#        [6.29119233e-02],
#        [5.99161174e-02],
#        [4.97303775e-02],
#        [3.59496705e-02],
#        [2.15698023e-02],
#        [8.38825644e-03],
#        [1.73756741e-02],
#        [4.43379269e-02],
#        [5.39245057e-02],
#        [4.73337328e-02],
#        [3.41521869e-02],
#        [2.03714799e-02],
#        [7.78909527e-03],
#        [7.78909527e-03],
#        [3.17555422e-02],
#        [4.97303775e-02],
#        [5.81186339e-02],
#        [5.51228280e-02],
#        [4.25404434e-02],
#        [2.81605752e-02],
#        [1.49790294e-02],
#        [2.39664470e-03],
#        [6.59077292e-03],
#        [1.55781905e-02],
#        [2.03714799e-02],
#        [2.33672858e-02],
#        [2.75614140e-02],
#        [3.35530258e-02],
#        [3.71479928e-02],
#        [3.47513481e-02],
#        [2.57639305e-02],
#        [1.31815458e-02],
#        [1.19832235e-03],
#        [2.21689635e-02],
#        [6.77052127e-02],
#        [1.10245656e-01],
#        [1.38406231e-01],
#        [1.45596165e-01],
#        [1.34212103e-01],
#        [1.15638107e-01],
#        [9.58657879e-02],
#        [7.78909527e-02],
#        [6.11144398e-02],
#        [4.55362493e-02],
#        [3.11563811e-02],
#        [1.79748352e-02],
#        [5.99161174e-03],
#        [6.17136010e-02],
#        [1.23427202e-01],
#        [1.57579389e-01],
#        [1.57579389e-01],
#        [1.37807070e-01],
#        [1.16836429e-01],
#        [9.88615938e-02],
#        [8.32834032e-02],
#        [6.89035351e-02],
#        [5.57219892e-02],
#        [4.25404434e-02],
#        [2.93588975e-02],
#        [1.61773517e-02],
#        [4.19412822e-03],
#        [1.91731576e-02],
#        [3.89454763e-02],
#        [5.21270222e-02],
#        [5.99161174e-02],
#        [6.47094068e-02],
#        [7.24985021e-02],
#        [8.32834032e-02],
#        [9.52666267e-02],
#        [1.03654883e-01],
#        [1.06051528e-01],
#        [1.00659077e-01],
#        [8.92750150e-02],
#        [7.72917915e-02],
#        [6.77052127e-02],
#        [6.05152786e-02],
#        [5.45236669e-02],
#        [4.79328939e-02],
#        [4.07429599e-02],
#        [3.11563811e-02],
#        [2.09706411e-02],
#        [9.58657879e-03],
#        [4.97303775e-02],
#        [1.07249850e-01],
#        [1.65967645e-01],
#        [2.17495506e-01],
#        [2.52246854e-01],
#        [2.63630917e-01],
#        [2.52246854e-01],
#        [2.28280407e-01],
#        [2.06111444e-01],
#        [1.90533253e-01],
#        [1.79748352e-01],
#        [1.68963451e-01],
#        [1.56381067e-01],
#        [1.40203715e-01],
#        [1.21030557e-01],
#        [1.01857400e-01],
#        [8.50808868e-02],
#        [6.95026962e-02],
#        [5.45236669e-02],
#        [4.01437987e-02],
#        [2.63630917e-02],
#        [1.37807070e-02],
#        [2.39664470e-03],
#        [1.91731576e-02],
#        [8.02875974e-02],
#        [1.62971839e-01],
#        [2.49251049e-01],
#        [3.16956261e-01],
#        [3.50509287e-01],
#        [3.46315159e-01],
#        [3.16357100e-01],
#        [2.80407430e-01],
#        [2.47453565e-01],
#        [2.17495506e-01],
#        [1.89334931e-01],
#        [1.63571001e-01],
#        [1.39604554e-01],
#        [1.18034751e-01],
#        [9.76632714e-02],
#        [7.90892750e-02],
#        [6.17136010e-02],
#        [4.61354104e-02],
#        [3.17555422e-02],
#        [1.85739964e-02],
#        [5.99161174e-03],
#        [1.43798682e-02],
#        [5.75194727e-02],
#        [7.90892750e-02],
#        [7.42959856e-02],
#        [5.69203116e-02],
#        [4.13421210e-02],
#        [2.63630917e-02],
#        [1.25823847e-02],
#        [0.00000000e+00],
#        [8.74775315e-02],
#        [1.92929898e-01],
#        [2.73816657e-01],
#        [3.11563811e-01],
#        [3.05572199e-01],
#        [2.78609946e-01],
#        [2.49850210e-01],
#        [2.20491312e-01],
#        [1.96524865e-01],
#        [1.85140803e-01],
#        [1.91731576e-01],
#        [2.10904733e-01],
#        [2.33672858e-01],
#        [2.49251049e-01],
#        [2.50449371e-01],
#        [2.35470342e-01],
#        [2.10904733e-01],
#        [1.85739964e-01],
#        [1.60575195e-01],
#        [1.37207909e-01],
#        [1.15038945e-01],
#        [9.52666267e-02],
#        [7.72917915e-02],
#        [6.11144398e-02],
#        [4.61354104e-02],
#        [3.23547034e-02],
#        [1.97723188e-02],
#        [7.18993409e-03],
#        [3.89454763e-02],
#        [6.95026962e-02],
#        [8.62792091e-02],
#        [8.62792091e-02],
#        [7.42959856e-02],
#        [5.99161174e-02],
#        [4.61354104e-02],
#        [3.35530258e-02],
#        [2.09706411e-02],
#        [8.98741762e-03],
#        [1.37807070e-02],
#        [1.97723188e-02],
#        [1.49790294e-02],
#        [5.39245057e-03],
#        [7.18993409e-03],
#        [2.09706411e-02],
#        [4.07429599e-02],
#        [6.29119233e-02],
#        [8.44817256e-02],
#        [9.88615938e-02],
#        [1.03654883e-01],
#        [9.88615938e-02],
#        [8.68783703e-02],
#        [7.18993409e-02],
#        [5.51228280e-02],
#        [3.95446375e-02],
#        [2.45656081e-02],
#        [1.07849011e-02],
#        [1.73756741e-02],
#        [3.77471540e-02],
#        [4.49370881e-02],
#        [4.19412822e-02],
#        [3.41521869e-02],
#        [2.15698023e-02],
#        [8.38825644e-03],
#        [5.99161174e-03],
#        [1.13840623e-02],
#        [1.55781905e-02],
#        [1.97723188e-02],
#        [2.15698023e-02],
#        [1.79748352e-02],
#        [8.38825644e-03],
#        [1.67765129e-02],
#        [4.67345716e-02],
#        [6.35110845e-02],
#        [7.13001797e-02],
#        [7.60934691e-02],
#        [7.66926303e-02],
#        [7.13001797e-02],
#        [5.99161174e-02],
#        [4.49370881e-02],
#        [2.99580587e-02],
#        [1.61773517e-02],
#        [2.99580587e-03],
#        [2.69622528e-02],
#        [6.71060515e-02],
#        [9.16716597e-02],
#        [9.88615938e-02],
#        [9.46674655e-02],
#        [8.32834032e-02],
#        [6.89035351e-02],
#        [5.39245057e-02],
#        [3.89454763e-02],
#        [2.45656081e-02],
#        [1.13840623e-02],
#        [3.83463152e-02],
#        [7.66926303e-02],
#        [9.64649491e-02],
#        [9.70641102e-02],
#        [8.80766926e-02],
#        [8.02875974e-02],
#        [7.78909527e-02],
#        [7.72917915e-02],
#        [7.48951468e-02],
#        [6.71060515e-02],
#        [5.39245057e-02],
#        [3.83463152e-02],
#        [2.33672858e-02],
#        [1.01857400e-02],
#        [9.58657879e-03],
#        [6.53085680e-02],
#        [1.09047334e-01],
#        [1.36608748e-01],
#        [1.49790294e-01],
#        [1.52786099e-01],
#        [1.53984422e-01],
#        [1.51587777e-01],
#        [1.42600359e-01],
#        [1.27621330e-01],
#        [1.08448173e-01],
#        [9.28699820e-02],
#        [9.28699820e-02],
#        [1.13840623e-01],
#        [1.51587777e-01],
#        [1.97124026e-01],
#        [2.35470342e-01],
#        [2.55242660e-01],
#        [2.52246854e-01],
#        [2.34272019e-01],
#        [2.11503895e-01],
#        [1.90533253e-01],
#        [1.82144997e-01],
#        [1.88735770e-01],
#        [2.07908928e-01],
#        [2.32474536e-01],
#        [2.51647693e-01],
#        [2.57040144e-01],
#        [2.46854404e-01],
#        [2.25883763e-01],
#        [2.00718993e-01],
#        [1.74955063e-01],
#        [1.50988616e-01],
#        [1.29418814e-01],
#        [1.09047334e-01],
#        [9.04733373e-02],
#        [7.30976633e-02],
#        [5.69203116e-02],
#        [4.19412822e-02],
#        [2.81605752e-02],
#        [1.55781905e-02],
#        [3.59496705e-03]])

# %%
#Build Model
def make_model(X_Train):
    input_layer = Input(shape=(X_Train_abv_thres.shape[1], X_Train_abv_thres.shape[2]))

    conv1 = Conv1D(filters=16, kernel_size=3, strides=1,
                    padding='same',activation='relu')(input_layer)
    conv2 = Conv1D(filters=32, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv1)
    conv3 = Conv1D(filters=64, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv2)

    flatten = Flatten()(conv3)

    dense1 = Dense(1152, activation='relu')(flatten)
    dense2 = Dense(576, activation='relu')(dense1)
    output_layer = Dense(1, activation='linear')(dense2)
    
    return Model(inputs=input_layer, outputs=output_layer)

# %%
mse_for_iter = []
train_loss_over_epoch = []
val_loss_over_epoch = []
predicted_y_values_unnors = []
models = []
def run_iteration(no_iter=20, epochs = 10):
    start_time = time.time()
    for iteration in range(no_iter):
        print(f'Iteration: {iteration + 1}')
        K.clear_session()
        model = make_model(X_Train_abv_thres)
        #plot_model(model, show_shapes=True)
        model.compile(optimizer = 'adam', loss = 'mean_squared_error')
        history = model.fit(X_Train_abv_thres, Y_Train_abv_thres, epochs=epochs,
                       validation_data=(X_Test_abv_thres, Y_Test_abv_thres))
        train_loss_over_epoch.append(history.history['loss'])
        val_loss_over_epoch.append(history.history['val_loss'])
        predicted_y_values = model.predict(X_Test_abv_thres)
        predicted_y_values_unnor = ytrain_min_max_scaler.inverse_transform(predicted_y_values)
        mse_for_iter.append(mean_squared_error(predicted_y_values_unnor, Y_Test_abv_thres))
        predicted_y_values_unnors.append(predicted_y_values_unnor)
        models.append(model)
        
    end_time = time.time()
    print('--------------------------\n')
    print(f'Starting time: {start_time}')
    print(f'Completing time: {end_time}')
    print(f'It took {(start_time - end_time)/60} minutes to train the model for {no_iter} iterations')
    #return predicted unnormalized values for test set from last iteration 
    return predicted_y_values_unnor, model

predicted_y_values_unnor, model = run_iteration(20,10)
# Out:
# Iteration: 1
# Epoch 1/10
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0243 - val_loss: 0.0102
# Epoch 2/10
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0036 - val_loss: 0.0078
# Epoch 3/10
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0021 - val_loss: 0.0047
# Epoch 4/10
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0014 - val_loss: 0.0051
# Epoch 5/10
# 53/53 [==============================] - 1s 26ms/step - loss: 9.3422e-04 - val_loss: 0.0045
# Epoch 6/10
# 53/53 [==============================] - 2s 29ms/step - loss: 7.8008e-04 - val_loss: 0.0042
# Epoch 7/10
# 53/53 [==============================] - 1s 25ms/step - loss: 7.0200e-04 - val_loss: 0.0037
# Epoch 8/10
# 53/53 [==============================] - 1s 24ms/step - loss: 4.5220e-04 - val_loss: 0.0038
# Epoch 9/10
# 53/53 [==============================] - 1s 18ms/step - loss: 5.7333e-04 - val_loss: 0.0031
# Epoch 10/10
# 53/53 [==============================] - 1s 18ms/step - loss: 5.3212e-04 - val_loss: 0.0046
# Iteration: 2
# Epoch 1/10
# 53/53 [==============================] - 2s 22ms/step - loss: 0.0835 - val_loss: 0.0178
# Epoch 2/10
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0082 - val_loss: 0.0083
# Epoch 3/10
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0036 - val_loss: 0.0059
# Epoch 4/10
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0022 - val_loss: 0.0048
# Epoch 5/10
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 0.0041
# Epoch 6/10
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0012 - val_loss: 0.0038
# Epoch 7/10
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0011 - val_loss: 0.0033
# Epoch 8/10
# 53/53 [==============================] - 1s 23ms/step - loss: 8.0809e-04 - val_loss: 0.0031
# Epoch 9/10
# 53/53 [==============================] - 1s 22ms/step - loss: 7.6714e-04 - val_loss: 0.0030
# Epoch 10/10
# 53/53 [==============================] - 1s 24ms/step - loss: 5.5598e-04 - val_loss: 0.0030
# Iteration: 3
# Epoch 1/10
# 53/53 [==============================] - 2s 28ms/step - loss: 0.0318 - val_loss: 0.0083
# Epoch 2/10
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0045 - val_loss: 0.0062
# Epoch 3/10
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0018 - val_loss: 0.0044
# Epoch 4/10
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0012 - val_loss: 0.0048
# Epoch 5/10
# 53/53 [==============================] - 1s 22ms/step - loss: 7.7268e-04 - val_loss: 0.0040
# Epoch 6/10
# 53/53 [==============================] - 1s 22ms/step - loss: 8.0857e-04 - val_loss: 0.0032
# Epoch 7/10
# 53/53 [==============================] - 1s 22ms/step - loss: 7.9984e-04 - val_loss: 0.0042
# Epoch 8/10
# 53/53 [==============================] - 1s 22ms/step - loss: 5.5814e-04 - val_loss: 0.0028
# Epoch 9/10
# 53/53 [==============================] - 1s 23ms/step - loss: 4.4064e-04 - val_loss: 0.0028
# Epoch 10/10
# 53/53 [==============================] - 1s 27ms/step - loss: 4.1855e-04 - val_loss: 0.0029
# Iteration: 4
# Epoch 1/10
# 53/53 [==============================] - 2s 28ms/step - loss: 0.0213 - val_loss: 0.0066
# Epoch 2/10
# 53/53 [==============================] - 1s 27ms/step - loss: 0.0027 - val_loss: 0.0057
# Epoch 3/10
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0013 - val_loss: 0.0049
# Epoch 4/10
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0011 - val_loss: 0.0091
# Epoch 5/10
# 53/53 [==============================] - 2s 28ms/step - loss: 0.0018 - val_loss: 0.0051
# Epoch 6/10
# 53/53 [==============================] - 2s 37ms/step - loss: 8.8685e-04 - val_loss: 0.0041
# Epoch 7/10
# 53/53 [==============================] - 1s 22ms/step - loss: 6.4693e-04 - val_loss: 0.0032
# Epoch 8/10
# 53/53 [==============================] - 2s 32ms/step - loss: 5.4008e-04 - val_loss: 0.0027
# Epoch 9/10
# 53/53 [==============================] - 2s 36ms/step - loss: 5.2706e-04 - val_loss: 0.0034
# Epoch 10/10
# 53/53 [==============================] - 2s 35ms/step - loss: 3.5044e-04 - val_loss: 0.0030
# Iteration: 5
# Epoch 1/10
# 53/53 [==============================] - 4s 46ms/step - loss: 0.0360 - val_loss: 0.0101
# Epoch 2/10
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0046 - val_loss: 0.0093
# Epoch 3/10
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0026 - val_loss: 0.0050
# Epoch 4/10
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0015 - val_loss: 0.0046
# Epoch 5/10
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0014 - val_loss: 0.0043
# Epoch 6/10
# 53/53 [==============================] - 2s 35ms/step - loss: 9.7425e-04 - val_loss: 0.0043
# Epoch 7/10
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0013 - val_loss: 0.0047
# Epoch 8/10
# 53/53 [==============================] - 2s 36ms/step - loss: 8.0787e-04 - val_loss: 0.0057
# Epoch 9/10
# 53/53 [==============================] - 2s 38ms/step - loss: 6.5601e-04 - val_loss: 0.0043
# Epoch 10/10
# 53/53 [==============================] - 2s 34ms/step - loss: 5.5255e-04 - val_loss: 0.0039
# Iteration: 6
# Epoch 1/10
# 53/53 [==============================] - 2s 20ms/step - loss: 0.0212 - val_loss: 0.0083
# Epoch 2/10
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0031 - val_loss: 0.0058
# Epoch 3/10
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0023 - val_loss: 0.0059
# Epoch 4/10
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0016 - val_loss: 0.0051
# Epoch 5/10
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0010 - val_loss: 0.0036
# Epoch 6/10
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0012 - val_loss: 0.0041
# Epoch 7/10
# 53/53 [==============================] - 1s 18ms/step - loss: 7.4037e-04 - val_loss: 0.0036
# Epoch 8/10
# 53/53 [==============================] - 1s 18ms/step - loss: 5.8570e-04 - val_loss: 0.0039
# Epoch 9/10
# 53/53 [==============================] - 1s 17ms/step - loss: 6.1005e-04 - val_loss: 0.0033
# Epoch 10/10
# 53/53 [==============================] - 1s 17ms/step - loss: 4.2687e-04 - val_loss: 0.0030
# Iteration: 7
# Epoch 1/10
# 53/53 [==============================] - 2s 20ms/step - loss: 0.0252 - val_loss: 0.0070
# Epoch 2/10
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0039 - val_loss: 0.0046
# Epoch 3/10
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0022 - val_loss: 0.0037
# Epoch 4/10
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0014 - val_loss: 0.0048
# Epoch 5/10
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 6/10
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 7/10
# 53/53 [==============================] - 1s 17ms/step - loss: 7.2445e-04 - val_loss: 0.0032
# Epoch 8/10
# 53/53 [==============================] - 1s 17ms/step - loss: 5.6301e-04 - val_loss: 0.0028
# Epoch 9/10
# 53/53 [==============================] - 1s 18ms/step - loss: 4.5153e-04 - val_loss: 0.0028
# Epoch 10/10
# 53/53 [==============================] - 1s 17ms/step - loss: 5.5701e-04 - val_loss: 0.0029
# Iteration: 8
# Epoch 1/10
# 53/53 [==============================] - 2s 25ms/step - loss: 0.0220 - val_loss: 0.0067
# Epoch 2/10
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 3/10
# 53/53 [==============================] - 2s 31ms/step - loss: 0.0015 - val_loss: 0.0085
# Epoch 4/10
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0018 - val_loss: 0.0048
# Epoch 5/10
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0011 - val_loss: 0.0045
# Epoch 6/10
# 53/53 [==============================] - 2s 34ms/step - loss: 7.3760e-04 - val_loss: 0.0038
# Epoch 7/10
# 53/53 [==============================] - 2s 34ms/step - loss: 7.4468e-04 - val_loss: 0.0036
# Epoch 8/10
# 53/53 [==============================] - 2s 33ms/step - loss: 5.1227e-04 - val_loss: 0.0042
# Epoch 9/10
# 53/53 [==============================] - 2s 36ms/step - loss: 4.8263e-04 - val_loss: 0.0039
# Epoch 10/10
# 53/53 [==============================] - 1s 25ms/step - loss: 5.0269e-04 - val_loss: 0.0048
# Iteration: 9
# Epoch 1/10
# 53/53 [==============================] - 2s 20ms/step - loss: 0.0353 - val_loss: 0.0100
# Epoch 2/10
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0034 - val_loss: 0.0062
# Epoch 3/10
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0019 - val_loss: 0.0048
# Epoch 4/10
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 5/10
# 53/53 [==============================] - 1s 18ms/step - loss: 8.3031e-04 - val_loss: 0.0044
# Epoch 6/10
# 53/53 [==============================] - 1s 17ms/step - loss: 8.8139e-04 - val_loss: 0.0046
# Epoch 7/10
# 53/53 [==============================] - 1s 23ms/step - loss: 5.5980e-04 - val_loss: 0.0034
# Epoch 8/10
# 53/53 [==============================] - 1s 21ms/step - loss: 5.2364e-04 - val_loss: 0.0034
# Epoch 9/10
# 53/53 [==============================] - 1s 17ms/step - loss: 4.1808e-04 - val_loss: 0.0036
# Epoch 10/10
# 53/53 [==============================] - 1s 18ms/step - loss: 4.4179e-04 - val_loss: 0.0032
# Iteration: 10
# Epoch 1/10
# 53/53 [==============================] - 2s 24ms/step - loss: 0.0693 - val_loss: 0.0087
# Epoch 2/10
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0051 - val_loss: 0.0097
# Epoch 3/10
# 53/53 [==============================] - 1s 28ms/step - loss: 0.0031 - val_loss: 0.0046
# Epoch 4/10
# 53/53 [==============================] - 2s 30ms/step - loss: 0.0017 - val_loss: 0.0054
# Epoch 5/10
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 6/10
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0012 - val_loss: 0.0030
# Epoch 7/10
# 53/53 [==============================] - 2s 36ms/step - loss: 9.1871e-04 - val_loss: 0.0029
# Epoch 8/10
# 53/53 [==============================] - 2s 36ms/step - loss: 7.4712e-04 - val_loss: 0.0031
# Epoch 9/10
# 53/53 [==============================] - 2s 36ms/step - loss: 5.2151e-04 - val_loss: 0.0037
# Epoch 10/10
# 53/53 [==============================] - 2s 34ms/step - loss: 4.8149e-04 - val_loss: 0.0039
# Iteration: 11
# Epoch 1/10
# 53/53 [==============================] - 3s 33ms/step - loss: 0.0321 - val_loss: 0.0074
# Epoch 2/10
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0032 - val_loss: 0.0069
# Epoch 3/10
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0024 - val_loss: 0.0043
# Epoch 4/10
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 5/10
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0012 - val_loss: 0.0035
# Epoch 6/10
# 53/53 [==============================] - 1s 20ms/step - loss: 6.0105e-04 - val_loss: 0.0032
# Epoch 7/10
# 53/53 [==============================] - 1s 19ms/step - loss: 7.2451e-04 - val_loss: 0.0043
# Epoch 8/10
# 53/53 [==============================] - 1s 20ms/step - loss: 6.9549e-04 - val_loss: 0.0041
# Epoch 9/10
# 53/53 [==============================] - 1s 20ms/step - loss: 4.2048e-04 - val_loss: 0.0029
# Epoch 10/10
# 53/53 [==============================] - 1s 19ms/step - loss: 4.0560e-04 - val_loss: 0.0036
# Iteration: 12
# Epoch 1/10
# 53/53 [==============================] - 2s 23ms/step - loss: 0.0429 - val_loss: 0.0100
# Epoch 2/10
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0037 - val_loss: 0.0057
# Epoch 3/10
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0022 - val_loss: 0.0052
# Epoch 4/10
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0015 - val_loss: 0.0044
# Epoch 5/10
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 0.0044
# Epoch 6/10
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0012 - val_loss: 0.0038
# Epoch 7/10
# 53/53 [==============================] - 1s 27ms/step - loss: 7.7309e-04 - val_loss: 0.0035
# Epoch 8/10
# 53/53 [==============================] - 2s 30ms/step - loss: 6.2292e-04 - val_loss: 0.0030
# Epoch 9/10
# 53/53 [==============================] - 2s 32ms/step - loss: 5.5236e-04 - val_loss: 0.0034
# Epoch 10/10
# 53/53 [==============================] - 2s 36ms/step - loss: 5.0063e-04 - val_loss: 0.0043
# Iteration: 13
# Epoch 1/10
# 53/53 [==============================] - 3s 41ms/step - loss: 0.0192 - val_loss: 0.0063
# Epoch 2/10
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0026 - val_loss: 0.0044
# Epoch 3/10
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 4/10
# 53/53 [==============================] - 1s 27ms/step - loss: 9.1950e-04 - val_loss: 0.0026
# Epoch 5/10
# 53/53 [==============================] - 1s 19ms/step - loss: 6.2920e-04 - val_loss: 0.0023
# Epoch 6/10
# 53/53 [==============================] - 1s 17ms/step - loss: 5.7994e-04 - val_loss: 0.0027
# Epoch 7/10
# 53/53 [==============================] - 1s 17ms/step - loss: 5.8869e-04 - val_loss: 0.0021
# Epoch 8/10
# 53/53 [==============================] - 1s 17ms/step - loss: 3.9535e-04 - val_loss: 0.0022
# Epoch 9/10
# 53/53 [==============================] - 1s 17ms/step - loss: 2.6852e-04 - val_loss: 0.0025
# Epoch 10/10
# 53/53 [==============================] - 1s 17ms/step - loss: 4.7536e-04 - val_loss: 0.0020
# Iteration: 14
# Epoch 1/10
# 53/53 [==============================] - 2s 21ms/step - loss: 0.0367 - val_loss: 0.0093
# Epoch 2/10
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0042 - val_loss: 0.0076
# Epoch 3/10
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0020 - val_loss: 0.0071
# Epoch 4/10
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0014 - val_loss: 0.0058
# Epoch 5/10
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0011 - val_loss: 0.0056
# Epoch 6/10
# 53/53 [==============================] - 1s 21ms/step - loss: 9.6724e-04 - val_loss: 0.0048
# Epoch 7/10
# 53/53 [==============================] - 2s 29ms/step - loss: 8.8993e-04 - val_loss: 0.0067
# Epoch 8/10
# 53/53 [==============================] - 2s 31ms/step - loss: 8.6144e-04 - val_loss: 0.0066
# Epoch 9/10
# 53/53 [==============================] - 2s 35ms/step - loss: 6.0274e-04 - val_loss: 0.0059
# Epoch 10/10
# 53/53 [==============================] - 1s 27ms/step - loss: 6.1245e-04 - val_loss: 0.0054
# Iteration: 15
# Epoch 1/10
# 53/53 [==============================] - 3s 42ms/step - loss: 0.0293 - val_loss: 0.0097
# Epoch 2/10
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0049 - val_loss: 0.0067
# Epoch 3/10
# 53/53 [==============================] - 2s 29ms/step - loss: 0.0026 - val_loss: 0.0054
# Epoch 4/10
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 0.0058
# Epoch 5/10
# 53/53 [==============================] - 1s 24ms/step - loss: 0.0011 - val_loss: 0.0054
# Epoch 6/10
# 53/53 [==============================] - 1s 25ms/step - loss: 7.7454e-04 - val_loss: 0.0062
# Epoch 7/10
# 53/53 [==============================] - 1s 22ms/step - loss: 8.8820e-04 - val_loss: 0.0053
# Epoch 8/10
# 53/53 [==============================] - 1s 22ms/step - loss: 8.5904e-04 - val_loss: 0.0048
# Epoch 9/10
# 53/53 [==============================] - 1s 23ms/step - loss: 5.6830e-04 - val_loss: 0.0037
# Epoch 10/10
# 53/53 [==============================] - 1s 24ms/step - loss: 5.1758e-04 - val_loss: 0.0043
# Iteration: 16
# Epoch 1/10
# 53/53 [==============================] - 2s 23ms/step - loss: 0.0148 - val_loss: 0.0067
# Epoch 2/10
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 3/10
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0016 - val_loss: 0.0039
# Epoch 4/10
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 0.0042
# Epoch 5/10
# 53/53 [==============================] - 1s 18ms/step - loss: 9.6415e-04 - val_loss: 0.0030
# Epoch 6/10
# 53/53 [==============================] - 1s 18ms/step - loss: 5.3946e-04 - val_loss: 0.0029
# Epoch 7/10
# 53/53 [==============================] - 1s 20ms/step - loss: 5.8679e-04 - val_loss: 0.0023
# Epoch 8/10
# 53/53 [==============================] - 1s 19ms/step - loss: 6.6910e-04 - val_loss: 0.0025
# Epoch 9/10
# 53/53 [==============================] - 1s 18ms/step - loss: 3.2457e-04 - val_loss: 0.0029
# Epoch 10/10
# 53/53 [==============================] - 1s 18ms/step - loss: 4.6338e-04 - val_loss: 0.0028
# Iteration: 17
# Epoch 1/10
# 53/53 [==============================] - 2s 21ms/step - loss: 0.0504 - val_loss: 0.0113
# Epoch 2/10
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 3/10
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0032 - val_loss: 0.0064
# Epoch 4/10
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0024 - val_loss: 0.0056
# Epoch 5/10
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0016 - val_loss: 0.0063
# Epoch 6/10
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 0.0050
# Epoch 7/10
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 0.0046
# Epoch 8/10
# 53/53 [==============================] - 1s 22ms/step - loss: 9.2714e-04 - val_loss: 0.0039
# Epoch 9/10
# 53/53 [==============================] - 1s 19ms/step - loss: 6.2067e-04 - val_loss: 0.0041
# Epoch 10/10
# 53/53 [==============================] - 1s 21ms/step - loss: 5.5328e-04 - val_loss: 0.0030
# Iteration: 18
# Epoch 1/10
# 53/53 [==============================] - 2s 27ms/step - loss: 0.0270 - val_loss: 0.0087
# Epoch 2/10
# 53/53 [==============================] - 1s 23ms/step - loss: 0.0045 - val_loss: 0.0051
# Epoch 3/10
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0024 - val_loss: 0.0044
# Epoch 4/10
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 0.0039
# Epoch 5/10
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 0.0040
# Epoch 6/10
# 53/53 [==============================] - 1s 19ms/step - loss: 9.1127e-04 - val_loss: 0.0045
# Epoch 7/10
# 53/53 [==============================] - 1s 18ms/step - loss: 7.1203e-04 - val_loss: 0.0034
# Epoch 8/10
# 53/53 [==============================] - 1s 26ms/step - loss: 7.6490e-04 - val_loss: 0.0052
# Epoch 9/10
# 53/53 [==============================] - 2s 30ms/step - loss: 7.1005e-04 - val_loss: 0.0043
# Epoch 10/10
# 53/53 [==============================] - 2s 32ms/step - loss: 6.5575e-04 - val_loss: 0.0038
# Iteration: 19
# Epoch 1/10
# 53/53 [==============================] - 3s 38ms/step - loss: 0.0403 - val_loss: 0.0081
# Epoch 2/10
# 53/53 [==============================] - 2s 33ms/step - loss: 0.0032 - val_loss: 0.0057
# Epoch 3/10
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0021 - val_loss: 0.0048
# Epoch 4/10
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0013 - val_loss: 0.0042
# Epoch 5/10
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0014 - val_loss: 0.0045
# Epoch 6/10
# 53/53 [==============================] - 2s 30ms/step - loss: 6.2415e-04 - val_loss: 0.0033
# Epoch 7/10
# 53/53 [==============================] - 2s 29ms/step - loss: 6.1051e-04 - val_loss: 0.0033
# Epoch 8/10
# 53/53 [==============================] - 1s 26ms/step - loss: 4.6748e-04 - val_loss: 0.0032
# Epoch 9/10
# 53/53 [==============================] - 2s 34ms/step - loss: 4.4591e-04 - val_loss: 0.0032
# Epoch 10/10
# 53/53 [==============================] - 2s 37ms/step - loss: 3.4972e-04 - val_loss: 0.0039
# Iteration: 20
# Epoch 1/10
# 53/53 [==============================] - 3s 42ms/step - loss: 0.0243 - val_loss: 0.0072
# Epoch 2/10
# 53/53 [==============================] - 2s 36ms/step - loss: 0.0028 - val_loss: 0.0078
# Epoch 3/10
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0015 - val_loss: 0.0047
# Epoch 4/10
# 53/53 [==============================] - 2s 32ms/step - loss: 0.0011 - val_loss: 0.0039
# Epoch 5/10
# 53/53 [==============================] - 2s 35ms/step - loss: 6.7889e-04 - val_loss: 0.0061
# Epoch 6/10
# 53/53 [==============================] - 2s 32ms/step - loss: 8.9703e-04 - val_loss: 0.0041
# Epoch 7/10
# 53/53 [==============================] - 2s 35ms/step - loss: 5.8647e-04 - val_loss: 0.0038
# Epoch 8/10
# 53/53 [==============================] - 2s 36ms/step - loss: 5.2645e-04 - val_loss: 0.0040
# Epoch 9/10
# 53/53 [==============================] - 2s 34ms/step - loss: 5.3034e-04 - val_loss: 0.0037
# Epoch 10/10
# 53/53 [==============================] - 2s 33ms/step - loss: 4.5952e-04 - val_loss: 0.0046
# --------------------------
#
# Starting time: 1616525084.0146606
# Completing time: 1616525375.565598
# It took -4.859182290236155 minutes to train the model for 20 iterations

# %%
model.save("cnn_model1_three_features_extreme_cases.hdf5")

# %%
def plot_evaluation():
    #mean square error over iterations
    plt.figure(figsize=(15, 10))
    plt.plot(mse_for_iter)
    plt.ylabel('mean squared error')
    plt.xlabel('iteration')
    plt.savefig('mse.png', bbox_inches='tight')
    plt.show()
        
    #plot train and validation loss over epochs for each iteration
    fig, axs = plt.subplots(10, 2)
    #axs.set_ylabel('loss')
    #axs.set_xlabel('epoch')
    fig.set_size_inches(18.5, 50)
    for row in range(10):
        for col in range(2):
            index = 2*row + col #index to get loss from training loss and validation loss list
            axs[row, col].plot(train_loss_over_epoch[index])
            axs[row, col].plot(val_loss_over_epoch[index])
            axs[row, col].set_title('Iteration(%d)' %(index+1))
            axs[row, col].legend(['train', 'Val'], loc='upper left')            
    plt.savefig('train_val_loss.png', bbox_inches='tight')
    
    #plot predicted value vs actual values from last iteration
    plt.figure(figsize=(15, 10))
    plt.plot(predicted_y_values_unnor, 'ro', alpha=0.8)
    plt.plot(Y_test_abv_thres, 'bo', alpha=0.1)
    plt.legend(['Predicted values', 'Actual values'], loc='upper right')
    plt.ylabel('Outflow')
    plt.xlabel('nth datapoint')
    plt.savefig('predicted_values_visuals.png', bbox_inches='tight')
    plt.show()
    
#call plot_evaluation function
plot_evaluation()

# %%
mse_for_iter
# Out:
# [215464.69995881963,
#  233604.7939368898,
#  239363.75744262672,
#  242675.441490479,
#  240914.4795929368,
#  254829.95359100684,
#  234356.64244835512,
#  211666.939969344,
#  238264.0836136803,
#  214808.59639083105,
#  248228.4888142105,
#  234637.6875571732,
#  245496.24308047415,
#  225027.54465471022,
#  271872.98546433845,
#  231594.27294341975,
#  260494.95572334583,
#  259535.98935365854,
#  229759.01269860702,
#  214547.86637046273]

# %%
print(np.mean(mse_for_iter))
# Out:
# 237357.22175476846

# %%
plot_model(model, show_shapes=True)

# %%
# building timeseries data with given timesteps
def timeseries(X, Y, Y_actual, time_steps, out_steps):
    input_size_0 = X.shape[0] - time_steps
    input_size_1 = X.shape[1]
    output_size_0 = Y.shape[0] - time_steps
    output_size_1 = Y.shape[1]
    X_values = np.zeros((input_size_0, time_steps, input_size_1))
    Y_values = np.zeros((output_size_0, output_size_1))
    Y_values_actual = np.zeros((output_size_0, output_size_1))
    
    for i in tqdm_notebook(range(input_size_0)):
        X_values[i] = X[i:time_steps+i]
        Y_values[i] = Y[time_steps+i-1]
        Y_values_actual[i] = Y_actual[time_steps+i-1]
        
    print("length of time-series i/o",X_values.shape,Y_values.shape)
    return X_values, Y_values, Y_values_actual

#getting data ready for training the model
def data_processing(lag_df):   
    #Normalizing training data
    x_train_nor = xtrain_min_max_scaler.fit_transform(x_train)
    y_train_nor = ytrain_min_max_scaler.fit_transform(y_train)

    # Normalizing test data
    x_test_nor = xtest_min_max_scaler.fit_transform(x_test)
    y_test_nor = ytest_min_max_scaler.fit_transform(y_test)
    
    # Saving actual train and test y_label
    y_train_actual = y_train
    y_test_actual = y_test
    
    return x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual

# %%
#Building timeseries
x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual = data_processing(lag_df)
X_Train, Y_Train, Y_train_actual = timeseries(x_train_nor, y_train_nor, y_train_actual, time_steps=18, out_steps=1)
X_Test, Y_Test, Y_test_actual = timeseries(x_test_nor, y_test_nor, y_test_actual, time_steps=18, out_steps=1)
# Out:
# /home/bidur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   # This is added back by InteractiveShellApp.init_path()
# HBox(children=(FloatProgress(value=0.0, max=148416.0), HTML(value='')))
# length of time-series i/o (148416, 18, 3) (148416, 1)
# HBox(children=(FloatProgress(value=0.0, max=37091.0), HTML(value='')))
# length of time-series i/o (37091, 18, 3) (37091, 1)

# %%
y_train_predict = model.predict(X_Train)

# %%
Y_Train_predict = ytrain_min_max_scaler.inverse_transform(y_train_predict)

# %%
mean_squared_error(Y_Train_predict, Y_train_actual)
# Out:
# 6798.20375230718

# %%
#plot predicted value vs actual values from last iteration
plt.figure(figsize=(15, 10))
plt.plot(Y_Train_predict, 'ro', alpha=0.8)
plt.plot(Y_train_actual, 'bo', alpha=0.1)
plt.legend(['Predicted values', 'Actual values'], loc='upper right')
plt.ylabel('Outflow')
plt.xlabel('nth datapoint')
plt.savefig('predicted_values_visuals.png', bbox_inches='tight')
plt.show()

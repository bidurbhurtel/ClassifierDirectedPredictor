# %%
#import modules
import numpy as np
import pandas as pd
import time
from keras import backend as K 
from keras.engine.training import Model
from keras.utils import to_categorical, plot_model
from keras.models import Sequential, load_model
from sklearn.preprocessing import MinMaxScaler
from keras.layers.convolutional import Conv1D, Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers import Dropout, Activation, Flatten
from keras.layers import LSTM, Dense, Input
from keras.optimizers import SGD
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tqdm import tqdm_notebook
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('../Sub0-RAW.csv')
df.head()

# %%
train_cols = ["Precipitation","Outflow"]
label_cols = ["Outflow(t+1)"]

# %%
new_df = df.filter(["Precipitation","Temperature", "Outflow"], axis=1)

# %%
#Min Max scalr normalizing
xtrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
xtest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))

# %%
#function to shift the time_series data for getting labels
def lag_seq(df, n_seq):
    for i in range(n_seq):
        df['Outflow(t+%d)' %(i+1)] = new_df['Outflow'].shift(-(i+1))
    return df

# building timeseries data with given timesteps
def timeseries(X, Y, Y_actual, time_steps, out_steps):
    input_size_0 = X.shape[0] - time_steps
    input_size_1 = X.shape[1]
    X_values = np.zeros((input_size_0, time_steps, input_size_1))
    Y_values = np.zeros((input_size_0,))
    Y_values_actual = np.zeros((input_size_0,))
    
    for i in tqdm_notebook(range(input_size_0)):
        X_values[i] = X[i:time_steps+i]
        Y_values[i] = Y[time_steps+i-1, 0]
        Y_values_actual[i] = Y_actual[time_steps+i-1, 0]
        
    print("length of time-series i/o",X_values.shape,Y_values.shape)
    return X_values, Y_values, Y_values_actual

#getting data ready for training the model
def data_processing(lag_df):
    #Splitting training and test data
    df_train, df_test = train_test_split(lag_df, train_size=0.8, test_size=0.2, shuffle=False)
    x_train = df_train.loc[:,train_cols].values
    y_train = df_train.loc[:,label_cols].values
    x_test = df_test.loc[:,train_cols].values
    y_test = df_test.loc[:,label_cols].values    
   
    #Normalizing training data
    x_train_nor = xtrain_min_max_scaler.fit_transform(x_train)
    y_train_nor = ytrain_min_max_scaler.fit_transform(y_train)

    # Normalizing test data
    x_test_nor = xtest_min_max_scaler.fit_transform(x_test)
    y_test_nor = ytest_min_max_scaler.fit_transform(y_test)
    
    # Saving actual train and test y_label
    y_train_actual = y_train
    y_test_actual = y_test
    
    #Building timeseries
    X_Train, Y_Train, Y_train_actual = timeseries(x_train_nor, y_train_nor, y_train_actual, time_steps=18, out_steps=1)
    X_Test, Y_Test, Y_test_actual = timeseries(x_test_nor, y_test_nor, y_test_actual, time_steps=18, out_steps=1)
    
    return X_Train, Y_Train, Y_train_actual, X_Test, Y_Test, Y_test_actual

# %%
#calling function to create lag dataframe
lag_df = lag_seq(new_df, 1)
lag_df.dropna(inplace=True)
X_Train, Y_Train, Y_train_actual, X_Test, Y_Test, Y_test_actual = data_processing(lag_df)
# Out:
# /home/bidur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   from ipykernel import kernelapp as app
# HBox(children=(FloatProgress(value=0.0, max=148416.0), HTML(value='')))
# length of time-series i/o (148416, 18, 2) (148416,)
# HBox(children=(FloatProgress(value=0.0, max=37091.0), HTML(value='')))
# length of time-series i/o (37091, 18, 2) (37091,)

# %%
#Build Model
def make_model(X_Train):
    input_layer = Input(shape=(X_Train.shape[1], X_Train.shape[2]))

    conv1 = Conv1D(filters=16, kernel_size=3, strides=1,
                    padding='same',activation='relu')(input_layer)
    conv2 = Conv1D(filters=32, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv1)
    conv3 = Conv1D(filters=64, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv2)

    flatten = Flatten()(conv3)

    dense1 = Dense(1152, activation='relu')(flatten)
    dense2 = Dense(576, activation='relu')(dense1)
    output_layer = Dense(1, activation='linear')(dense2)
    
    return Model(inputs=input_layer, outputs=output_layer)

# %%
mse_for_iter = []
train_loss_over_epoch = []
val_loss_over_epoch = []
predicted_y_values_unnors = []
models = []
def run_iteration(no_iter=20, epochs = 10):
    start_time = time.time()
    for iteration in range(no_iter):
        print(f'Iteration: {iteration + 1}')
        K.clear_session()
        model = make_model(X_Train)
        #plot_model(model, show_shapes=True)
        model.compile(optimizer = 'adam', loss = 'mean_squared_error')
        history = model.fit(X_Train, Y_Train, epochs=epochs,
                       validation_data=(X_Test, Y_Test))
        train_loss_over_epoch.append(history.history['loss'])
        val_loss_over_epoch.append(history.history['val_loss'])
        predicted_y_values = model.predict(X_Test)
        predicted_y_values_unnor = ytrain_min_max_scaler.inverse_transform(predicted_y_values)
        mse_for_iter.append(mean_squared_error(predicted_y_values_unnor, Y_test_actual))
        predicted_y_values_unnors.append(predicted_y_values_unnor)
        models.append(model)
        
    end_time = time.time()
    print('--------------------------\n')
    print(f'Starting time: {start_time}')
    print(f'Completing time: {end_time}')
    print(f'It took {(start_time - end_time)/60} minutes to train the model for {no_iter} iterations')
    #return predicted unnormalized values for test set from last iteration 
    return predicted_y_values_unnor, model

predicted_y_values_unnor, model = run_iteration(20,10)
# Out:
# Iteration: 1
# Epoch 1/10
# 4638/4638 [==============================] - 69s 15ms/step - loss: 6.3024e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 63s 14ms/step - loss: 5.2041e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 62s 13ms/step - loss: 4.9617e-04 - val_loss: 0.0012
# Epoch 4/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.8411e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.7827e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.6444e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.6575e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.4887e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 61s 13ms/step - loss: 4.4144e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.4086e-04 - val_loss: 0.0011
# Iteration: 2
# Epoch 1/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.9698e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.2108e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 61s 13ms/step - loss: 4.9646e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.8447e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 61s 13ms/step - loss: 4.7090e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.6780e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 61s 13ms/step - loss: 4.5382e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 62s 13ms/step - loss: 4.5074e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 63s 14ms/step - loss: 4.4300e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.2803e-04 - val_loss: 0.0012
# Iteration: 3
# Epoch 1/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.8737e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.1297e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.9732e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.8836e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.7191e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.6942e-04 - val_loss: 0.0013
# Epoch 7/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.5641e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.4977e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.4002e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.3779e-04 - val_loss: 0.0011
# Iteration: 4
# Epoch 1/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.8771e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.1527e-04 - val_loss: 0.0012
# Epoch 3/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.9698e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.8478e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.7135e-04 - val_loss: 0.0014
# Epoch 6/10
# 4638/4638 [==============================] - 61s 13ms/step - loss: 4.6344e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.5306e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.4530e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.4606e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.3431e-04 - val_loss: 0.0011
# Iteration: 5
# Epoch 1/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 6.0370e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 61s 13ms/step - loss: 5.2053e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 61s 13ms/step - loss: 5.0249e-04 - val_loss: 0.0013
# Epoch 4/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.8533e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 61s 13ms/step - loss: 4.7597e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.6592e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 61s 13ms/step - loss: 4.5288e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 61s 13ms/step - loss: 4.4464e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 61s 13ms/step - loss: 4.4084e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 61s 13ms/step - loss: 4.2829e-04 - val_loss: 0.0011
# Iteration: 6
# Epoch 1/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 6.6522e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 5.2540e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.9628e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.9149e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.7771e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.6601e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.5604e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.4654e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.3717e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.2729e-04 - val_loss: 0.0012
# Iteration: 7
# Epoch 1/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 6.3556e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 5.2044e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.9446e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.8747e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.7116e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.6332e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.5626e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.4755e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.4414e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.3381e-04 - val_loss: 0.0012
# Iteration: 8
# Epoch 1/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 6.1737e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 5.2111e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.0360e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.8463e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.7263e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.6620e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.5373e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 62s 13ms/step - loss: 4.4239e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.4348e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.2792e-04 - val_loss: 0.0011
# Iteration: 9
# Epoch 1/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 6.8875e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.2849e-04 - val_loss: 0.0012
# Epoch 3/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.1551e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.9857e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.8397e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.7314e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.6577e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.5782e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.5392e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.4013e-04 - val_loss: 0.0012
# Iteration: 10
# Epoch 1/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 5.8259e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 5.1442e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 5.0134e-04 - val_loss: 0.0012
# Epoch 4/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.8906e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.7923e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.6531e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.5949e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.4977e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 62s 13ms/step - loss: 4.4485e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 64s 14ms/step - loss: 4.3755e-04 - val_loss: 0.0011
# Iteration: 11
# Epoch 1/10
# 4638/4638 [==============================] - 61s 13ms/step - loss: 5.8981e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 61s 13ms/step - loss: 5.3112e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 65s 14ms/step - loss: 5.0067e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 62s 13ms/step - loss: 4.8638e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 65s 14ms/step - loss: 4.7234e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 66s 14ms/step - loss: 4.6865e-04 - val_loss: 0.0012
# Epoch 7/10
# 4638/4638 [==============================] - 62s 13ms/step - loss: 4.6511e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 61s 13ms/step - loss: 4.5098e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.4372e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.3900e-04 - val_loss: 0.0012
# Iteration: 12
# Epoch 1/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.9690e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 5.1426e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.9936e-04 - val_loss: 0.0013
# Epoch 4/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.9026e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.6943e-04 - val_loss: 0.0012
# Epoch 6/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.6283e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.5117e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.4614e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.3930e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.2795e-04 - val_loss: 0.0012
# Iteration: 13
# Epoch 1/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 5.8789e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 5.1994e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.9467e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.8381e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.7304e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.6305e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.5501e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.4946e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.4332e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.3648e-04 - val_loss: 0.0012
# Iteration: 14
# Epoch 1/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 6.5044e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.1998e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 5.0126e-04 - val_loss: 0.0013
# Epoch 4/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.8623e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.7038e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.6124e-04 - val_loss: 0.0012
# Epoch 7/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.5421e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 62s 13ms/step - loss: 4.4218e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.3257e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.2605e-04 - val_loss: 0.0012
# Iteration: 15
# Epoch 1/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 5.7649e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.1295e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.9392e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.8364e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.7770e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.6781e-04 - val_loss: 0.0012
# Epoch 7/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.5937e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.5734e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.4668e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.3577e-04 - val_loss: 0.0012
# Iteration: 16
# Epoch 1/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.6937e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 5.1588e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.9734e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.8324e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.7378e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.6464e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.6075e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.5375e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.3513e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.3126e-04 - val_loss: 0.0011
# Iteration: 17
# Epoch 1/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 6.0628e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 5.2124e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.0348e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.9708e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.7819e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.6754e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.6375e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.5234e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.4823e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.4222e-04 - val_loss: 0.0011
# Iteration: 18
# Epoch 1/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 6.7593e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.2355e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.1412e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.8948e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.8416e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.6731e-04 - val_loss: 0.0012
# Epoch 7/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.6157e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.4970e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.5111e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.3823e-04 - val_loss: 0.0011
# Iteration: 19
# Epoch 1/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.9102e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.2155e-04 - val_loss: 0.0012
# Epoch 3/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.9096e-04 - val_loss: 0.0012
# Epoch 4/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.8156e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.6748e-04 - val_loss: 0.0012
# Epoch 6/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.6577e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.5412e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.4473e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.3588e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.2918e-04 - val_loss: 0.0012
# Iteration: 20
# Epoch 1/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 6.7291e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.1382e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 5.0618e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.8599e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.7614e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.6776e-04 - val_loss: 0.0013
# Epoch 7/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.6267e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 62s 13ms/step - loss: 4.5564e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 60s 13ms/step - loss: 4.4714e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 59s 13ms/step - loss: 4.3956e-04 - val_loss: 0.0012
# --------------------------
#
# Starting time: 1611139115.9597137
# Completing time: 1611151229.174024
# It took -201.88690517346063 minutes to train the model for 20 iterations

# %%
model.save("cnn_model1_2_features.hdf5")

# %%
def plot_evaluation():
    #mean square error over iterations
    plt.figure(figsize=(15, 10))
    plt.plot(mse_for_iter)
    plt.ylabel('mean squared error')
    plt.xlabel('iteration')
    plt.savefig('mse.png', bbox_inches='tight')
    plt.show()
        
    #plot train and validation loss over epochs for each iteration
    fig, axs = plt.subplots(10, 2)
    #axs.set_ylabel('loss')
    #axs.set_xlabel('epoch')
    fig.set_size_inches(18.5, 50)
    for row in range(10):
        for col in range(2):
            index = 2*row + col #index to get loss from training loss and validation loss list
            axs[row, col].plot(train_loss_over_epoch[index])
            axs[row, col].plot(val_loss_over_epoch[index])
            axs[row, col].set_title('Iteration(%d)' %(index+1))
            axs[row, col].legend(['train', 'Val'], loc='upper left')            
    plt.savefig('train_val_loss.png', bbox_inches='tight')
    
    #plot predicted value vs actual values from last iteration
    plt.figure(figsize=(15, 10))
    plt.plot(predicted_y_values_unnor, 'ro', alpha=0.8)
    plt.plot(Y_test_actual, 'bo', alpha=0.1)
    plt.legend(['Predicted values', 'Actual values'], loc='upper right')
    plt.ylabel('Outflow')
    plt.xlabel('nth datapoint')
    plt.savefig('predicted_values_visuals.png', bbox_inches='tight')
    plt.show()
    
#call plot_evaluation function
plot_evaluation()

# %%
mse_for_iter
# Out:
# [4172.873506298799,
#  4221.384361708657,
#  4156.485762438688,
#  4147.6611179335505,
#  4076.004080178543,
#  4314.759335891507,
#  4233.772929469437,
#  4151.948048795953,
#  4340.910589412753,
#  4119.687272706923,
#  4322.456312511871,
#  4292.229441141622,
#  4426.807139926758,
#  4433.557175797389,
#  4242.660015602601,
#  4179.4793892544685,
#  4182.295711757294,
#  4122.142040379577,
#  4265.556025638325,
#  4189.597428855195]

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 18, 2)]           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 18, 16)            112
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 18, 32)            1568
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 18, 64)            6208
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 1152)              1328256
# _________________________________________________________________
# dense_1 (Dense)              (None, 576)               664128
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 577
# =================================================================
# Total params: 2,000,849
# Trainable params: 2,000,849
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(np.mean(mse_for_iter))
# Out:
# 4229.613384284996

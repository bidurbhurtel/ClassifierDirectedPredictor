# %%
#import modules
import numpy as np
import pandas as pd
import time
from keras import backend as K 
from keras.engine.training import Model
from keras.utils import to_categorical, plot_model
from keras.models import Sequential, load_model
from sklearn.preprocessing import MinMaxScaler
from keras.layers.convolutional import Conv1D, Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers import Dropout, Activation, Flatten
from keras.layers import LSTM, Dense, Input
from keras.optimizers import SGD
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tqdm import tqdm_notebook
from sklearn.metrics import mean_squared_error

# %%
#import data
df = pd.read_csv('./Sub0-RAW.csv')
df.head()
# Out:
#        Dates  Year  Month  Day    Hours  Precipitation  Temperature  Outflow
# 0  10/1/1980  1980     10    1  0:00:00            0.0      102.992      5.0
# 1  10/1/1980  1980     10    1  1:00:00            0.0       97.790      5.0
# 2  10/1/1980  1980     10    1  2:00:00            0.0       92.588      5.0
# 3  10/1/1980  1980     10    1  3:00:00            0.0       87.404      5.0
# 4  10/1/1980  1980     10    1  4:00:00            0.0       85.172      5.0

# %%
#define train and label column
train_cols = ["Precipitation","Temperature", "Outflow"]
label_cols = ["Precipitation(t+1)","Temperature(t+1)"]

# %%
#filter the columns
new_df = df.filter(train_cols, axis=1)

# %%
#Min Max scalr normalizing
xtrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
xtest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))

# %%
#function to shift the time_series data for getting labels
def lag_seq(df, n_seq):
    for i in range(n_seq):
        df['Precipitation(t+%d)' %(i+1)] = new_df['Precipitation'].shift(-(i+1))
        df['Temperature(t+%d)' %(i+1)] = new_df['Temperature'].shift(-(i+1))        
        df['Outflow(t+%d)' %(i+1)] = new_df['Outflow'].shift(-(i+1))
    return df

# building timeseries data with given timesteps
def timeseries(X, Y, Y_actual, time_steps, out_steps):
    input_size_0 = X.shape[0] - time_steps
    input_size_1 = X.shape[1]
    output_size_0 = Y.shape[0] - time_steps
    output_size_1 = Y.shape[1]
    X_values = np.zeros((input_size_0, time_steps, input_size_1))
    Y_values = np.zeros((output_size_0, output_size_1))
    Y_values_actual = np.zeros((output_size_0, output_size_1))
    
    for i in tqdm_notebook(range(input_size_0)):
        X_values[i] = X[i:time_steps+i]
        Y_values[i] = Y[time_steps+i-1]
        Y_values_actual[i] = Y_actual[time_steps+i-1]
        
    print("length of time-series i/o",X_values.shape,Y_values.shape)
    return X_values, Y_values, Y_values_actual

#getting data ready for training the model
def data_processing(lag_df):
    #Splitting training and test data
    df_train, df_test = train_test_split(lag_df, train_size=0.8, test_size=0.2, shuffle=False)
    x_train = df_train.loc[:,train_cols].values
    y_train = df_train.loc[:,label_cols].values
    x_test = df_test.loc[:,train_cols].values
    y_test = df_test.loc[:,label_cols].values    
   
    #Normalizing training data
    x_train_nor = xtrain_min_max_scaler.fit_transform(x_train)
    y_train_nor = ytrain_min_max_scaler.fit_transform(y_train)

    # Normalizing test data
    x_test_nor = xtest_min_max_scaler.fit_transform(x_test)
    y_test_nor = ytest_min_max_scaler.fit_transform(y_test)
    
    # Saving actual train and test y_label
    y_train_actual = y_train
    y_test_actual = y_test
    
    return x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual

# %%
#calling function to create lag dataframe
lag_df = lag_seq(new_df, 2)
lag_df.dropna(inplace=True)

# %%
lag_df
# Out:
#         Precipitation  Temperature  ...  Temperature(t+2)  Outflow(t+2)
# 0                 0.0      102.992  ...            92.588           5.0
# 1                 0.0       97.790  ...            87.404           5.0
# 2                 0.0       92.588  ...            85.172           5.0
# 3                 0.0       87.404  ...            82.940           5.0
# 4                 0.0       85.172  ...            80.708           5.0
# ...               ...          ...  ...               ...           ...
# 185537            0.0       50.054  ...            54.284          30.0
# 185538            0.0       52.880  ...            55.670          29.0
# 185539            0.0       54.284  ...            57.074          29.0
# 185540            0.0       55.670  ...            57.056          31.0
# 185541            0.0       57.074  ...            57.020          38.0
#
# [185542 rows x 9 columns]

# %%
#Building timeseries
x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual = data_processing(lag_df)
X_Train, Y_Train, Y_train_actual = timeseries(x_train_nor, y_train_nor, y_train_actual, time_steps=18, out_steps=1)
X_Test, Y_Test, Y_test_actual = timeseries(x_test_nor, y_test_nor, y_test_actual, time_steps=18, out_steps=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=148415.0), HTML(value='')))
# length of time-series i/o (148415, 18, 3) (148415, 2)
# HBox(children=(FloatProgress(value=0.0, max=37091.0), HTML(value='')))
# length of time-series i/o (37091, 18, 3) (37091, 2)

# %%
#Build Model
def make_model(X_Train):
    input_layer = Input(shape=(X_Train.shape[1], X_Train.shape[2]))

    conv1 = Conv1D(filters=16, kernel_size=3, strides=1,
                    padding='same',activation='relu')(input_layer)
    conv2 = Conv1D(filters=32, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv1)
    conv3 = Conv1D(filters=64, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv2)

    flatten = Flatten()(conv3)

    dense1 = Dense(1152, activation='relu')(flatten)
    dense2 = Dense(576, activation='relu')(dense1)
    output_layer = Dense(2, activation='linear')(dense2)
    
    return Model(inputs=input_layer, outputs=output_layer)

# %%
mse_for_iter = []
train_loss_over_epoch = []
val_loss_over_epoch = []

def run_iteration(no_iter=20, epochs = 10):
    start_time = time.time()
    for iteration in range(no_iter):
        print(f'Iteration: {iteration + 1}')
        K.clear_session()
        model = make_model(X_Train)
        #plot_model(model, show_shapes=True)
        model.compile(optimizer = 'adam', loss = 'mean_squared_error')
        history = model.fit(X_Train, Y_Train, epochs=epochs,
                       validation_data=(X_Test, Y_Test))
        train_loss_over_epoch.append(history.history['loss'])
        val_loss_over_epoch.append(history.history['val_loss'])
        predicted_y_values = model.predict(X_Test)
        predicted_y_values_unnor = ytrain_min_max_scaler.inverse_transform(predicted_y_values)
        mse_for_iter.append(mean_squared_error(predicted_y_values_unnor, Y_test_actual))
               
    end_time = time.time()
    print('--------------------------\n')
    print(f'Starting time: {start_time}')
    print(f'Completing time: {end_time}')
    print(f'It took {(start_time - end_time)/60} minutes to train the model for {no_iter} iterations')
    #return predicted unnormalized values for test set from last iteration 
    return predicted_y_values, predicted_y_values_unnor, model

predicted_y_values, predicted_y_values_unnor, model = run_iteration(1,10)
# Out:
# Iteration: 1
# Epoch 1/10
# 4638/4638 [==============================] - 22s 3ms/step - loss: 9.2495e-04 - val_loss: 1.2953e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.8001e-05 - val_loss: 9.8631e-05
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.3741e-05 - val_loss: 9.7554e-05
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.3301e-05 - val_loss: 9.4208e-05
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.1163e-05 - val_loss: 9.1271e-05
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 6.9739e-05 - val_loss: 1.0333e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 7.1928e-05 - val_loss: 9.4595e-05
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 6.3206e-05 - val_loss: 9.2992e-05
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 6.6089e-05 - val_loss: 9.7405e-05
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 6.3844e-05 - val_loss: 9.2400e-05
# --------------------------
#
# Starting time: 1613015199.5050724
# Completing time: 1613015353.7126226
# It took -2.5701258381207785 minutes to train the model for 1 iterations

# %%
#prediction for X_Train values which has to be used to predict another day output
y_train_predict = model.predict(X_Train)

# %%
#define train and label column for day 2
train_cols = ["Precipitation","Temperature"]
label_cols = ["Outflow(t+2)"]

# %%
#Building timeseries for day 2
time_steps = 18
x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual = data_processing(lag_df)
X_Train, Y_Train, Y_train_actual = timeseries(x_train_nor, y_train_nor, y_train_actual, time_steps=18, out_steps=1)
X_Test, Y_Test, Y_test_actual = timeseries(x_test_nor, y_test_nor, y_test_actual, time_steps=18, out_steps=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=148415.0), HTML(value='')))
# length of time-series i/o (148415, 18, 2) (148415, 1)
# HBox(children=(FloatProgress(value=0.0, max=37091.0), HTML(value='')))
# length of time-series i/o (37091, 18, 2) (37091, 1)

# %%
#preparing timeseries for day2 data
train_input_size_0 = X_Train.shape[0]
test_input_size_0 = X_Test.shape[0]
input_size_2 = X_Train.shape[2]
output_size_0 = Y_Train.shape[0]
output_size_1 = Y_Train.shape[1]
X_Train1 = np.zeros((train_input_size_0, time_steps+1, input_size_2))
X_Test1 = np.zeros((test_input_size_0, time_steps+1, input_size_2))

#replacing last value of each timeseries data with the predicted value
len_data = len(X_Train1)
for i in range (len_data):
    #reshaping y_train_predict to make both values under concatenation of same shape 
    X_Train1[i] = np.concatenate((X_Train[i], y_train_predict[i].reshape(1,2)), axis=0) 
len_data_test = len(X_Test)
for i in range (len_data_test):
    X_Test1[i] = np.concatenate((X_Test[i],predicted_y_values[i].reshape(1,2)), axis=0)

# %%
#Build Model for day 2
def make_model1(X_Train):
    input_layer = Input(shape=(X_Train.shape[1], X_Train.shape[2]))

    conv1 = Conv1D(filters=16, kernel_size=3, strides=1,
                    padding='same',activation='relu')(input_layer)
    conv2 = Conv1D(filters=32, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv1)
    conv3 = Conv1D(filters=64, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv2)

    flatten = Flatten()(conv3)

    dense1 = Dense(1152, activation='relu')(flatten)
    dense2 = Dense(576, activation='relu')(dense1)
    output_layer = Dense(1, activation='linear')(dense2)
    
    return Model(inputs=input_layer, outputs=output_layer)

# %%
mse_for_iter1 = []
train_loss_over_epoch1 = []
val_loss_over_epoch1 = []
predicted_y_values1_unnors = []
models = []

def run_iteration_model_2(no_iter=20, epochs = 10):
    start_time = time.time()
    for iteration in range(no_iter):
        print(f'Iteration: {iteration + 1}')
        K.clear_session()
        model1 = make_model1(X_Train1)
        #plot_model(model, show_shapes=True)
        model1.compile(optimizer = 'adam', loss = 'mean_squared_error')
        history = model1.fit(X_Train1, Y_Train, epochs=epochs,
                       validation_data=(X_Test1, Y_Test))
        train_loss_over_epoch1.append(history.history['loss'])
        val_loss_over_epoch1.append(history.history['val_loss'])
        predicted_y_values1 = model1.predict(X_Test1)
        predicted_y_values1_unnor = ytrain_min_max_scaler.inverse_transform(predicted_y_values1)
        mse_for_iter1.append(mean_squared_error(predicted_y_values1_unnor, Y_test_actual))
        predicted_y_values1_unnors.append(predicted_y_values1_unnor)
        models.append(model1)
               
    end_time = time.time()
    print('--------------------------\n')
    print(f'Starting time: {start_time}')
    print(f'Completing time: {end_time}')
    print(f'It took {(start_time - end_time)/60} minutes to train the model for {no_iter} iterations')
    #return predicted unnormalized values for test set from last iteration 
    return predicted_y_values1, predicted_y_values1_unnor, model1

predicted_y_values1, predicted_y_values1_unnor, model1 = run_iteration_model_2(20,10)
# Out:
# Iteration: 1
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 0.0012 - val_loss: 7.6871e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.3768e-04 - val_loss: 5.7961e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.0262e-04 - val_loss: 4.6653e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.5918e-04 - val_loss: 4.4034e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.7061e-04 - val_loss: 4.1675e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3728e-04 - val_loss: 4.2451e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2561e-04 - val_loss: 4.3716e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3124e-04 - val_loss: 4.5926e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3425e-04 - val_loss: 4.1380e-04
# Epoch 10/10
# 4638/4638 [==============================] - 13s 3ms/step - loss: 2.0641e-04 - val_loss: 5.6141e-04
# Iteration: 2
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 7.2813e-04 - val_loss: 6.2632e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.1727e-04 - val_loss: 5.1071e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.3013e-04 - val_loss: 4.7515e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.7943e-04 - val_loss: 4.1936e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3463e-04 - val_loss: 4.5402e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.6443e-04 - val_loss: 4.2797e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2883e-04 - val_loss: 4.5584e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2171e-04 - val_loss: 3.9823e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.1501e-04 - val_loss: 4.3656e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.9988e-04 - val_loss: 4.3560e-04
# Iteration: 3
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 9.7559e-04 - val_loss: 4.6095e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.6173e-04 - val_loss: 5.1169e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.8877e-04 - val_loss: 5.6337e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.8471e-04 - val_loss: 4.4210e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.5553e-04 - val_loss: 4.3871e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.6931e-04 - val_loss: 4.1933e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2812e-04 - val_loss: 4.2700e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.5112e-04 - val_loss: 4.0676e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.1645e-04 - val_loss: 4.6131e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.9758e-04 - val_loss: 3.8199e-04
# Iteration: 4
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.9877e-04 - val_loss: 4.8442e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.2978e-04 - val_loss: 4.9717e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.8865e-04 - val_loss: 5.0775e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.9291e-04 - val_loss: 3.9882e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4473e-04 - val_loss: 4.4807e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4433e-04 - val_loss: 4.3375e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4809e-04 - val_loss: 4.3039e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.1736e-04 - val_loss: 4.1102e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.1816e-04 - val_loss: 4.1216e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3206e-04 - val_loss: 3.9958e-04
# Iteration: 5
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 0.0026 - val_loss: 4.7984e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.5373e-04 - val_loss: 4.7883e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.4317e-04 - val_loss: 7.7767e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.7710e-04 - val_loss: 4.9995e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.0956e-04 - val_loss: 4.3212e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.5487e-04 - val_loss: 5.9226e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2968e-04 - val_loss: 3.8715e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3379e-04 - val_loss: 3.8892e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.0533e-04 - val_loss: 4.5491e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.0758e-04 - val_loss: 4.4046e-04
# Iteration: 6
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 0.0011 - val_loss: 5.4682e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 4.1479e-04 - val_loss: 4.5393e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.1495e-04 - val_loss: 4.4684e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.7365e-04 - val_loss: 4.4676e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.7438e-04 - val_loss: 4.6058e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.6127e-04 - val_loss: 4.2696e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.5595e-04 - val_loss: 4.1447e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3945e-04 - val_loss: 4.1528e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3570e-04 - val_loss: 4.7936e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2115e-04 - val_loss: 4.7988e-04
# Iteration: 7
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 0.0013 - val_loss: 8.2344e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.6563e-04 - val_loss: 5.8277e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.3245e-04 - val_loss: 6.4916e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.5347e-04 - val_loss: 5.3526e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.6213e-04 - val_loss: 5.2252e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4961e-04 - val_loss: 4.3082e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4983e-04 - val_loss: 4.3045e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3193e-04 - val_loss: 5.6144e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.6453e-04 - val_loss: 4.8277e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.9728e-04 - val_loss: 4.1492e-04
# Iteration: 8
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.8005e-04 - val_loss: 5.2000e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.2436e-04 - val_loss: 4.5866e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.9691e-04 - val_loss: 5.4983e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.5467e-04 - val_loss: 4.6636e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.5514e-04 - val_loss: 4.4835e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.7517e-04 - val_loss: 4.5334e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.1208e-04 - val_loss: 4.4458e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2941e-04 - val_loss: 4.1300e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.9365e-04 - val_loss: 4.4179e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.9022e-04 - val_loss: 4.0449e-04
# Iteration: 9
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 6.1527e-04 - val_loss: 5.3340e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.6837e-04 - val_loss: 4.7718e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.4326e-04 - val_loss: 4.4302e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.7410e-04 - val_loss: 4.3415e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.8656e-04 - val_loss: 4.4451e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4952e-04 - val_loss: 4.6266e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.1157e-04 - val_loss: 4.3961e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.5254e-04 - val_loss: 4.2429e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3463e-04 - val_loss: 5.0940e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2222e-04 - val_loss: 5.2652e-04
# Iteration: 10
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 6.7182e-04 - val_loss: 4.7267e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.4182e-04 - val_loss: 5.7173e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.9121e-04 - val_loss: 4.7423e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.9026e-04 - val_loss: 4.4267e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.7830e-04 - val_loss: 4.9572e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.6035e-04 - val_loss: 4.0356e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.5089e-04 - val_loss: 5.0732e-04
# Epoch 8/10
# 4638/4638 [==============================] - 13s 3ms/step - loss: 2.1259e-04 - val_loss: 5.2341e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2576e-04 - val_loss: 4.6048e-04
# Epoch 10/10
# 4638/4638 [==============================] - 13s 3ms/step - loss: 2.2175e-04 - val_loss: 4.1306e-04
# Iteration: 11
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.0579e-04 - val_loss: 4.7828e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.4915e-04 - val_loss: 4.2801e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.9284e-04 - val_loss: 5.0962e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.8334e-04 - val_loss: 4.5448e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.7935e-04 - val_loss: 4.3489e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3067e-04 - val_loss: 4.6492e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2921e-04 - val_loss: 4.1069e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3982e-04 - val_loss: 4.3447e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.1532e-04 - val_loss: 3.9705e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2879e-04 - val_loss: 4.4025e-04
# Iteration: 12
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 0.0010 - val_loss: 5.8894e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.6483e-04 - val_loss: 5.9419e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.9705e-04 - val_loss: 4.2326e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.5415e-04 - val_loss: 4.6386e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.5836e-04 - val_loss: 4.2805e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2749e-04 - val_loss: 4.4914e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2956e-04 - val_loss: 4.4923e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.5803e-04 - val_loss: 5.3357e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2388e-04 - val_loss: 4.5230e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2342e-04 - val_loss: 4.1513e-04
# Iteration: 13
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 9.3658e-04 - val_loss: 4.8929e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.0907e-04 - val_loss: 5.6381e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.3196e-04 - val_loss: 4.5971e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.0372e-04 - val_loss: 4.1185e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3119e-04 - val_loss: 4.2101e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3723e-04 - val_loss: 4.5543e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4689e-04 - val_loss: 4.8525e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.0436e-04 - val_loss: 4.0181e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2486e-04 - val_loss: 4.2796e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.1083e-04 - val_loss: 4.0688e-04
# Iteration: 14
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 7.1786e-04 - val_loss: 6.1699e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.6215e-04 - val_loss: 5.0692e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.9779e-04 - val_loss: 4.7627e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.7108e-04 - val_loss: 4.3438e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.7433e-04 - val_loss: 4.1259e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.6231e-04 - val_loss: 4.6204e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3188e-04 - val_loss: 4.6574e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4079e-04 - val_loss: 3.8949e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.1560e-04 - val_loss: 4.5160e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.1299e-04 - val_loss: 4.4800e-04
# Iteration: 15
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 7.8563e-04 - val_loss: 9.5945e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.9231e-04 - val_loss: 4.9350e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.9505e-04 - val_loss: 4.7748e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.1887e-04 - val_loss: 4.8637e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.6302e-04 - val_loss: 4.6610e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4768e-04 - val_loss: 4.9309e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3962e-04 - val_loss: 4.4521e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.1412e-04 - val_loss: 4.8236e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.9765e-04 - val_loss: 4.3467e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2936e-04 - val_loss: 5.0804e-04
# Iteration: 16
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 9.1204e-04 - val_loss: 6.1523e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.4713e-04 - val_loss: 4.9599e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.2340e-04 - val_loss: 4.1749e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.7403e-04 - val_loss: 4.2598e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4346e-04 - val_loss: 4.4699e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4192e-04 - val_loss: 4.2865e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2640e-04 - val_loss: 4.2094e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2699e-04 - val_loss: 4.2106e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.0911e-04 - val_loss: 4.3250e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.0954e-04 - val_loss: 4.2604e-04
# Iteration: 17
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.6513e-04 - val_loss: 7.9813e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.7144e-04 - val_loss: 4.4026e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.0309e-04 - val_loss: 5.0928e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.6860e-04 - val_loss: 4.5557e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.7982e-04 - val_loss: 4.7377e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.5217e-04 - val_loss: 4.4653e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4571e-04 - val_loss: 4.2649e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3046e-04 - val_loss: 4.0481e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2360e-04 - val_loss: 4.8563e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3416e-04 - val_loss: 4.4552e-04
# Iteration: 18
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 0.0011 - val_loss: 4.2048e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.3665e-04 - val_loss: 4.7933e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.1743e-04 - val_loss: 4.3308e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.9104e-04 - val_loss: 4.2696e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.6302e-04 - val_loss: 4.5711e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4281e-04 - val_loss: 5.2721e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4544e-04 - val_loss: 4.7263e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.0675e-04 - val_loss: 4.1566e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.1321e-04 - val_loss: 4.2981e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3318e-04 - val_loss: 4.0836e-04
# Iteration: 19
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 7.6114e-04 - val_loss: 7.3885e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.7044e-04 - val_loss: 4.9640e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.1482e-04 - val_loss: 4.2066e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.8593e-04 - val_loss: 4.5561e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.5039e-04 - val_loss: 4.5413e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4344e-04 - val_loss: 4.1820e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3317e-04 - val_loss: 5.7134e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4159e-04 - val_loss: 4.2486e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.1685e-04 - val_loss: 4.3227e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.1807e-04 - val_loss: 4.3515e-04
# Iteration: 20
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 0.0015 - val_loss: 5.5652e-04
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.3792e-04 - val_loss: 4.3829e-04
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.8280e-04 - val_loss: 4.6894e-04
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.0184e-04 - val_loss: 5.0398e-04
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4302e-04 - val_loss: 4.2321e-04
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4750e-04 - val_loss: 4.4301e-04
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.3029e-04 - val_loss: 6.6284e-04
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2175e-04 - val_loss: 4.2517e-04
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.4674e-04 - val_loss: 4.1290e-04
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.1015e-04 - val_loss: 4.2114e-04
# --------------------------
#
# Starting time: 1613015359.2224522
# Completing time: 1613018158.8120782
# It took -46.65982710123062 minutes to train the model for 20 iterations

# %%
model.save("cnn_model2_2_features_pred_tem_all_pred.hdf5")

# %%
def plot_evaluation():
    #mean square error over iterations
    plt.figure(figsize=(15, 10))
    plt.plot(mse_for_iter1)
    plt.ylabel('mean squared error')
    plt.xlabel('iteration')
    plt.savefig('mse.png', bbox_inches='tight')
    plt.show()
        
    #plot train and validation loss over epochs for each iteration
    fig, axs = plt.subplots(10, 2)
    #axs.set_ylabel('loss')
    #axs.set_xlabel('epoch')
    fig.set_size_inches(18.5, 50)
    for row in range(10):
        for col in range(2):
            index = 2*row + col #index to get loss from training loss and validation loss list
            axs[row, col].plot(train_loss_over_epoch1[index])
            axs[row, col].plot(val_loss_over_epoch1[index])
            axs[row, col].set_title('Iteration(%d)' %(index+1))
            axs[row, col].legend(['train', 'Val'], loc='upper left')            
    plt.savefig('train_val_loss.png', bbox_inches='tight')
    
    #plot predicted value vs actual values from last iteration
    plt.figure(figsize=(15, 10))
    plt.plot(predicted_y_values1_unnor, 'ro', alpha=0.8)
    plt.plot(Y_test_actual, 'bo', alpha=0.1)
    plt.legend(['Predicted values', 'Actual values'], loc='upper right')
    plt.ylabel('Outflow')
    plt.xlabel('nth datapoint')
    plt.savefig('predicted_values_visuals.png', bbox_inches='tight')
    plt.show()
    
#call plot_evaluation function
plot_evaluation()

# %%
mse_for_iter1
# Out:
# [2014.4375961612939,
#  1593.440113928321,
#  1425.7237730565769,
#  1495.2072809488434,
#  1691.8927539833417,
#  1702.905052811257,
#  1564.0964282630493,
#  1522.172422706373,
#  1984.5826443795543,
#  1543.6948639281472,
#  1702.0334357108345,
#  1562.5739577236009,
#  1559.9596208268774,
#  1695.606539296367,
#  1951.852183515913,
#  1559.0835607547199,
#  1727.2094693720553,
#  1546.970750617127,
#  1626.4471243273006,
#  1575.6173564558774]

# %%
print(np.mean(mse_for_iter1))
# Out:
# 1652.2753464383713

# %%
plot_model(model1, show_shapes=True)

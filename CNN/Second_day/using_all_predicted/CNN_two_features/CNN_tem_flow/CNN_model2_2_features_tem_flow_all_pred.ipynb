# %%
#import modules
import numpy as np
import pandas as pd
import time
from keras import backend as K 
from keras.engine.training import Model
from keras.utils import to_categorical, plot_model
from keras.models import Sequential, load_model
from sklearn.preprocessing import MinMaxScaler
from keras.layers.convolutional import Conv1D, Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers import Dropout, Activation, Flatten
from keras.layers import LSTM, Dense, Input
from keras.optimizers import SGD
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tqdm import tqdm_notebook
from sklearn.metrics import mean_squared_error

# %%
#import data
df = pd.read_csv('./Sub0-RAW.csv')
df.head()
# Out:
#        Dates  Year  Month  Day    Hours  Precipitation  Temperature  Outflow
# 0  10/1/1980  1980     10    1  0:00:00            0.0      102.992      5.0
# 1  10/1/1980  1980     10    1  1:00:00            0.0       97.790      5.0
# 2  10/1/1980  1980     10    1  2:00:00            0.0       92.588      5.0
# 3  10/1/1980  1980     10    1  3:00:00            0.0       87.404      5.0
# 4  10/1/1980  1980     10    1  4:00:00            0.0       85.172      5.0

# %%
#define train and label column
train_cols = ["Precipitation","Temperature", "Outflow"]
label_cols = ["Temperature(t+1)","Outflow(t+1)"]

# %%
#filter the columns
new_df = df.filter(train_cols, axis=1)

# %%
#Min Max scalr normalizing
xtrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
xtest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))

# %%
#function to shift the time_series data for getting labels
def lag_seq(df, n_seq):
    for i in range(n_seq):
        #df['Precipitation(t+%d)' %(i+1)] = new_df['Precipitation'].shift(-(i+1))
        df['Temperature(t+%d)' %(i+1)] = new_df['Temperature'].shift(-(i+1))        
        df['Outflow(t+%d)' %(i+1)] = new_df['Outflow'].shift(-(i+1))
    return df

# building timeseries data with given timesteps
def timeseries(X, Y, Y_actual, time_steps, out_steps):
    input_size_0 = X.shape[0] - time_steps
    input_size_1 = X.shape[1]
    output_size_0 = Y.shape[0] - time_steps
    output_size_1 = Y.shape[1]
    X_values = np.zeros((input_size_0, time_steps, input_size_1))
    Y_values = np.zeros((output_size_0, output_size_1))
    Y_values_actual = np.zeros((output_size_0, output_size_1))
    
    for i in tqdm_notebook(range(input_size_0)):
        X_values[i] = X[i:time_steps+i]
        Y_values[i] = Y[time_steps+i-1]
        Y_values_actual[i] = Y_actual[time_steps+i-1]
        
    print("length of time-series i/o",X_values.shape,Y_values.shape)
    return X_values, Y_values, Y_values_actual

#getting data ready for training the model
def data_processing(lag_df):
    #Splitting training and test data
    df_train, df_test = train_test_split(lag_df, train_size=0.8, test_size=0.2, shuffle=False)
    x_train = df_train.loc[:,train_cols].values
    y_train = df_train.loc[:,label_cols].values
    x_test = df_test.loc[:,train_cols].values
    y_test = df_test.loc[:,label_cols].values    
   
    #Normalizing training data
    x_train_nor = xtrain_min_max_scaler.fit_transform(x_train)
    y_train_nor = ytrain_min_max_scaler.fit_transform(y_train)

    # Normalizing test data
    x_test_nor = xtest_min_max_scaler.fit_transform(x_test)
    y_test_nor = ytest_min_max_scaler.fit_transform(y_test)
    
    # Saving actual train and test y_label
    y_train_actual = y_train
    y_test_actual = y_test
    
    return x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual

# %%
#calling function to create lag dataframe
lag_df = lag_seq(new_df, 2)
lag_df.dropna(inplace=True)

# %%
lag_df
# Out:
#         Precipitation  Temperature  ...  Temperature(t+2)  Outflow(t+2)
# 0                 0.0      102.992  ...            92.588           5.0
# 1                 0.0       97.790  ...            87.404           5.0
# 2                 0.0       92.588  ...            85.172           5.0
# 3                 0.0       87.404  ...            82.940           5.0
# 4                 0.0       85.172  ...            80.708           5.0
# ...               ...          ...  ...               ...           ...
# 185537            0.0       50.054  ...            54.284          30.0
# 185538            0.0       52.880  ...            55.670          29.0
# 185539            0.0       54.284  ...            57.074          29.0
# 185540            0.0       55.670  ...            57.056          31.0
# 185541            0.0       57.074  ...            57.020          38.0
#
# [185542 rows x 7 columns]

# %%
#Building timeseries
x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual = data_processing(lag_df)
X_Train, Y_Train, Y_train_actual = timeseries(x_train_nor, y_train_nor, y_train_actual, time_steps=18, out_steps=1)
X_Test, Y_Test, Y_test_actual = timeseries(x_test_nor, y_test_nor, y_test_actual, time_steps=18, out_steps=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=148415.0), HTML(value='')))
# length of time-series i/o (148415, 18, 3) (148415, 2)
# HBox(children=(FloatProgress(value=0.0, max=37091.0), HTML(value='')))
# length of time-series i/o (37091, 18, 3) (37091, 2)

# %%
#Build Model
def make_model(X_Train):
    input_layer = Input(shape=(X_Train.shape[1], X_Train.shape[2]))

    conv1 = Conv1D(filters=16, kernel_size=3, strides=1,
                    padding='same',activation='relu')(input_layer)
    conv2 = Conv1D(filters=32, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv1)
    conv3 = Conv1D(filters=64, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv2)

    flatten = Flatten()(conv3)

    dense1 = Dense(1152, activation='relu')(flatten)
    dense2 = Dense(576, activation='relu')(dense1)
    output_layer = Dense(2, activation='linear')(dense2)
    
    return Model(inputs=input_layer, outputs=output_layer)

# %%
mse_for_iter = []
train_loss_over_epoch = []
val_loss_over_epoch = []

def run_iteration(no_iter=20, epochs = 10):
    start_time = time.time()
    for iteration in range(no_iter):
        print(f'Iteration: {iteration + 1}')
        K.clear_session()
        model = make_model(X_Train)
        #plot_model(model, show_shapes=True)
        model.compile(optimizer = 'adam', loss = 'mean_squared_error')
        history = model.fit(X_Train, Y_Train, epochs=epochs,
                       validation_data=(X_Test, Y_Test))
        train_loss_over_epoch.append(history.history['loss'])
        val_loss_over_epoch.append(history.history['val_loss'])
        predicted_y_values = model.predict(X_Test)
        predicted_y_values_unnor = ytrain_min_max_scaler.inverse_transform(predicted_y_values)
        mse_for_iter.append(mean_squared_error(predicted_y_values_unnor, Y_test_actual))
               
    end_time = time.time()
    print('--------------------------\n')
    print(f'Starting time: {start_time}')
    print(f'Completing time: {end_time}')
    print(f'It took {(start_time - end_time)/60} minutes to train the model for {no_iter} iterations')
    #return predicted unnormalized values for test set from last iteration 
    return predicted_y_values, predicted_y_values_unnor, model

predicted_y_values, predicted_y_values_unnor, model = run_iteration(1,10)
# Out:
# Iteration: 1
# Epoch 1/10
# 4638/4638 [==============================] - 23s 3ms/step - loss: 6.6686e-04 - val_loss: 3.9658e-05
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 4.3843e-05 - val_loss: 4.4343e-05
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.6444e-05 - val_loss: 2.3310e-05
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2442e-05 - val_loss: 2.6442e-05
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.9360e-05 - val_loss: 1.5975e-05
# Epoch 6/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.7518e-05 - val_loss: 1.8654e-05
# Epoch 7/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.7916e-05 - val_loss: 2.5686e-05
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.5889e-05 - val_loss: 2.5518e-05
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.4200e-05 - val_loss: 1.4741e-05
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.4520e-05 - val_loss: 1.7251e-05
# --------------------------
#
# Starting time: 1613011298.5867887
# Completing time: 1613011457.2207499
# It took -2.643899353345235 minutes to train the model for 1 iterations

# %%
#prediction for X_Train values which has to be used to predict another day output
y_train_predict = model.predict(X_Train)

# %%
#define train and label column for day 2
train_cols = ["Temperature","Outflow"]
label_cols = ["Outflow(t+2)"]

# %%
#Building timeseries for day 2
time_steps = 18
x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual = data_processing(lag_df)
X_Train, Y_Train, Y_train_actual = timeseries(x_train_nor, y_train_nor, y_train_actual, time_steps=18, out_steps=1)
X_Test, Y_Test, Y_test_actual = timeseries(x_test_nor, y_test_nor, y_test_actual, time_steps=18, out_steps=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=148415.0), HTML(value='')))
# length of time-series i/o (148415, 18, 2) (148415, 1)
# HBox(children=(FloatProgress(value=0.0, max=37091.0), HTML(value='')))
# length of time-series i/o (37091, 18, 2) (37091, 1)

# %%
#preparing timeseries for day2 data
train_input_size_0 = X_Train.shape[0]
test_input_size_0 = X_Test.shape[0]
input_size_2 = X_Train.shape[2]
output_size_0 = Y_Train.shape[0]
output_size_1 = Y_Train.shape[1]
X_Train1 = np.zeros((train_input_size_0, time_steps+1, input_size_2))
X_Test1 = np.zeros((test_input_size_0, time_steps+1, input_size_2))

#replacing last value of each timeseries data with the predicted value
len_data = len(X_Train1)
for i in range (len_data):
    #reshaping y_train_predict to make both values under concatenation of same shape 
    X_Train1[i] = np.concatenate((X_Train[i], y_train_predict[i].reshape(1,2)), axis=0) 
len_data_test = len(X_Test)
for i in range (len_data_test):
    X_Test1[i] = np.concatenate((X_Test[i],predicted_y_values[i].reshape(1,2)), axis=0)

# %%
#Build Model for day 2
def make_model1(X_Train):
    input_layer = Input(shape=(X_Train.shape[1], X_Train.shape[2]))

    conv1 = Conv1D(filters=16, kernel_size=3, strides=1,
                    padding='same',activation='relu')(input_layer)
    conv2 = Conv1D(filters=32, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv1)
    conv3 = Conv1D(filters=64, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv2)

    flatten = Flatten()(conv3)

    dense1 = Dense(1152, activation='relu')(flatten)
    dense2 = Dense(576, activation='relu')(dense1)
    output_layer = Dense(1, activation='linear')(dense2)
    
    return Model(inputs=input_layer, outputs=output_layer)

# %%
mse_for_iter1 = []
train_loss_over_epoch1 = []
val_loss_over_epoch1 = []
predicted_y_values1_unnors = []
models = []

def run_iteration_model_2(no_iter=20, epochs = 10):
    start_time = time.time()
    for iteration in range(no_iter):
        print(f'Iteration: {iteration + 1}')
        K.clear_session()
        model1 = make_model1(X_Train1)
        #plot_model(model, show_shapes=True)
        model1.compile(optimizer = 'adam', loss = 'mean_squared_error')
        history = model1.fit(X_Train1, Y_Train, epochs=epochs,
                       validation_data=(X_Test1, Y_Test))
        train_loss_over_epoch1.append(history.history['loss'])
        val_loss_over_epoch1.append(history.history['val_loss'])
        predicted_y_values1 = model1.predict(X_Test1)
        predicted_y_values1_unnor = ytrain_min_max_scaler.inverse_transform(predicted_y_values1)
        mse_for_iter1.append(mean_squared_error(predicted_y_values1_unnor, Y_test_actual))
        predicted_y_values1_unnors.append(predicted_y_values1_unnor)
        models.append(model1)
               
    end_time = time.time()
    print('--------------------------\n')
    print(f'Starting time: {start_time}')
    print(f'Completing time: {end_time}')
    print(f'It took {(start_time - end_time)/60} minutes to train the model for {no_iter} iterations')
    #return predicted unnormalized values for test set from last iteration 
    return predicted_y_values1, predicted_y_values1_unnor, model1

predicted_y_values1, predicted_y_values1_unnor, model1 = run_iteration_model_2(20,10)
# Out:
# Iteration: 1
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 0.0017 - val_loss: 2.1885e-05
# Epoch 2/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 2.2647e-05 - val_loss: 1.5733e-05
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.3588e-05 - val_loss: 1.0259e-05
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.1532e-05 - val_loss: 1.4772e-05
# Epoch 5/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 9.2752e-06 - val_loss: 1.0350e-05
# Epoch 6/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 9.8353e-06 - val_loss: 1.8832e-05
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.9951e-06 - val_loss: 3.4423e-05
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 7.5605e-06 - val_loss: 8.9184e-06
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 7.5920e-06 - val_loss: 8.5995e-06
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 6.8811e-06 - val_loss: 7.5711e-06
# Iteration: 2
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 2.3067e-04 - val_loss: 1.4292e-05
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.7260e-05 - val_loss: 4.1253e-05
# Epoch 3/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.5608e-05 - val_loss: 1.7995e-05
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.2909e-05 - val_loss: 1.0873e-05
# Epoch 5/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.2216e-05 - val_loss: 1.3294e-05
# Epoch 6/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 8.5241e-06 - val_loss: 1.2260e-05
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 9.2823e-06 - val_loss: 1.1755e-05
# Epoch 8/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 7.2251e-06 - val_loss: 8.9380e-06
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.5527e-06 - val_loss: 7.5291e-06
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 7.6152e-06 - val_loss: 9.0445e-06
# Iteration: 3
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 7.5596e-04 - val_loss: 4.4537e-05
# Epoch 2/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 4.1225e-05 - val_loss: 2.9618e-05
# Epoch 3/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 2.9307e-05 - val_loss: 1.8922e-05
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.1918e-05 - val_loss: 2.0279e-05
# Epoch 5/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.3383e-05 - val_loss: 2.0296e-05
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.0584e-05 - val_loss: 1.0340e-05
# Epoch 7/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 8.2897e-06 - val_loss: 1.1317e-05
# Epoch 8/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.1405e-05 - val_loss: 1.4357e-05
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 9.1742e-06 - val_loss: 1.0545e-05
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 5.8788e-06 - val_loss: 1.2532e-05
# Iteration: 4
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 8.5323e-04 - val_loss: 6.8746e-05
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 3.5004e-05 - val_loss: 1.7576e-05
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.3103e-05 - val_loss: 1.6490e-05
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.8638e-05 - val_loss: 1.4161e-05
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.2154e-05 - val_loss: 1.3586e-05
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.1043e-05 - val_loss: 1.3755e-05
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.2716e-06 - val_loss: 1.5517e-05
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 9.3345e-06 - val_loss: 9.7196e-06
# Epoch 9/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 6.9847e-06 - val_loss: 1.0897e-05
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 6.9901e-06 - val_loss: 9.0043e-06
# Iteration: 5
# Epoch 1/10
# 4638/4638 [==============================] - 16s 3ms/step - loss: 4.2352e-04 - val_loss: 2.9603e-05
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 5.0856e-05 - val_loss: 3.7159e-05
# Epoch 3/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 2.3312e-05 - val_loss: 1.4934e-05
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.0610e-05 - val_loss: 1.3917e-05
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.4486e-05 - val_loss: 3.2154e-05
# Epoch 6/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.1291e-05 - val_loss: 2.3328e-05
# Epoch 7/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 9.1369e-06 - val_loss: 1.0751e-05
# Epoch 8/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 7.5379e-06 - val_loss: 1.4103e-05
# Epoch 9/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 5.8256e-06 - val_loss: 2.4184e-05
# Epoch 10/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 6.1695e-06 - val_loss: 1.1769e-05
# Iteration: 6
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 0.0023 - val_loss: 2.3076e-05
# Epoch 2/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 2.2371e-05 - val_loss: 3.0985e-05
# Epoch 3/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.8539e-05 - val_loss: 1.3845e-05
# Epoch 4/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.2100e-05 - val_loss: 1.1343e-05
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 9.5329e-06 - val_loss: 1.2240e-05
# Epoch 6/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.2893e-05 - val_loss: 8.8391e-06
# Epoch 7/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 8.4483e-06 - val_loss: 9.7461e-06
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 6.5192e-06 - val_loss: 1.4355e-05
# Epoch 9/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 6.6927e-06 - val_loss: 1.2727e-05
# Epoch 10/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 6.2202e-06 - val_loss: 8.7369e-06
# Iteration: 7
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 2.4334e-04 - val_loss: 2.9728e-05
# Epoch 2/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 2.6031e-05 - val_loss: 5.0816e-05
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.5381e-05 - val_loss: 6.5933e-05
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.4362e-05 - val_loss: 2.0998e-05
# Epoch 5/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.5104e-05 - val_loss: 2.9201e-05
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.0134e-05 - val_loss: 9.6813e-06
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 7.4580e-06 - val_loss: 9.8324e-06
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 9.0804e-06 - val_loss: 1.1513e-05
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 6.5513e-06 - val_loss: 7.9054e-06
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 5.5748e-06 - val_loss: 8.1307e-06
# Iteration: 8
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 4.1604e-04 - val_loss: 3.5820e-05
# Epoch 2/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.8049e-05 - val_loss: 1.4810e-05
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.2875e-05 - val_loss: 1.9475e-05
# Epoch 4/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.0567e-05 - val_loss: 1.4136e-05
# Epoch 5/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.0976e-05 - val_loss: 1.0396e-05
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 9.4224e-06 - val_loss: 9.8694e-06
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.4125e-06 - val_loss: 1.4254e-05
# Epoch 8/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 7.1105e-06 - val_loss: 9.7607e-06
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 7.3834e-06 - val_loss: 9.1720e-06
# Epoch 10/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 6.3563e-06 - val_loss: 9.3442e-06
# Iteration: 9
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 5.1978e-04 - val_loss: 2.1767e-05
# Epoch 2/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 5.5469e-05 - val_loss: 4.2157e-05
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.7175e-05 - val_loss: 2.3320e-05
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.8829e-05 - val_loss: 1.4767e-05
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.2434e-05 - val_loss: 1.4281e-05
# Epoch 6/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 8.5537e-06 - val_loss: 1.0378e-05
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 7.6403e-06 - val_loss: 1.1634e-05
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.3793e-06 - val_loss: 1.2888e-05
# Epoch 9/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 6.8315e-06 - val_loss: 1.3352e-05
# Epoch 10/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 6.4517e-06 - val_loss: 9.6089e-06
# Iteration: 10
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 3.4702e-04 - val_loss: 3.1934e-05
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 2.2159e-05 - val_loss: 2.3942e-05
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.3476e-05 - val_loss: 1.7171e-05
# Epoch 4/10
# 4638/4638 [==============================] - 13s 3ms/step - loss: 1.3850e-05 - val_loss: 4.0313e-05
# Epoch 5/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.2527e-05 - val_loss: 1.6300e-05
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.0246e-05 - val_loss: 1.4508e-05
# Epoch 7/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.1765e-05 - val_loss: 1.4126e-05
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.0172e-05 - val_loss: 1.1191e-05
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 7.7469e-06 - val_loss: 1.4313e-05
# Epoch 10/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 7.5028e-06 - val_loss: 6.9395e-05
# Iteration: 11
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 3.6487e-04 - val_loss: 2.2346e-05
# Epoch 2/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.6381e-05 - val_loss: 1.7162e-05
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.7501e-05 - val_loss: 1.1963e-05
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.3745e-05 - val_loss: 1.3015e-05
# Epoch 5/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.0072e-05 - val_loss: 1.8692e-05
# Epoch 6/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.0697e-05 - val_loss: 1.2318e-05
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.6714e-05 - val_loss: 9.1256e-06
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 9.2543e-06 - val_loss: 2.1606e-05
# Epoch 9/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 8.8865e-06 - val_loss: 5.6693e-05
# Epoch 10/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 9.2864e-06 - val_loss: 9.6380e-06
# Iteration: 12
# Epoch 1/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 6.9061e-04 - val_loss: 3.5209e-05
# Epoch 2/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 2.5702e-05 - val_loss: 2.4970e-05
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.8791e-05 - val_loss: 2.1497e-05
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.7691e-05 - val_loss: 1.8123e-05
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 9.0331e-06 - val_loss: 1.0730e-05
# Epoch 6/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.2096e-06 - val_loss: 1.2964e-05
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 9.8634e-06 - val_loss: 1.1050e-05
# Epoch 8/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 9.7027e-06 - val_loss: 1.1769e-05
# Epoch 9/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 7.9487e-06 - val_loss: 1.3051e-05
# Epoch 10/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 7.1978e-06 - val_loss: 1.2187e-05
# Iteration: 13
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 3.1323e-04 - val_loss: 3.4594e-05
# Epoch 2/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.8676e-05 - val_loss: 6.5679e-05
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.5164e-05 - val_loss: 2.7499e-05
# Epoch 4/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.0139e-05 - val_loss: 3.0668e-05
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.0718e-05 - val_loss: 1.3307e-05
# Epoch 6/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.0391e-05 - val_loss: 1.2165e-05
# Epoch 7/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.0438e-06 - val_loss: 1.4537e-05
# Epoch 8/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 9.9227e-06 - val_loss: 1.7567e-05
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 7.2967e-06 - val_loss: 1.3269e-05
# Epoch 10/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 8.0322e-06 - val_loss: 1.0568e-05
# Iteration: 14
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 3.8674e-04 - val_loss: 1.5639e-04
# Epoch 2/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 3.8902e-05 - val_loss: 2.2837e-05
# Epoch 3/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.7084e-05 - val_loss: 1.2129e-05
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.3509e-05 - val_loss: 1.1563e-05
# Epoch 5/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.1489e-05 - val_loss: 1.2804e-05
# Epoch 6/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.0568e-05 - val_loss: 9.8536e-06
# Epoch 7/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 8.4269e-06 - val_loss: 9.4448e-06
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.1274e-06 - val_loss: 9.3746e-06
# Epoch 9/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 6.0311e-06 - val_loss: 1.1528e-05
# Epoch 10/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 7.7717e-06 - val_loss: 1.2755e-05
# Iteration: 15
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 2.0724e-04 - val_loss: 2.5019e-05
# Epoch 2/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 2.4074e-05 - val_loss: 1.6711e-05
# Epoch 3/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.5920e-05 - val_loss: 1.6045e-05
# Epoch 4/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.1801e-05 - val_loss: 1.6784e-05
# Epoch 5/10
# 4638/4638 [==============================] - 16s 3ms/step - loss: 9.5722e-06 - val_loss: 1.1262e-05
# Epoch 6/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.0775e-05 - val_loss: 1.5648e-05
# Epoch 7/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 9.1201e-06 - val_loss: 1.2640e-05
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 9.7113e-06 - val_loss: 1.3344e-05
# Epoch 9/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 6.5803e-06 - val_loss: 1.0861e-05
# Epoch 10/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.0732e-05 - val_loss: 9.8568e-06
# Iteration: 16
# Epoch 1/10
# 4638/4638 [==============================] - 16s 3ms/step - loss: 4.8603e-04 - val_loss: 3.0813e-05
# Epoch 2/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 2.9728e-05 - val_loss: 1.8586e-05
# Epoch 3/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.7954e-05 - val_loss: 2.5216e-05
# Epoch 4/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.4815e-05 - val_loss: 2.2932e-05
# Epoch 5/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.0999e-05 - val_loss: 1.6035e-05
# Epoch 6/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.0032e-05 - val_loss: 1.3463e-05
# Epoch 7/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.0060e-05 - val_loss: 3.3166e-05
# Epoch 8/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 7.6741e-06 - val_loss: 1.0744e-05
# Epoch 9/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 7.2938e-06 - val_loss: 1.0959e-05
# Epoch 10/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 6.5615e-06 - val_loss: 1.2490e-05
# Iteration: 17
# Epoch 1/10
# 4638/4638 [==============================] - 16s 3ms/step - loss: 3.3712e-04 - val_loss: 1.8770e-05
# Epoch 2/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 3.9038e-05 - val_loss: 4.1940e-05
# Epoch 3/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 1.8540e-05 - val_loss: 2.1697e-05
# Epoch 4/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.2630e-05 - val_loss: 1.9325e-05
# Epoch 5/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.3196e-05 - val_loss: 1.9488e-05
# Epoch 6/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.0750e-05 - val_loss: 1.8249e-05
# Epoch 7/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.0753e-05 - val_loss: 1.9302e-05
# Epoch 8/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.2333e-05 - val_loss: 2.5019e-05
# Epoch 9/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 8.4747e-06 - val_loss: 2.7633e-05
# Epoch 10/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 9.1324e-06 - val_loss: 1.5931e-05
# Iteration: 18
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 9.0075e-04 - val_loss: 4.9980e-05
# Epoch 2/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 2.1725e-05 - val_loss: 2.2682e-05
# Epoch 3/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.7446e-05 - val_loss: 1.1855e-05
# Epoch 4/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.1820e-05 - val_loss: 1.2016e-05
# Epoch 5/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.1632e-05 - val_loss: 1.6684e-05
# Epoch 6/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 9.7840e-06 - val_loss: 1.2212e-05
# Epoch 7/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 6.7669e-06 - val_loss: 8.6044e-06
# Epoch 8/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 7.1912e-06 - val_loss: 8.2241e-06
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 6.9806e-06 - val_loss: 7.8944e-06
# Epoch 10/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 7.4467e-06 - val_loss: 9.3339e-06
# Iteration: 19
# Epoch 1/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 4.4845e-04 - val_loss: 7.7175e-05
# Epoch 2/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 3.0864e-05 - val_loss: 3.0182e-05
# Epoch 3/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.7720e-05 - val_loss: 1.4401e-05
# Epoch 4/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.0251e-05 - val_loss: 1.5704e-05
# Epoch 5/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.1536e-05 - val_loss: 1.1668e-05
# Epoch 6/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 8.3712e-06 - val_loss: 1.3030e-05
# Epoch 7/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 7.1204e-06 - val_loss: 9.4597e-06
# Epoch 8/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 6.2894e-06 - val_loss: 8.9439e-06
# Epoch 9/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 6.9076e-06 - val_loss: 9.7947e-06
# Epoch 10/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 6.2305e-06 - val_loss: 2.9123e-05
# Iteration: 20
# Epoch 1/10
# 4638/4638 [==============================] - 17s 3ms/step - loss: 2.1818e-04 - val_loss: 2.0883e-05
# Epoch 2/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 4.5257e-05 - val_loss: 2.3604e-05
# Epoch 3/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 2.2411e-05 - val_loss: 3.3339e-05
# Epoch 4/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.6966e-05 - val_loss: 1.6762e-05
# Epoch 5/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.5177e-05 - val_loss: 1.1028e-05
# Epoch 6/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 1.2138e-05 - val_loss: 1.4724e-05
# Epoch 7/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 8.7324e-06 - val_loss: 1.7947e-05
# Epoch 8/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 8.1050e-06 - val_loss: 1.1783e-05
# Epoch 9/10
# 4638/4638 [==============================] - 14s 3ms/step - loss: 8.7847e-06 - val_loss: 1.3404e-05
# Epoch 10/10
# 4638/4638 [==============================] - 15s 3ms/step - loss: 7.6994e-06 - val_loss: 1.4235e-05
# --------------------------
#
# Starting time: 1613011462.9188213
# Completing time: 1613014422.0613234
# It took -49.319041701157886 minutes to train the model for 20 iterations

# %%
model.save("cnn_model2_2_features_tem_flow_all_pred.hdf5")

# %%
def plot_evaluation():
    #mean square error over iterations
    plt.figure(figsize=(15, 10))
    plt.plot(mse_for_iter1)
    plt.ylabel('mean squared error')
    plt.xlabel('iteration')
    plt.savefig('mse.png', bbox_inches='tight')
    plt.show()
        
    #plot train and validation loss over epochs for each iteration
    fig, axs = plt.subplots(10, 2)
    #axs.set_ylabel('loss')
    #axs.set_xlabel('epoch')
    fig.set_size_inches(18.5, 50)
    for row in range(10):
        for col in range(2):
            index = 2*row + col #index to get loss from training loss and validation loss list
            axs[row, col].plot(train_loss_over_epoch1[index])
            axs[row, col].plot(val_loss_over_epoch1[index])
            axs[row, col].set_title('Iteration(%d)' %(index+1))
            axs[row, col].legend(['train', 'Val'], loc='upper left')            
    plt.savefig('train_val_loss.png', bbox_inches='tight')
    
    #plot predicted value vs actual values from last iteration
    plt.figure(figsize=(15, 10))
    plt.plot(predicted_y_values1_unnor, 'ro', alpha=0.8)
    plt.plot(Y_test_actual, 'bo', alpha=0.1)
    plt.legend(['Predicted values', 'Actual values'], loc='upper right')
    plt.ylabel('Outflow')
    plt.xlabel('nth datapoint')
    plt.savefig('predicted_values_visuals.png', bbox_inches='tight')
    plt.show()
    
#call plot_evaluation function
plot_evaluation()

# %%
mse_for_iter1
# Out:
# [55.01471920179446,
#  60.47789674191484,
#  90.47818328756021,
#  36.26784826034999,
#  79.05314311268116,
#  55.40580382564175,
#  59.17652403844486,
#  59.94374483017826,
#  47.299352406845664,
#  171.49685109464716,
#  66.03449795209103,
#  85.00162190982458,
#  69.04057497147154,
#  31.93552721003439,
#  58.641573383566055,
#  94.6519681380807,
#  106.76983362822874,
#  53.31967564252876,
#  176.8062676569227,
#  93.52323706078198]

# %%
print(np.mean(mse_for_iter1))
# Out:
# 77.51694221767943

# %%
plot_model(model1, show_shapes=True)

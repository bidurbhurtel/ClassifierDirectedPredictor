# %%
#import modules
import numpy as np
import pandas as pd
import time
from keras import backend as K 
from keras.engine.training import Model
from keras.utils import to_categorical, plot_model
from keras.models import Sequential, load_model
from sklearn.preprocessing import MinMaxScaler
from keras.layers.convolutional import Conv1D, Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers import Dropout, Activation, Flatten
from keras.layers import LSTM, Dense, Input
from keras.optimizers import SGD
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tqdm import tqdm_notebook
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('../Sub0-RAW.csv')
df.head()
# Out:
#        Dates  Year  Month  Day    Hours  Precipitation  Temperature  Outflow
# 0  10/1/1980  1980     10    1  0:00:00            0.0      102.992      5.0
# 1  10/1/1980  1980     10    1  1:00:00            0.0       97.790      5.0
# 2  10/1/1980  1980     10    1  2:00:00            0.0       92.588      5.0
# 3  10/1/1980  1980     10    1  3:00:00            0.0       87.404      5.0
# 4  10/1/1980  1980     10    1  4:00:00            0.0       85.172      5.0

# %%
train_cols = ["Precipitation","Temperature","Outflow"]
label_cols = ["Outflow(t+1)"]

# %%
new_df = df.filter(train_cols, axis=1)

# %%
#Min Max scalr normalizing
xtrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
xtest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))

# %%
#function to shift the time_series data for getting labels
def lag_seq(df, n_seq):
    for i in range(n_seq):
        df['Outflow(t+%d)' %(i+1)] = new_df['Outflow'].shift(-(i+1))
    return df

# building timeseries data with given timesteps
def timeseries(X, Y, Y_actual, time_steps, out_steps):
    input_size_0 = X.shape[0] - time_steps
    input_size_1 = X.shape[1]
    X_values = np.zeros((input_size_0, time_steps, input_size_1))
    Y_values = np.zeros((input_size_0,))
    Y_values_actual = np.zeros((input_size_0,))
    
    for i in tqdm_notebook(range(input_size_0)):
        X_values[i] = X[i:time_steps+i]
        Y_values[i] = Y[time_steps+i-1, 0]
        Y_values_actual[i] = Y_actual[time_steps+i-1, 0]
        
    print("length of time-series i/o",X_values.shape,Y_values.shape)
    return X_values, Y_values, Y_values_actual

#getting data ready for training the model
def data_processing(lag_df):
    #Splitting training and test data
    df_train, df_test = train_test_split(lag_df, train_size=0.8, test_size=0.2, shuffle=False)
    x_train = df_train.loc[:,train_cols].values
    y_train = df_train.loc[:,label_cols].values
    x_test = df_test.loc[:,train_cols].values
    y_test = df_test.loc[:,label_cols].values    
   
    #Normalizing training data
    x_train_nor = xtrain_min_max_scaler.fit_transform(x_train)
    y_train_nor = ytrain_min_max_scaler.fit_transform(y_train)

    # Normalizing test data
    x_test_nor = xtest_min_max_scaler.fit_transform(x_test)
    y_test_nor = ytest_min_max_scaler.fit_transform(y_test)
    
    # Saving actual train and test y_label
    y_train_actual = y_train
    y_test_actual = y_test
    
    #Building timeseries
    X_Train, Y_Train, Y_train_actual = timeseries(x_train_nor, y_train_nor, y_train_actual, time_steps=18, out_steps=1)
    X_Test, Y_Test, Y_test_actual = timeseries(x_test_nor, y_test_nor, y_test_actual, time_steps=18, out_steps=1)
    
    return X_Train, Y_Train, Y_train_actual, X_Test, Y_Test, Y_test_actual

# %%
#calling function to create lag dataframe
lag_df = lag_seq(new_df, 1)
lag_df.dropna(inplace=True)
X_Train, Y_Train, Y_train_actual, X_Test, Y_Test, Y_test_actual = data_processing(lag_df)
# Out:
# /home/bidur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   from ipykernel import kernelapp as app
# HBox(children=(FloatProgress(value=0.0, max=148416.0), HTML(value='')))
# length of time-series i/o (148416, 18, 3) (148416,)
# HBox(children=(FloatProgress(value=0.0, max=37091.0), HTML(value='')))
# length of time-series i/o (37091, 18, 3) (37091,)

# %%
#Build Model
def make_model(X_Train):
    input_layer = Input(shape=(X_Train.shape[1], X_Train.shape[2]))

    conv1 = Conv1D(filters=16, kernel_size=1, strides=1,
                    padding='same',activation='relu')(input_layer)
    conv2 = Conv1D(filters=32, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv1)
    conv3 = Conv1D(filters=64, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv2)
    #conv4 = Conv1D(filters=128, kernel_size=3,strides = 1,
                         # padding='same', activation='relu')(conv3)
    #model.add(MaxPooling2D(pool_size=(2,2), strides = (1,1)))

    flatten = Flatten()(conv3)

    #dense1 = Dense(128, activation='relu')(flatten)
    #dense2 = Dense(64, activation='relu')(dense1)
    #dense3 = Dense(32, activation='relu')(dense2)
    #dense4 = Dense(16, activation='relu')(dense3)
    dense1 = Dense(20, activation='relu')(flatten)    
    output_layer = Dense(1, activation='linear')(dense1)
    
    return Model(inputs=input_layer, outputs=output_layer)

# %%
mse_for_iter = []
train_loss_over_epoch = []
val_loss_over_epoch = []
models = []
predicted_y_values_unnors = []
def run_iteration(no_iter=20, epochs = 10):
    start_time = time.time()
    for iteration in range(no_iter):
        print(f'Iteration: {iteration + 1}')
        K.clear_session()
        model = make_model(X_Train)
        #plot_model(model, show_shapes=True)
        model.compile(optimizer = 'adam', loss = 'mean_squared_error')
        history = model.fit(X_Train, Y_Train, epochs=epochs,
                       validation_data=(X_Test, Y_Test))
        train_loss_over_epoch.append(history.history['loss'])
        val_loss_over_epoch.append(history.history['val_loss'])
        predicted_y_values = model.predict(X_Test)
        predicted_y_values_unnor = ytrain_min_max_scaler.inverse_transform(predicted_y_values)
        mse_for_iter.append(mean_squared_error(predicted_y_values_unnor, Y_test_actual))
        models.append(model)
        predicted_y_values_unnors.append(predicted_y_values_unnor)
        
    end_time = time.time()
    print(f'It took {(start_time - end_time)/60} minutes to train the model for {no_iter} iterations')
    #return predicted unnormalized values for test set from last iteration 
    return predicted_y_values_unnor, model

predicted_y_values_unnor, model = run_iteration(20,10)
# Out:
# Iteration: 1
# Epoch 1/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 5.3637e-05 - val_loss: 1.5956e-05
# Epoch 2/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 8.1844e-06 - val_loss: 5.4751e-06
# Epoch 3/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 5.1497e-06 - val_loss: 3.1428e-06
# Epoch 4/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 3.8128e-06 - val_loss: 2.2724e-06
# Epoch 5/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.9091e-06 - val_loss: 2.7400e-06
# Epoch 6/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 3.4015e-06 - val_loss: 2.2344e-06
# Epoch 7/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.2053e-06 - val_loss: 4.0827e-06
# Epoch 8/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.0148e-06 - val_loss: 1.8341e-06
# Epoch 9/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.0662e-06 - val_loss: 1.3722e-06
# Epoch 10/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.3017e-06 - val_loss: 1.6349e-06
# Iteration: 2
# Epoch 1/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 3.9891e-05 - val_loss: 1.7693e-05
# Epoch 2/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 9.1691e-06 - val_loss: 7.0163e-06
# Epoch 3/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 5.1196e-06 - val_loss: 2.6571e-06
# Epoch 4/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.5352e-06 - val_loss: 1.9764e-06
# Epoch 5/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.0042e-06 - val_loss: 2.1463e-06
# Epoch 6/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.8862e-06 - val_loss: 1.4685e-06
# Epoch 7/10
# 4638/4638 [==============================] - 11s 2ms/step - loss: 1.3874e-06 - val_loss: 9.3637e-07
# Epoch 8/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.3870e-06 - val_loss: 7.7768e-07
# Epoch 9/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.1412e-06 - val_loss: 1.2580e-06
# Epoch 10/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.1439e-06 - val_loss: 8.4913e-07
# Iteration: 3
# Epoch 1/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 4.8860e-05 - val_loss: 2.1701e-05
# Epoch 2/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.2748e-05 - val_loss: 7.1473e-06
# Epoch 3/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 6.6424e-06 - val_loss: 6.5996e-06
# Epoch 4/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 4.6501e-06 - val_loss: 4.3005e-06
# Epoch 5/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.9277e-06 - val_loss: 3.4753e-06
# Epoch 6/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.2633e-06 - val_loss: 5.1407e-06
# Epoch 7/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.8644e-06 - val_loss: 4.4807e-06
# Epoch 8/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.3438e-06 - val_loss: 6.1300e-05
# Epoch 9/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.5490e-06 - val_loss: 2.3839e-06
# Epoch 10/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.7590e-06 - val_loss: 4.3240e-05
# Iteration: 4
# Epoch 1/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 4.0879e-05 - val_loss: 2.1745e-05
# Epoch 2/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 7.1369e-06 - val_loss: 6.4491e-06
# Epoch 3/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 5.0864e-06 - val_loss: 4.0340e-06
# Epoch 4/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 4.0920e-06 - val_loss: 6.2453e-06
# Epoch 5/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.3849e-06 - val_loss: 2.8452e-06
# Epoch 6/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.1050e-06 - val_loss: 2.8534e-06
# Epoch 7/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.1733e-06 - val_loss: 2.1739e-06
# Epoch 8/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.8861e-06 - val_loss: 1.5547e-06
# Epoch 9/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.5850e-06 - val_loss: 7.2915e-06
# Epoch 10/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.5552e-06 - val_loss: 8.8569e-07
# Iteration: 5
# Epoch 1/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.0531e-05 - val_loss: 7.1167e-06
# Epoch 2/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 5.1608e-06 - val_loss: 3.9534e-06
# Epoch 3/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 4.4302e-06 - val_loss: 1.9275e-06
# Epoch 4/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.8259e-06 - val_loss: 1.9657e-06
# Epoch 5/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.0461e-06 - val_loss: 1.2162e-06
# Epoch 6/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.3670e-06 - val_loss: 3.1958e-06
# Epoch 7/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.2069e-06 - val_loss: 1.5719e-06
# Epoch 8/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.0137e-06 - val_loss: 1.0036e-06
# Epoch 9/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.6629e-06 - val_loss: 1.2306e-06
# Epoch 10/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.1585e-06 - val_loss: 3.4159e-06
# Iteration: 6
# Epoch 1/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 5.5510e-05 - val_loss: 1.3422e-05
# Epoch 2/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 9.3941e-06 - val_loss: 7.9554e-06
# Epoch 3/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 4.7050e-06 - val_loss: 4.5957e-06
# Epoch 4/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 3.4987e-06 - val_loss: 3.4572e-06
# Epoch 5/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.8923e-06 - val_loss: 1.9878e-06
# Epoch 6/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.0164e-06 - val_loss: 4.9676e-06
# Epoch 7/10
# 4638/4638 [==============================] - 11s 2ms/step - loss: 1.9340e-06 - val_loss: 1.6155e-06
# Epoch 8/10
# 4638/4638 [==============================] - 11s 2ms/step - loss: 1.6691e-06 - val_loss: 1.6981e-06
# Epoch 9/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.2617e-06 - val_loss: 1.2921e-06
# Epoch 10/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.4622e-06 - val_loss: 1.0442e-06
# Iteration: 7
# Epoch 1/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 5.7181e-05 - val_loss: 1.5887e-05
# Epoch 2/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.1429e-05 - val_loss: 6.0595e-06
# Epoch 3/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 4.9113e-06 - val_loss: 3.1686e-06
# Epoch 4/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 4.8984e-06 - val_loss: 2.6958e-06
# Epoch 5/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.1624e-06 - val_loss: 2.9033e-06
# Epoch 6/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.0124e-06 - val_loss: 1.3790e-06
# Epoch 7/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.9380e-06 - val_loss: 1.1827e-06
# Epoch 8/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.6090e-06 - val_loss: 8.5022e-07
# Epoch 9/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.7784e-06 - val_loss: 1.4952e-06
# Epoch 10/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.7475e-06 - val_loss: 5.5513e-06
# Iteration: 8
# Epoch 1/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 5.6692e-05 - val_loss: 4.2201e-05
# Epoch 2/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.1117e-05 - val_loss: 8.3296e-06
# Epoch 3/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 6.0191e-06 - val_loss: 7.9298e-06
# Epoch 4/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 3.4728e-06 - val_loss: 4.6776e-06
# Epoch 5/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 4.1582e-06 - val_loss: 5.1706e-06
# Epoch 6/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 3.3159e-06 - val_loss: 1.2995e-05
# Epoch 7/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.2741e-06 - val_loss: 2.5722e-06
# Epoch 8/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.6524e-06 - val_loss: 2.9946e-06
# Epoch 9/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.5523e-06 - val_loss: 2.3181e-06
# Epoch 10/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.5820e-06 - val_loss: 2.7089e-05
# Iteration: 9
# Epoch 1/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 4.6170e-05 - val_loss: 1.1419e-05
# Epoch 2/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 8.8254e-06 - val_loss: 8.1054e-06
# Epoch 3/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 5.8190e-06 - val_loss: 6.2004e-06
# Epoch 4/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 3.5107e-06 - val_loss: 3.8471e-06
# Epoch 5/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 4.7066e-06 - val_loss: 2.9799e-06
# Epoch 6/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.5280e-06 - val_loss: 1.8752e-06
# Epoch 7/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.5392e-06 - val_loss: 2.7065e-06
# Epoch 8/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.3850e-06 - val_loss: 1.2273e-06
# Epoch 9/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.6646e-06 - val_loss: 1.4180e-06
# Epoch 10/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.1526e-06 - val_loss: 8.4201e-07
# Iteration: 10
# Epoch 1/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 5.2870e-05 - val_loss: 3.7332e-05
# Epoch 2/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.2203e-05 - val_loss: 1.4023e-05
# Epoch 3/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 7.2377e-06 - val_loss: 8.9400e-06
# Epoch 4/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 4.7918e-06 - val_loss: 2.9455e-06
# Epoch 5/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 3.6754e-06 - val_loss: 2.9161e-06
# Epoch 6/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 4.9738e-06 - val_loss: 5.7984e-06
# Epoch 7/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.2359e-06 - val_loss: 2.1567e-06
# Epoch 8/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.6983e-06 - val_loss: 1.1958e-06
# Epoch 9/10
# 4638/4638 [==============================] - 11s 2ms/step - loss: 1.4297e-06 - val_loss: 1.0305e-06
# Epoch 10/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.4153e-06 - val_loss: 1.1959e-06
# Iteration: 11
# Epoch 1/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 5.7367e-05 - val_loss: 1.5954e-05
# Epoch 2/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 8.9006e-06 - val_loss: 1.1157e-05
# Epoch 3/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 5.4697e-06 - val_loss: 2.2887e-06
# Epoch 4/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.2103e-06 - val_loss: 1.3689e-05
# Epoch 5/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.7141e-06 - val_loss: 2.0167e-06
# Epoch 6/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.9350e-06 - val_loss: 1.9017e-06
# Epoch 7/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.3655e-06 - val_loss: 4.8110e-06
# Epoch 8/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.6867e-06 - val_loss: 2.4127e-06
# Epoch 9/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.0434e-06 - val_loss: 9.6145e-07
# Epoch 10/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.1424e-06 - val_loss: 1.4952e-06
# Iteration: 12
# Epoch 1/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 4.5744e-05 - val_loss: 1.3706e-05
# Epoch 2/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 8.5568e-06 - val_loss: 9.6043e-06
# Epoch 3/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 6.5866e-06 - val_loss: 7.1606e-06
# Epoch 4/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 4.4179e-06 - val_loss: 3.3362e-06
# Epoch 5/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.9435e-06 - val_loss: 1.9492e-06
# Epoch 6/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 3.0008e-06 - val_loss: 2.8300e-06
# Epoch 7/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.7307e-06 - val_loss: 1.7732e-06
# Epoch 8/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.8419e-06 - val_loss: 2.2644e-06
# Epoch 9/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.4964e-06 - val_loss: 1.4187e-06
# Epoch 10/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.8741e-06 - val_loss: 1.6980e-06
# Iteration: 13
# Epoch 1/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 5.2314e-05 - val_loss: 2.1495e-05
# Epoch 2/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.5365e-05 - val_loss: 1.3257e-05
# Epoch 3/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 6.4990e-06 - val_loss: 3.6395e-06
# Epoch 4/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 5.1654e-06 - val_loss: 2.9923e-06
# Epoch 5/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 3.1095e-06 - val_loss: 2.9749e-06
# Epoch 6/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 3.0214e-06 - val_loss: 1.7779e-06
# Epoch 7/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 3.1573e-06 - val_loss: 8.7248e-06
# Epoch 8/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.2582e-06 - val_loss: 1.7519e-06
# Epoch 9/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.0236e-06 - val_loss: 2.4921e-06
# Epoch 10/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.5039e-06 - val_loss: 1.6508e-06
# Iteration: 14
# Epoch 1/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 4.6940e-05 - val_loss: 1.8002e-05
# Epoch 2/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 7.3734e-06 - val_loss: 8.0353e-06
# Epoch 3/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 4.0618e-06 - val_loss: 2.8527e-06
# Epoch 4/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 4.3492e-06 - val_loss: 4.0721e-06
# Epoch 5/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.9654e-06 - val_loss: 2.6903e-06
# Epoch 6/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.1198e-06 - val_loss: 1.4800e-06
# Epoch 7/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.7943e-06 - val_loss: 1.5552e-05
# Epoch 8/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.8319e-06 - val_loss: 1.4885e-06
# Epoch 9/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.5257e-06 - val_loss: 9.0808e-07
# Epoch 10/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.1511e-06 - val_loss: 1.1432e-06
# Iteration: 15
# Epoch 1/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 4.6969e-05 - val_loss: 3.9085e-05
# Epoch 2/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 1.5941e-05 - val_loss: 1.0525e-05
# Epoch 3/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 6.4229e-06 - val_loss: 2.3752e-05
# Epoch 4/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 5.1142e-06 - val_loss: 5.5269e-06
# Epoch 5/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 3.2419e-06 - val_loss: 4.0804e-06
# Epoch 6/10
# 4638/4638 [==============================] - 9s 2ms/step - loss: 2.7133e-06 - val_loss: 1.8206e-06
# Epoch 7/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.4608e-06 - val_loss: 3.2326e-06
# Epoch 8/10
# 4638/4638 [==============================] - 11s 2ms/step - loss: 2.2530e-06 - val_loss: 1.3814e-06
# Epoch 9/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.9749e-06 - val_loss: 1.9977e-06
# Epoch 10/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.8016e-06 - val_loss: 2.4032e-06
# Iteration: 16
# Epoch 1/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 4.2905e-05 - val_loss: 1.0083e-05
# Epoch 2/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 7.9146e-06 - val_loss: 3.6763e-06
# Epoch 3/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.8427e-06 - val_loss: 3.3396e-06
# Epoch 4/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 4.3303e-06 - val_loss: 4.3625e-06
# Epoch 5/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.0106e-06 - val_loss: 3.1147e-06
# Epoch 6/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.4552e-06 - val_loss: 1.4853e-06
# Epoch 7/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.4804e-06 - val_loss: 1.7582e-06
# Epoch 8/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.6685e-06 - val_loss: 1.1723e-06
# Epoch 9/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.0010e-06 - val_loss: 1.1501e-06
# Epoch 10/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.0874e-06 - val_loss: 1.8060e-06
# Iteration: 17
# Epoch 1/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 5.7884e-05 - val_loss: 1.6100e-05
# Epoch 2/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 8.8977e-06 - val_loss: 8.8384e-06
# Epoch 3/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 6.0998e-06 - val_loss: 1.7458e-05
# Epoch 4/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.6090e-06 - val_loss: 2.9129e-06
# Epoch 5/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.3244e-06 - val_loss: 2.5116e-06
# Epoch 6/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.2899e-06 - val_loss: 1.7922e-06
# Epoch 7/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.0530e-06 - val_loss: 1.8942e-06
# Epoch 8/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.4018e-06 - val_loss: 1.1912e-06
# Epoch 9/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.2982e-06 - val_loss: 1.8960e-06
# Epoch 10/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.5809e-06 - val_loss: 8.1891e-07
# Iteration: 18
# Epoch 1/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.9960e-05 - val_loss: 1.6065e-05
# Epoch 2/10
# 4638/4638 [==============================] - 11s 2ms/step - loss: 6.4729e-06 - val_loss: 5.5981e-06
# Epoch 3/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 5.2637e-06 - val_loss: 3.8703e-06
# Epoch 4/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.9493e-06 - val_loss: 4.5905e-06
# Epoch 5/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.4200e-06 - val_loss: 3.4565e-06
# Epoch 6/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.6544e-06 - val_loss: 1.5390e-06
# Epoch 7/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.9801e-06 - val_loss: 2.9691e-06
# Epoch 8/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.7042e-06 - val_loss: 1.3285e-06
# Epoch 9/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.4877e-06 - val_loss: 3.7709e-06
# Epoch 10/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.5823e-06 - val_loss: 1.5817e-06
# Iteration: 19
# Epoch 1/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 5.6766e-05 - val_loss: 1.8293e-05
# Epoch 2/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.1811e-05 - val_loss: 1.4364e-05
# Epoch 3/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 7.2775e-06 - val_loss: 7.3485e-06
# Epoch 4/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 5.7111e-06 - val_loss: 3.7588e-06
# Epoch 5/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 5.1611e-06 - val_loss: 2.8033e-06
# Epoch 6/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 4.0537e-06 - val_loss: 4.5295e-06
# Epoch 7/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.0228e-06 - val_loss: 2.4687e-06
# Epoch 8/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.3953e-06 - val_loss: 1.7710e-06
# Epoch 9/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.1226e-06 - val_loss: 4.0728e-06
# Epoch 10/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.2578e-06 - val_loss: 1.9543e-06
# Iteration: 20
# Epoch 1/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 4.8646e-05 - val_loss: 1.4452e-05
# Epoch 2/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 8.8924e-06 - val_loss: 7.7198e-06
# Epoch 3/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 4.4753e-06 - val_loss: 9.5127e-06
# Epoch 4/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 3.1217e-06 - val_loss: 2.0450e-06
# Epoch 5/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 2.5815e-06 - val_loss: 1.6250e-06
# Epoch 6/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.8956e-06 - val_loss: 1.8459e-06
# Epoch 7/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.8751e-06 - val_loss: 1.2286e-06
# Epoch 8/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.4891e-06 - val_loss: 3.5383e-06
# Epoch 9/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.4597e-06 - val_loss: 1.3403e-06
# Epoch 10/10
# 4638/4638 [==============================] - 10s 2ms/step - loss: 1.1768e-06 - val_loss: 1.5694e-06
# It took -32.59659421443939 minutes to train the model for 20 iterations

# %%
#model.save("cnn_model1_waterflow_30epochs.hdf5")

# %%
def plot_evaluation():
    #mean square error over iterations
    plt.figure(figsize=(15, 10))
    plt.plot(mse_for_iter)
    plt.ylabel('mean squared error')
    plt.xlabel('iteration')
    plt.savefig('mse30.png',bbox_inches='tight')
    plt.show()
        
    #plot train and validation loss over epochs for each iteration
    fig, axs = plt.subplots(10, 2)
    #axs.set_ylabel('loss')
    #axs.set_xlabel('epoch')
    fig.set_size_inches(18.5, 50)
    for row in range(10):
        for col in range(2):
            index = 2*row + col #index to get loss from training loss and validation loss list
            axs[row, col].plot(train_loss_over_epoch[index])
            axs[row, col].plot(val_loss_over_epoch[index])
            axs[row, col].set_title('Iteration(%d)' %(index+1))
            axs[row, col].legend(['train', 'Val'], loc='upper left')            
    plt.savefig('train_val_loss30.png', bbox_inches='tight')
    
    #plot predicted value vs actual values from last iteration
    plt.figure(figsize=(15, 10))
    plt.plot(predicted_y_values_unnor, 'ro', alpha=0.8)
    plt.plot(Y_test_actual, 'bo', alpha=0.1)
    plt.legend(['Predicted values', 'Actual values'], loc='upper right')
    plt.ylabel('Outflow')
    plt.xlabel('nth datapoint')
    plt.savefig('predicted_values_visual30.png', bbox_inches='tight')
    plt.show()
    
#call plot_evaluation function
plot_evaluation()

# %%
mse_for_iter
# Out:
# [11.918968700500782,
#  22.07405936780792,
#  76.29757045706067,
#  25.497127327777587,
#  18.025660550911173,
#  32.815451131710624,
#  61.85053851974183,
#  171.1740051544602,
#  23.311590463066512,
#  17.5439639257268,
#  16.27564523747477,
#  32.73069633013084,
#  24.793326182585552,
#  20.504716703776232,
#  33.610865384821864,
#  13.522388750642602,
#  22.296916947596248,
#  35.01676739046975,
#  22.845889742648463,
#  11.080000673631327]

# %%
print(np.mean(mse_for_iter))
# Out:
# 34.659307447127084

# %%
plot_model(model, show_shapes=True)

# %%
#import modules
import numpy as np
import pandas as pd
import time
from keras import backend as K 
from keras.engine.training import Model
from keras.utils import to_categorical, plot_model
from keras.models import Sequential, load_model
from sklearn.preprocessing import MinMaxScaler
from keras.layers.convolutional import Conv1D, Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers import Dropout, Activation, Flatten
from keras.layers import LSTM, Dense, Input
from keras.optimizers import SGD
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tqdm import tqdm_notebook
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('./Sub0-RAW.csv')
df.head()
# Out:
#        Dates  Year  Month  Day    Hours  Precipitation  Temperature  Outflow
# 0  10/1/1980  1980     10    1  0:00:00            0.0      102.992      5.0
# 1  10/1/1980  1980     10    1  1:00:00            0.0       97.790      5.0
# 2  10/1/1980  1980     10    1  2:00:00            0.0       92.588      5.0
# 3  10/1/1980  1980     10    1  3:00:00            0.0       87.404      5.0
# 4  10/1/1980  1980     10    1  4:00:00            0.0       85.172      5.0

# %%
train_cols = ["Precipitation", "Temperature"]
label_cols = ["Outflow(t+2)"]

# %%
new_df = df.filter(["Precipitation", "Temperature", "Outflow"], axis=1)

# %%
#Min Max scalr normalizing
xtrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
xtest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))

# %%
#function to shift the time_series data for getting labels
def lag_seq(df, n_seq):
    for i in range(n_seq):
        df['Outflow(t+%d)' %(i+1)] = new_df['Outflow'].shift(-(i+1))
    return df

# building timeseries data with given timesteps
def timeseries(X, Y, Y_actual, time_steps, out_steps):
    input_size_0 = X.shape[0] - time_steps
    input_size_1 = X.shape[1]
    X_values = np.zeros((input_size_0, time_steps, input_size_1))
    Y_values = np.zeros((input_size_0,))
    Y_values_actual = np.zeros((input_size_0,))
    
    for i in tqdm_notebook(range(input_size_0)):
        X_values[i] = X[i:time_steps+i]
        Y_values[i] = Y[time_steps+i-1, 0]
        Y_values_actual[i] = Y_actual[time_steps+i-1, 0]
        
    print("length of time-series i/o",X_values.shape,Y_values.shape)
    return X_values, Y_values, Y_values_actual

#getting data ready for training the model
def data_processing(lag_df):
    #Splitting training and test data
    df_train, df_test = train_test_split(lag_df, train_size=0.8, test_size=0.2, shuffle=False)
    x_train = df_train.loc[:,train_cols].values
    y_train = df_train.loc[:,label_cols].values
    x_test = df_test.loc[:,train_cols].values
    y_test = df_test.loc[:,label_cols].values    
   
    #Normalizing training data
    x_train_nor = xtrain_min_max_scaler.fit_transform(x_train)
    y_train_nor = ytrain_min_max_scaler.fit_transform(y_train)

    # Normalizing test data
    x_test_nor = xtest_min_max_scaler.fit_transform(x_test)
    y_test_nor = ytest_min_max_scaler.fit_transform(y_test)
    
    # Saving actual train and test y_label
    y_train_actual = y_train
    y_test_actual = y_test
    
    return x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual

# %%
#calling function to create lag dataframe
lag_df = lag_seq(new_df, 2)
lag_df.dropna(inplace=True)

# %%
#Building timeseries
x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual = data_processing(lag_df)
X_Train, Y_Train, Y_train_actual = timeseries(x_train_nor, y_train_nor, y_train_actual, time_steps=18, out_steps=1)
X_Test, Y_Test, Y_test_actual = timeseries(x_test_nor, y_test_nor, y_test_actual, time_steps=18, out_steps=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   from ipykernel import kernelapp as app
# HBox(children=(FloatProgress(value=0.0, max=148415.0), HTML(value='')))
# length of time-series i/o (148415, 18, 2) (148415,)
# HBox(children=(FloatProgress(value=0.0, max=37091.0), HTML(value='')))
# length of time-series i/o (37091, 18, 2) (37091,)

# %%
#Build Model
def make_model(X_Train):
    input_layer = Input(shape=(X_Train.shape[1], X_Train.shape[2]))

    lstm1 = LSTM(units=16, return_sequences=True)(input_layer)
    dropout1 = Dropout(0.2)(lstm1)
    lstm2 = LSTM(units=32, return_sequences=True)(dropout1)
    dropout2 = Dropout(0.2)(lstm2)
    lstm3 = LSTM(units=64)(dropout2)
    dropout3 = Dropout(0.2)(lstm3)

    dense1 = Dense(128, activation='relu')(dropout3)
    dense2 = Dense(64, activation='relu')(dense1)
    output_layer = Dense(1, activation='linear')(dense2)
    
    return Model(inputs=input_layer, outputs=output_layer)

# %%
mse_for_iter = []
train_loss_over_epoch = []
val_loss_over_epoch = []
predicted_y_values_unnors = []
models = []

def run_iteration_model(no_iter=20, epochs = 10):
    start_time = time.time()
    for iteration in range(no_iter):
        print(f'Iteration: {iteration + 1}')
        K.clear_session()
        model = make_model(X_Train)
        #plot_model(model, show_shapes=True)
        model.compile(optimizer = 'adam', loss = 'mean_squared_error')
        history = model.fit(X_Train, Y_Train, epochs=epochs,
                       validation_data=(X_Test, Y_Test))
        train_loss_over_epoch.append(history.history['loss'])
        val_loss_over_epoch.append(history.history['val_loss'])
        predicted_y_values = model.predict(X_Test)
        predicted_y_values_unnor = ytrain_min_max_scaler.inverse_transform(predicted_y_values)
        mse_for_iter.append(mean_squared_error(predicted_y_values_unnor, Y_test_actual))
        predicted_y_values_unnors.append(predicted_y_values_unnor)
        models.append(model)
               
    end_time = time.time()
    print('--------------------------\n')
    print(f'Starting time: {start_time}')
    print(f'Completing time: {end_time}')
    print(f'It took {(start_time - end_time)/60} minutes to train the model for {no_iter} iterations')
    #return predicted unnormalized values for test set from last iteration 
    return predicted_y_values, predicted_y_values_unnor, model

predicted_y_values, predicted_y_values_unnor, model = run_iteration_model(20,10)
# Out:
# Iteration: 1
# Epoch 1/10
# 4638/4638 [==============================] - 41s 7ms/step - loss: 6.6865e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.4569e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.3798e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.1779e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.8852e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.4133e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.5580e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.1564e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.3866e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.0528e-04 - val_loss: 0.0011
# Iteration: 2
# Epoch 1/10
# 4638/4638 [==============================] - 35s 7ms/step - loss: 7.2199e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.6132e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.3730e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.4238e-04 - val_loss: 0.0012
# Epoch 5/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.3822e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.1819e-04 - val_loss: 0.0012
# Epoch 7/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.2051e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.1042e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.1223e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.0735e-04 - val_loss: 0.0011
# Iteration: 3
# Epoch 1/10
# 4638/4638 [==============================] - 35s 7ms/step - loss: 7.2877e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 6.1689e-04 - val_loss: 0.0012
# Epoch 3/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.7957e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.5583e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.2811e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.3405e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.4891e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 4.9978e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.0996e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.2706e-04 - val_loss: 0.0011
# Iteration: 4
# Epoch 1/10
# 4638/4638 [==============================] - 35s 7ms/step - loss: 7.0690e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.4610e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.4589e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.5951e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.3117e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.4914e-04 - val_loss: 0.0012
# Epoch 7/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.1208e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.2583e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.0475e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.3612e-04 - val_loss: 0.0011
# Iteration: 5
# Epoch 1/10
# 4638/4638 [==============================] - 34s 7ms/step - loss: 7.2859e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.2121e-04 - val_loss: 0.0013
# Epoch 3/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.8716e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.4277e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.3218e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.4624e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.4097e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.2602e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 5.2991e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.3409e-04 - val_loss: 0.0011
# Iteration: 6
# Epoch 1/10
# 4638/4638 [==============================] - 34s 7ms/step - loss: 7.1743e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.7372e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.8288e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.7100e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.4546e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.3260e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.3363e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.9171e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 4.9972e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.2313e-04 - val_loss: 0.0011
# Iteration: 7
# Epoch 1/10
# 4638/4638 [==============================] - 34s 7ms/step - loss: 7.0107e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.5931e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.0832e-04 - val_loss: 0.0012
# Epoch 4/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.1664e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.3347e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.5460e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.0879e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.0236e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.5427e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.7724e-04 - val_loss: 0.0011
# Iteration: 8
# Epoch 1/10
# 4638/4638 [==============================] - 35s 7ms/step - loss: 7.0837e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.5213e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.8916e-04 - val_loss: 0.0012
# Epoch 4/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.3757e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.9300e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 5.4391e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.4047e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.4099e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.9580e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.0833e-04 - val_loss: 0.0012
# Iteration: 9
# Epoch 1/10
# 4638/4638 [==============================] - 34s 7ms/step - loss: 7.0197e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.7852e-04 - val_loss: 0.0012
# Epoch 3/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.2262e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.4176e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.2375e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.1311e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.7617e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.7421e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.3896e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.1853e-04 - val_loss: 0.0012
# Iteration: 10
# Epoch 1/10
# 4638/4638 [==============================] - 34s 7ms/step - loss: 7.2533e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.8258e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.4460e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.5605e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.3087e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.3192e-04 - val_loss: 0.0012
# Epoch 7/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.3466e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.2235e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 4.8015e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.0651e-04 - val_loss: 0.0011
# Iteration: 11
# Epoch 1/10
# 4638/4638 [==============================] - 34s 7ms/step - loss: 7.2225e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.6168e-04 - val_loss: 0.0012
# Epoch 3/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.7193e-04 - val_loss: 0.0012
# Epoch 4/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.4310e-04 - val_loss: 0.0012
# Epoch 5/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.8456e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 4.8798e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 4.9303e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.4544e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.3512e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.1071e-04 - val_loss: 0.0011
# Iteration: 12
# Epoch 1/10
# 4638/4638 [==============================] - 35s 7ms/step - loss: 7.2533e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.9314e-04 - val_loss: 0.0013
# Epoch 3/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.6137e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.8937e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.2667e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.0140e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.1417e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.1517e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.9081e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.0767e-04 - val_loss: 0.0011
# Iteration: 13
# Epoch 1/10
# 4638/4638 [==============================] - 35s 7ms/step - loss: 6.8818e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.9923e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.5717e-04 - val_loss: 0.0012
# Epoch 4/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.3167e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.1529e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.9936e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.1139e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.2093e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.1213e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.1302e-04 - val_loss: 0.0011
# Iteration: 14
# Epoch 1/10
# 4638/4638 [==============================] - 35s 7ms/step - loss: 7.3708e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.7153e-04 - val_loss: 0.0012
# Epoch 3/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.6675e-04 - val_loss: 0.0012
# Epoch 4/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.3932e-04 - val_loss: 0.0013
# Epoch 5/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.3815e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.1821e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.0648e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.1300e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.2980e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.3650e-04 - val_loss: 0.0011
# Iteration: 15
# Epoch 1/10
# 4638/4638 [==============================] - 34s 7ms/step - loss: 7.0776e-04 - val_loss: 0.0014
# Epoch 2/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.8375e-04 - val_loss: 0.0012
# Epoch 3/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.6555e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.5784e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.4698e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.3071e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.0651e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.3452e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.2691e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.1717e-04 - val_loss: 0.0011
# Iteration: 16
# Epoch 1/10
# 4638/4638 [==============================] - 35s 7ms/step - loss: 6.8269e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 5.5948e-04 - val_loss: 0.0012
# Epoch 3/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.4960e-04 - val_loss: 0.0012
# Epoch 4/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 5.1906e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.5648e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.4844e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.3799e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.1880e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.4600e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.5442e-04 - val_loss: 0.0011
# Iteration: 17
# Epoch 1/10
# 4638/4638 [==============================] - 35s 7ms/step - loss: 7.1940e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.6242e-04 - val_loss: 0.0012
# Epoch 3/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.5254e-04 - val_loss: 0.0013
# Epoch 4/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.9273e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.6937e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.1912e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.4856e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.6566e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.2574e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.3849e-04 - val_loss: 0.0011
# Iteration: 18
# Epoch 1/10
# 4638/4638 [==============================] - 35s 7ms/step - loss: 7.2251e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.9361e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.5779e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.3576e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.3648e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.3829e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.0742e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.5419e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.3378e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.0515e-04 - val_loss: 0.0011
# Iteration: 19
# Epoch 1/10
# 4638/4638 [==============================] - 34s 7ms/step - loss: 7.6043e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.6322e-04 - val_loss: 0.0012
# Epoch 3/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.6746e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.3623e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.3628e-04 - val_loss: 0.0012
# Epoch 6/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.2868e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.2316e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.1582e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.3478e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.0396e-04 - val_loss: 0.0011
# Iteration: 20
# Epoch 1/10
# 4638/4638 [==============================] - 35s 7ms/step - loss: 6.9037e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.7155e-04 - val_loss: 0.0012
# Epoch 3/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.5835e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.7340e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.6265e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 4.8296e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.7517e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.2586e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 5.2431e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 5.1928e-04 - val_loss: 0.0011
# --------------------------
#
# Starting time: 1613575943.2043166
# Completing time: 1613582202.9466672
# It took -104.32903917630513 minutes to train the model for 20 iterations

# %%
model.save("lstm_model2_2_features_pre_tem_without_prediction.hdf5")

# %%
def plot_evaluation():
    #mean square error over iterations
    plt.figure(figsize=(15, 10))
    plt.plot(mse_for_iter)
    plt.ylabel('mean squared error')
    plt.xlabel('iteration')
    plt.savefig('mse_wo_pred.png', bbox_inches='tight')
    plt.show()
        
    #plot train and validation loss over epochs for each iteration
    fig, axs = plt.subplots(10, 2)
    #axs.set_ylabel('loss')
    #axs.set_xlabel('epoch')
    fig.set_size_inches(18.5, 50)
    for row in range(10):
        for col in range(2):
            index = 2*row + col #index to get loss from training loss and validation loss list
            axs[row, col].plot(train_loss_over_epoch[index])
            axs[row, col].plot(val_loss_over_epoch[index])
            axs[row, col].set_title('Iteration(%d)' %(index+1))
            axs[row, col].legend(['train', 'Val'], loc='upper left')            
    plt.savefig('train_val_loss_wo_pred.png', bbox_inches='tight')
    
    #plot predicted value vs actual values from last iteration
    plt.figure(figsize=(15, 10))
    plt.plot(predicted_y_values_unnor, 'ro', alpha=0.8)
    plt.plot(Y_test_actual, 'bo', alpha=0.1)
    plt.legend(['Predicted values', 'Actual values'], loc='upper right')
    plt.ylabel('Outflow')
    plt.xlabel('nth datapoint')
    plt.savefig('predicted_values_visuals_wo_pred.png', bbox_inches='tight')
    plt.show()
    
#call plot_evaluation function
plot_evaluation()

# %%
mse_for_iter
# Out:
# [4092.5952550282827,
#  4060.9690332126725,
#  4047.270152819002,
#  4185.987572242623,
#  4153.699431851893,
#  4136.622314130143,
#  4040.590667032634,
#  4260.7481170397505,
#  4281.946872511929,
#  4053.1645554481415,
#  4117.209668748076,
#  4166.6500678226585,
#  4028.7915796912393,
#  4065.4689059741163,
#  4085.941695250425,
#  4106.091739769004,
#  4114.915719967435,
#  4210.087024138519,
#  4090.4859069061304,
#  4135.918203605767]

# %%
print(np.mean(mse_for_iter))
# Out:
# 4121.757724159523

# %%
plot_model(model, show_shapes=True)

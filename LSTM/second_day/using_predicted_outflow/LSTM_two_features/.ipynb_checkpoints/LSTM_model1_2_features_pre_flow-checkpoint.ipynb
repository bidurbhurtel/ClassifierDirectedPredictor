# %%
#import modules
import numpy as np
import pandas as pd
import time
from keras import backend as K 
from keras.engine.training import Model
from keras.utils import to_categorical, plot_model
from keras.models import Sequential, load_model
from sklearn.preprocessing import MinMaxScaler
from keras.layers.convolutional import Conv1D, Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers import Dropout, Activation, Flatten
from keras.layers import LSTM, Dense, Input
from keras.optimizers import SGD
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tqdm import tqdm_notebook
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('../Sub0-RAW.csv')
df.head()
# Out:
#        Dates  Year  Month  Day    Hours  Precipitation  Temperature  Outflow
# 0  10/1/1980  1980     10    1  0:00:00            0.0      102.992      5.0
# 1  10/1/1980  1980     10    1  1:00:00            0.0       97.790      5.0
# 2  10/1/1980  1980     10    1  2:00:00            0.0       92.588      5.0
# 3  10/1/1980  1980     10    1  3:00:00            0.0       87.404      5.0
# 4  10/1/1980  1980     10    1  4:00:00            0.0       85.172      5.0

# %%
train_cols = ["Precipitation","Temperature"]
label_cols = ["Outflow(t+1)"]

# %%
new_df = df.filter(["Precipitation","Temperature", "Outflow"], axis=1)

# %%
#Min Max scalr normalizing
xtrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
xtest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))

# %%
#function to shift the time_series data for getting labels
def lag_seq(df, n_seq):
    for i in range(n_seq):
        df['Outflow(t+%d)' %(i+1)] = new_df['Outflow'].shift(-(i+1))
    return df

# building timeseries data with given timesteps
def timeseries(X, Y, Y_actual, time_steps, out_steps):
    input_size_0 = X.shape[0] - time_steps
    input_size_1 = X.shape[1]
    X_values = np.zeros((input_size_0, time_steps, input_size_1))
    Y_values = np.zeros((input_size_0,))
    Y_values_actual = np.zeros((input_size_0,))
    
    for i in tqdm_notebook(range(input_size_0)):
        X_values[i] = X[i:time_steps+i]
        Y_values[i] = Y[time_steps+i-1, 0]
        Y_values_actual[i] = Y_actual[time_steps+i-1, 0]
        
    print("length of time-series i/o",X_values.shape,Y_values.shape)
    return X_values, Y_values, Y_values_actual

#getting data ready for training the model
def data_processing(lag_df):
    #Splitting training and test data
    df_train, df_test = train_test_split(lag_df, train_size=0.8, test_size=0.2, shuffle=False)
    x_train = df_train.loc[:,train_cols].values
    y_train = df_train.loc[:,label_cols].values
    x_test = df_test.loc[:,train_cols].values
    y_test = df_test.loc[:,label_cols].values    
   
    #Normalizing training data
    x_train_nor = xtrain_min_max_scaler.fit_transform(x_train)
    y_train_nor = ytrain_min_max_scaler.fit_transform(y_train)

    # Normalizing test data
    x_test_nor = xtest_min_max_scaler.fit_transform(x_test)
    y_test_nor = ytest_min_max_scaler.fit_transform(y_test)
    
    # Saving actual train and test y_label
    y_train_actual = y_train
    y_test_actual = y_test
    
    #Building timeseries
    X_Train, Y_Train, Y_train_actual = timeseries(x_train_nor, y_train_nor, y_train_actual, time_steps=18, out_steps=1)
    X_Test, Y_Test, Y_test_actual = timeseries(x_test_nor, y_test_nor, y_test_actual, time_steps=18, out_steps=1)
    
    return X_Train, Y_Train, Y_train_actual, X_Test, Y_Test, Y_test_actual

# %%
#calling function to create lag dataframe
lag_df = lag_seq(new_df, 1)
lag_df.dropna(inplace=True)
X_Train, Y_Train, Y_train_actual, X_Test, Y_Test, Y_test_actual = data_processing(lag_df)
# Out:
# /home/bidur/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   from ipykernel import kernelapp as app
# HBox(children=(FloatProgress(value=0.0, max=148416.0), HTML(value='')))
# length of time-series i/o (148416, 18, 2) (148416,)
# HBox(children=(FloatProgress(value=0.0, max=37091.0), HTML(value='')))
# length of time-series i/o (37091, 18, 2) (37091,)

# %%
#Build Model
def make_model(X_Train):
    input_layer = Input(shape=(X_Train.shape[1], X_Train.shape[2]))

    conv1 = Conv1D(filters=16, kernel_size=1, strides=1,
                    padding='same',activation='relu')(input_layer)
    conv2 = Conv1D(filters=32, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv1)
    conv3 = Conv1D(filters=64, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv2)
    conv4 = Conv1D(filters=128, kernel_size=3,strides = 1,
                          padding='same', activation='relu')(conv3)
    #model.add(MaxPooling2D(pool_size=(2,2), strides = (1,1)))

    flatten = Flatten()(conv4)

    dense1 = Dense(128, activation='relu')(flatten)
    dense2 = Dense(64, activation='relu')(dense1)
    dense3 = Dense(32, activation='relu')(dense2)
    dense4 = Dense(16, activation='relu')(dense3)
    output_layer = Dense(1, activation='linear')(dense4)
    
    return Model(inputs=input_layer, outputs=output_layer)

# %%
mse_for_iter = []
train_loss_over_epoch = []
val_loss_over_epoch = []
def run_iteration(no_iter=20, epochs = 10):
    start_time = time.time()
    for iteration in range(no_iter):
        print(f'Iteration: {iteration + 1}')
        K.clear_session()
        model = make_model(X_Train)
        model.compile(optimizer = 'adam', loss = 'mean_squared_error')
        history = model.fit(X_Train, Y_Train, epochs=epochs,
                       validation_data=(X_Test, Y_Test))
        train_loss_over_epoch.append(history.history['loss'])
        val_loss_over_epoch.append(history.history['val_loss'])
        predicted_y_values = model.predict(X_Test)
        predicted_y_values_unnor = ytrain_min_max_scaler.inverse_transform(predicted_y_values)
        mse_for_iter.append(mean_squared_error(predicted_y_values_unnor, Y_test_actual))
    end_time = time.time()
    print(f'It took {(start_time - end_time)/60} minutes to train the model for {no_iter} iterations')
    #return predicted unnormalized values for test set from last iteration 
    return predicted_y_values_unnor

predicted_y_values_unnor = run_iteration(20,10)
# Out:
# Iteration: 1
# Epoch 1/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 6.0243e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 5.1954e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 5.0042e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.9801e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.8614e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.7984e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.7177e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.5806e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.5348e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 33s 7ms/step - loss: 4.4454e-04 - val_loss: 0.0011
# Iteration: 2
# Epoch 1/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.8936e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.1782e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.0487e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.8702e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.7846e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.6865e-04 - val_loss: 0.0012
# Epoch 7/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.5719e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.5257e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.4110e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.3697e-04 - val_loss: 0.0011
# Iteration: 3
# Epoch 1/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.8814e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.1378e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.9081e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 30s 7ms/step - loss: 4.8235e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.7656e-04 - val_loss: 0.0012
# Epoch 6/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.6445e-04 - val_loss: 0.0012
# Epoch 7/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.5547e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.5079e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.3543e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.3176e-04 - val_loss: 0.0012
# Iteration: 4
# Epoch 1/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 5.7217e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 5.1520e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.9894e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.8784e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.7519e-04 - val_loss: 0.0012
# Epoch 6/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.6510e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.5514e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.4571e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.4809e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.2789e-04 - val_loss: 0.0012
# Iteration: 5
# Epoch 1/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 6.0291e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 5.1397e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.9821e-04 - val_loss: 0.0012
# Epoch 4/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.8718e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.7937e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.6739e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.5853e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.5519e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.3728e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.4035e-04 - val_loss: 0.0012
# Iteration: 6
# Epoch 1/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.8521e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 5.2519e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.9983e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.8399e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.7380e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.5903e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.4788e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.3966e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.2724e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.1614e-04 - val_loss: 0.0012
# Iteration: 7
# Epoch 1/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.8167e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.2219e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.9775e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.9021e-04 - val_loss: 0.0013
# Epoch 5/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.7536e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.6691e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.6175e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.5346e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.5024e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.3900e-04 - val_loss: 0.0011
# Iteration: 8
# Epoch 1/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 6.1217e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 5.2508e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.9935e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.8969e-04 - val_loss: 0.0012
# Epoch 5/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.8069e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 4.6816e-04 - val_loss: 0.0012
# Epoch 7/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.5785e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.4957e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.3888e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.2621e-04 - val_loss: 0.0011
# Iteration: 9
# Epoch 1/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.9075e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 5.1905e-04 - val_loss: 0.0012
# Epoch 3/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 5.0106e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.8887e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.8275e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.6423e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.6694e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.6023e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.5255e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.4619e-04 - val_loss: 0.0012
# Iteration: 10
# Epoch 1/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 5.9777e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 5.1590e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.9461e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.8345e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.7844e-04 - val_loss: 0.0012
# Epoch 6/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.6486e-04 - val_loss: 0.0013
# Epoch 7/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.5279e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.3860e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.3505e-04 - val_loss: 0.0013
# Epoch 10/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.2189e-04 - val_loss: 0.0012
# Iteration: 11
# Epoch 1/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.9206e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.3520e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 5.0578e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.9677e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.7787e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.6858e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.5754e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.5848e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.4421e-04 - val_loss: 0.0013
# Epoch 10/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.2965e-04 - val_loss: 0.0012
# Iteration: 12
# Epoch 1/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 6.0765e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.2419e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 5.0262e-04 - val_loss: 0.0012
# Epoch 4/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.9495e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.7688e-04 - val_loss: 0.0012
# Epoch 6/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.6829e-04 - val_loss: 0.0012
# Epoch 7/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.6299e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.5720e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.4894e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 4.3447e-04 - val_loss: 0.0013
# Iteration: 13
# Epoch 1/10
# 4638/4638 [==============================] - 30s 6ms/step - loss: 6.0839e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 5.2373e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 4.9826e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 4.8164e-04 - val_loss: 0.0012
# Epoch 5/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 4.7457e-04 - val_loss: 0.0012
# Epoch 6/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 4.6249e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 4.4682e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 4.4144e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 4.3179e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 4.1481e-04 - val_loss: 0.0012
# Iteration: 14
# Epoch 1/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 6.4101e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 33s 7ms/step - loss: 5.1945e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 4.9742e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 4.7891e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 4.7023e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 33s 7ms/step - loss: 4.6267e-04 - val_loss: 0.0012
# Epoch 7/10
# 4638/4638 [==============================] - 33s 7ms/step - loss: 4.5181e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 4.4396e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 33s 7ms/step - loss: 4.3320e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 32s 7ms/step - loss: 4.1684e-04 - val_loss: 0.0012
# Iteration: 15
# Epoch 1/10
# 4638/4638 [==============================] - 33s 7ms/step - loss: 6.0266e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 5.2026e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.8821e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.8395e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 31s 7ms/step - loss: 4.6941e-04 - val_loss: 0.0012
# Epoch 6/10
# 4638/4638 [==============================] - 29s 6ms/step - loss: 4.6099e-04 - val_loss: 0.0012
# Epoch 7/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.5072e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.3946e-04 - val_loss: 0.0013
# Epoch 9/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.2609e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.1585e-04 - val_loss: 0.0012
# Iteration: 16
# Epoch 1/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 5.9617e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 5.2139e-04 - val_loss: 0.0012
# Epoch 3/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.9779e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.8797e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.7642e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.5724e-04 - val_loss: 0.0012
# Epoch 7/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.5094e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.4280e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.3283e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.2989e-04 - val_loss: 0.0011
# Iteration: 17
# Epoch 1/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 5.7188e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 5.2353e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.9874e-04 - val_loss: 0.0012
# Epoch 4/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.8277e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.7498e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.6918e-04 - val_loss: 0.0012
# Epoch 7/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.6085e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.5201e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.4487e-04 - val_loss: 0.0012
# Epoch 10/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.3179e-04 - val_loss: 0.0011
# Iteration: 18
# Epoch 1/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 5.9353e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 5.2460e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.9678e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.7546e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.7162e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.6335e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.5259e-04 - val_loss: 0.0011
# Epoch 8/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.4270e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 28s 6ms/step - loss: 4.3485e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.2527e-04 - val_loss: 0.0011
# Iteration: 19
# Epoch 1/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 6.1816e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 5.2265e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.9109e-04 - val_loss: 0.0012
# Epoch 4/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.7962e-04 - val_loss: 0.0012
# Epoch 5/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.6799e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.5663e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.4859e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.3464e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.2551e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.0105e-04 - val_loss: 0.0012
# Iteration: 20
# Epoch 1/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 5.7980e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 5.2033e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.9821e-04 - val_loss: 0.0011
# Epoch 4/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.8252e-04 - val_loss: 0.0011
# Epoch 5/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.7434e-04 - val_loss: 0.0011
# Epoch 6/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.6833e-04 - val_loss: 0.0011
# Epoch 7/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.5745e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 26s 6ms/step - loss: 4.4883e-04 - val_loss: 0.0011
# Epoch 9/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.3820e-04 - val_loss: 0.0011
# Epoch 10/10
# 4638/4638 [==============================] - 27s 6ms/step - loss: 4.2627e-04 - val_loss: 0.0012
# It took -97.7824644168218 minutes to train the model for 20 iterations

# %%
model.save("cnn_model1_2_features.hdf5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c5eda35faacd> in <module>
# ----> 1 model.save("cnn_model1_2_features.hdf5")
#
# NameError: name 'model' is not defined

# %%
def plot_evaluation():
    #mean square error over iterations
    plt.figure(figsize=(15, 10))
    plt.plot(mse_for_iter)
    plt.ylabel('mean squared error')
    plt.xlabel('iteration')
    plt.savefig('mse.png', bbox_inches='tight')
    plt.show()
        
    #plot train and validation loss over epochs for each iteration
    fig, axs = plt.subplots(10, 2)
    #axs.set_ylabel('loss')
    #axs.set_xlabel('epoch')
    fig.set_size_inches(18.5, 50)
    for row in range(10):
        for col in range(2):
            index = 2*row + col #index to get loss from training loss and validation loss list
            axs[row, col].plot(train_loss_over_epoch[index])
            axs[row, col].plot(val_loss_over_epoch[index])
            axs[row, col].set_title('Iteration(%d)' %(index+1))
            axs[row, col].legend(['train', 'Val'], loc='upper left')            
    plt.savefig('train_val_loss.png', bbox_inches='tight')
    
    #plot predicted value vs actual values from last iteration
    plt.figure(figsize=(15, 10))
    plt.plot(predicted_y_values_unnor, 'ro', alpha=0.8)
    plt.plot(Y_test_actual, 'bo', alpha=0.1)
    plt.legend(['Predicted values', 'Actual values'], loc='upper right')
    plt.ylabel('Outflow')
    plt.xlabel('nth datapoint')
    plt.savefig('predicted_values_visuals.png', bbox_inches='tight')
    plt.show()
    
#call plot_evaluation function
plot_evaluation()

# %%
mse_for_iter
# Out:
# [4157.430093186492,
#  4187.526325156745,
#  4250.134445406972,
#  4245.522619384154,
#  4233.076386514333,
#  4433.773591250413,
#  4117.869502627833,
#  4209.346058719152,
#  4350.050719180199,
#  4315.737893023717,
#  4442.916240236946,
#  4572.99677132311,
#  4272.021368711335,
#  4298.2804479220085,
#  4288.1187429607,
#  4180.319503512468,
#  4170.3986498047125,
#  4213.638894396031,
#  4436.4629739206175,
#  4269.696658313628]

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5f15418b3570> in <module>
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined

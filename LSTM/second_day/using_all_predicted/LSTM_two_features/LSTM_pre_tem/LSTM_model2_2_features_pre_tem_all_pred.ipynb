# %%
#import modules
import numpy as np
import pandas as pd
import time
from keras import backend as K 
from keras.engine.training import Model
from keras.utils import to_categorical, plot_model
from keras.models import Sequential, load_model
from sklearn.preprocessing import MinMaxScaler
from keras.layers.convolutional import Conv1D, Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers import Dropout, Activation, Flatten
from keras.layers import LSTM, Dense, Input
from keras.optimizers import SGD
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tqdm import tqdm_notebook
from sklearn.metrics import mean_squared_error

# %%
#import data
df = pd.read_csv('./Sub0-RAW.csv')
df.head()
# Out:
#        Dates  Year  Month  Day    Hours  Precipitation  Temperature  Outflow
# 0  10/1/1980  1980     10    1  0:00:00            0.0      102.992      5.0
# 1  10/1/1980  1980     10    1  1:00:00            0.0       97.790      5.0
# 2  10/1/1980  1980     10    1  2:00:00            0.0       92.588      5.0
# 3  10/1/1980  1980     10    1  3:00:00            0.0       87.404      5.0
# 4  10/1/1980  1980     10    1  4:00:00            0.0       85.172      5.0

# %%
#define train and label column
train_cols = ["Precipitation","Temperature", "Outflow"]
label_cols = ["Precipitation(t+1)","Temperature(t+1)"]

# %%
#filter the columns
new_df = df.filter(train_cols, axis=1)

# %%
#Min Max scalr normalizing
xtrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
xtest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))

# %%
#function to shift the time_series data for getting labels
def lag_seq(df, n_seq):
    for i in range(n_seq):
        df['Precipitation(t+%d)' %(i+1)] = new_df['Precipitation'].shift(-(i+1))
        df['Temperature(t+%d)' %(i+1)] = new_df['Temperature'].shift(-(i+1))        
        df['Outflow(t+%d)' %(i+1)] = new_df['Outflow'].shift(-(i+1))
    return df

# building timeseries data with given timesteps
def timeseries(X, Y, Y_actual, time_steps, out_steps):
    input_size_0 = X.shape[0] - time_steps
    input_size_1 = X.shape[1]
    output_size_0 = Y.shape[0] - time_steps
    output_size_1 = Y.shape[1]
    X_values = np.zeros((input_size_0, time_steps, input_size_1))
    Y_values = np.zeros((output_size_0, output_size_1))
    Y_values_actual = np.zeros((output_size_0, output_size_1))
    
    for i in tqdm_notebook(range(input_size_0)):
        X_values[i] = X[i:time_steps+i]
        Y_values[i] = Y[time_steps+i-1]
        Y_values_actual[i] = Y_actual[time_steps+i-1]
        
    print("length of time-series i/o",X_values.shape,Y_values.shape)
    return X_values, Y_values, Y_values_actual

#getting data ready for training the model
def data_processing(lag_df):
    #Splitting training and test data
    df_train, df_test = train_test_split(lag_df, train_size=0.8, test_size=0.2, shuffle=False)
    x_train = df_train.loc[:,train_cols].values
    y_train = df_train.loc[:,label_cols].values
    x_test = df_test.loc[:,train_cols].values
    y_test = df_test.loc[:,label_cols].values    
   
    #Normalizing training data
    x_train_nor = xtrain_min_max_scaler.fit_transform(x_train)
    y_train_nor = ytrain_min_max_scaler.fit_transform(y_train)

    # Normalizing test data
    x_test_nor = xtest_min_max_scaler.fit_transform(x_test)
    y_test_nor = ytest_min_max_scaler.fit_transform(y_test)
    
    # Saving actual train and test y_label
    y_train_actual = y_train
    y_test_actual = y_test
    
    return x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual

# %%
#calling function to create lag dataframe
lag_df = lag_seq(new_df, 2)
lag_df.dropna(inplace=True)

# %%
lag_df
# Out:
#         Precipitation  Temperature  ...  Temperature(t+2)  Outflow(t+2)
# 0                 0.0      102.992  ...            92.588           5.0
# 1                 0.0       97.790  ...            87.404           5.0
# 2                 0.0       92.588  ...            85.172           5.0
# 3                 0.0       87.404  ...            82.940           5.0
# 4                 0.0       85.172  ...            80.708           5.0
# ...               ...          ...  ...               ...           ...
# 185537            0.0       50.054  ...            54.284          30.0
# 185538            0.0       52.880  ...            55.670          29.0
# 185539            0.0       54.284  ...            57.074          29.0
# 185540            0.0       55.670  ...            57.056          31.0
# 185541            0.0       57.074  ...            57.020          38.0
#
# [185542 rows x 9 columns]

# %%
#Building timeseries
x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual = data_processing(lag_df)
X_Train, Y_Train, Y_train_actual = timeseries(x_train_nor, y_train_nor, y_train_actual, time_steps=18, out_steps=1)
X_Test, Y_Test, Y_test_actual = timeseries(x_test_nor, y_test_nor, y_test_actual, time_steps=18, out_steps=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=148415.0), HTML(value='')))
# length of time-series i/o (148415, 18, 3) (148415, 2)
# HBox(children=(FloatProgress(value=0.0, max=37091.0), HTML(value='')))
# length of time-series i/o (37091, 18, 3) (37091, 2)

# %%
#Build Model
def make_model(X_Train):
    input_layer = Input(shape=(X_Train.shape[1], X_Train.shape[2]))

    lstm1 = LSTM(units=16, return_sequences=True)(input_layer)
    dropout1 = Dropout(0.2)(lstm1)
    lstm2 = LSTM(units=32, return_sequences=True)(dropout1)
    dropout2 = Dropout(0.2)(lstm2)
    lstm3 = LSTM(units=64)(dropout2)
    dropout3 = Dropout(0.2)(lstm3)

    dense1 = Dense(128, activation='relu')(dropout3)
    dense2 = Dense(64, activation='relu')(dense1)
    output_layer = Dense(2, activation='linear')(dense2)
    
    return Model(inputs=input_layer, outputs=output_layer)

# %%
mse_for_iter = []
train_loss_over_epoch = []
val_loss_over_epoch = []

def run_iteration(no_iter=20, epochs = 10):
    start_time = time.time()
    for iteration in range(no_iter):
        print(f'Iteration: {iteration + 1}')
        K.clear_session()
        model = make_model(X_Train)
        #plot_model(model, show_shapes=True)
        model.compile(optimizer = 'adam', loss = 'mean_squared_error')
        history = model.fit(X_Train, Y_Train, epochs=epochs,
                       validation_data=(X_Test, Y_Test))
        train_loss_over_epoch.append(history.history['loss'])
        val_loss_over_epoch.append(history.history['val_loss'])
        predicted_y_values = model.predict(X_Test)
        predicted_y_values_unnor = ytrain_min_max_scaler.inverse_transform(predicted_y_values)
        mse_for_iter.append(mean_squared_error(predicted_y_values_unnor, Y_test_actual))
               
    end_time = time.time()
    print('--------------------------\n')
    print(f'Starting time: {start_time}')
    print(f'Completing time: {end_time}')
    print(f'It took {(start_time - end_time)/60} minutes to train the model for {no_iter} iterations')
    #return predicted unnormalized values for test set from last iteration 
    return predicted_y_values, predicted_y_values_unnor, model

predicted_y_values, predicted_y_values_unnor, model = run_iteration(1,10)
# Out:
# Iteration: 1
# Epoch 1/10
# 4638/4638 [==============================] - 50s 9ms/step - loss: 0.0038 - val_loss: 2.7644e-04
# Epoch 2/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.2653e-04 - val_loss: 2.2701e-04
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.6965e-04 - val_loss: 6.0471e-04
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.2402e-04 - val_loss: 9.4330e-04
# Epoch 5/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 1.9977e-04 - val_loss: 8.7298e-04
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 1.9189e-04 - val_loss: 8.8912e-04
# Epoch 7/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 1.7493e-04 - val_loss: 0.0012
# Epoch 8/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 1.7538e-04 - val_loss: 0.0012
# Epoch 9/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 1.6111e-04 - val_loss: 8.9253e-04
# Epoch 10/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 1.5670e-04 - val_loss: 0.0012
# --------------------------
#
# Starting time: 1613050518.1695647
# Completing time: 1613050931.7400174
# It took -6.892840878168742 minutes to train the model for 1 iterations

# %%
#prediction for X_Train values which has to be used to predict another day output
y_train_predict = model.predict(X_Train)

# %%
#define train and label column for day 2
train_cols = ["Precipitation","Temperature"]
label_cols = ["Outflow(t+2)"]

# %%
#Building timeseries for day 2
time_steps = 18
x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual = data_processing(lag_df)
X_Train, Y_Train, Y_train_actual = timeseries(x_train_nor, y_train_nor, y_train_actual, time_steps=18, out_steps=1)
X_Test, Y_Test, Y_test_actual = timeseries(x_test_nor, y_test_nor, y_test_actual, time_steps=18, out_steps=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=148415.0), HTML(value='')))
# length of time-series i/o (148415, 18, 2) (148415, 1)
# HBox(children=(FloatProgress(value=0.0, max=37091.0), HTML(value='')))
# length of time-series i/o (37091, 18, 2) (37091, 1)

# %%
#preparing timeseries for day2 data
train_input_size_0 = X_Train.shape[0]
test_input_size_0 = X_Test.shape[0]
input_size_2 = X_Train.shape[2]
output_size_0 = Y_Train.shape[0]
output_size_1 = Y_Train.shape[1]
X_Train1 = np.zeros((train_input_size_0, time_steps+1, input_size_2))
X_Test1 = np.zeros((test_input_size_0, time_steps+1, input_size_2))

#replacing last value of each timeseries data with the predicted value
len_data = len(X_Train1)
for i in range (len_data):
    #reshaping y_train_predict to make both values under concatenation of same shape 
    X_Train1[i] = np.concatenate((X_Train[i], y_train_predict[i].reshape(1,2)), axis=0) 
len_data_test = len(X_Test)
for i in range (len_data_test):
    X_Test1[i] = np.concatenate((X_Test[i],predicted_y_values[i].reshape(1,2)), axis=0)

# %%
#Build Model for day 2
def make_model1(X_Train):
    input_layer = Input(shape=(X_Train.shape[1], X_Train.shape[2]))

    lstm1 = LSTM(units=16, return_sequences=True)(input_layer)
    dropout1 = Dropout(0.2)(lstm1)
    lstm2 = LSTM(units=32, return_sequences=True)(dropout1)
    dropout2 = Dropout(0.2)(lstm2)
    lstm3 = LSTM(units=64)(dropout2)
    dropout3 = Dropout(0.2)(lstm3)

    dense1 = Dense(128, activation='relu')(dropout3)
    dense2 = Dense(64, activation='relu')(dense1)
    output_layer = Dense(1, activation='linear')(dense2)
    
    return Model(inputs=input_layer, outputs=output_layer)

# %%
mse_for_iter1 = []
train_loss_over_epoch1 = []
val_loss_over_epoch1 = []
predicted_y_values1_unnors = []
models = []

def run_iteration_model_2(no_iter=20, epochs = 10):
    start_time = time.time()
    for iteration in range(no_iter):
        print(f'Iteration: {iteration + 1}')
        K.clear_session()
        model1 = make_model1(X_Train1)
        #plot_model(model, show_shapes=True)
        model1.compile(optimizer = 'adam', loss = 'mean_squared_error')
        history = model1.fit(X_Train1, Y_Train, epochs=epochs,
                       validation_data=(X_Test1, Y_Test))
        train_loss_over_epoch1.append(history.history['loss'])
        val_loss_over_epoch1.append(history.history['val_loss'])
        predicted_y_values1 = model1.predict(X_Test1)
        predicted_y_values1_unnor = ytrain_min_max_scaler.inverse_transform(predicted_y_values1)
        mse_for_iter1.append(mean_squared_error(predicted_y_values1_unnor, Y_test_actual))
        predicted_y_values1_unnors.append(predicted_y_values1_unnor)
        models.append(model1)
               
    end_time = time.time()
    print('--------------------------\n')
    print(f'Starting time: {start_time}')
    print(f'Completing time: {end_time}')
    print(f'It took {(start_time - end_time)/60} minutes to train the model for {no_iter} iterations')
    #return predicted unnormalized values for test set from last iteration 
    return predicted_y_values1, predicted_y_values1_unnor, model1

predicted_y_values1, predicted_y_values1_unnor, model1 = run_iteration_model_2(20,10)
# Out:
# Iteration: 1
# Epoch 1/10
# 4638/4638 [==============================] - 44s 9ms/step - loss: 6.8110e-04 - val_loss: 0.0013
# Epoch 2/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 5.7063e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.6055e-04 - val_loss: 5.7921e-04
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.2866e-04 - val_loss: 4.6674e-04
# Epoch 5/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.2268e-04 - val_loss: 4.3164e-04
# Epoch 6/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.7677e-04 - val_loss: 5.4035e-04
# Epoch 7/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.8734e-04 - val_loss: 4.6321e-04
# Epoch 8/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.7008e-04 - val_loss: 5.7684e-04
# Epoch 9/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.8711e-04 - val_loss: 3.9614e-04
# Epoch 10/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.5063e-04 - val_loss: 4.0132e-04
# Iteration: 2
# Epoch 1/10
# 4638/4638 [==============================] - 44s 9ms/step - loss: 7.0149e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 5.5380e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 4.8581e-04 - val_loss: 7.0908e-04
# Epoch 4/10
# 4638/4638 [==============================] - 39s 9ms/step - loss: 3.2665e-04 - val_loss: 5.9598e-04
# Epoch 5/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.4346e-04 - val_loss: 4.7752e-04
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.9592e-04 - val_loss: 4.9594e-04
# Epoch 7/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.0026e-04 - val_loss: 4.9944e-04
# Epoch 8/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.1076e-04 - val_loss: 4.1266e-04
# Epoch 9/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.6038e-04 - val_loss: 4.6249e-04
# Epoch 10/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.6029e-04 - val_loss: 4.5670e-04
# Iteration: 3
# Epoch 1/10
# 4638/4638 [==============================] - 44s 9ms/step - loss: 7.5949e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.2907e-04 - val_loss: 0.0010
# Epoch 3/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 4.8460e-04 - val_loss: 5.8819e-04
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.6848e-04 - val_loss: 7.2999e-04
# Epoch 5/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.1545e-04 - val_loss: 7.4152e-04
# Epoch 6/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.0366e-04 - val_loss: 4.8634e-04
# Epoch 7/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.8566e-04 - val_loss: 5.0045e-04
# Epoch 8/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.8254e-04 - val_loss: 4.3973e-04
# Epoch 9/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.7536e-04 - val_loss: 4.0435e-04
# Epoch 10/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.8291e-04 - val_loss: 4.1022e-04
# Iteration: 4
# Epoch 1/10
# 4638/4638 [==============================] - 45s 9ms/step - loss: 6.5721e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 5.2555e-04 - val_loss: 9.6765e-04
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 4.7345e-04 - val_loss: 5.7585e-04
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.5744e-04 - val_loss: 4.7365e-04
# Epoch 5/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.0698e-04 - val_loss: 5.1924e-04
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.1882e-04 - val_loss: 4.8401e-04
# Epoch 7/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.9486e-04 - val_loss: 4.6831e-04
# Epoch 8/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.8458e-04 - val_loss: 5.0741e-04
# Epoch 9/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.7936e-04 - val_loss: 4.5143e-04
# Epoch 10/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.8755e-04 - val_loss: 4.2657e-04
# Iteration: 5
# Epoch 1/10
# 4638/4638 [==============================] - 46s 9ms/step - loss: 7.0150e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.2020e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 4.9644e-04 - val_loss: 4.5936e-04
# Epoch 4/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.3874e-04 - val_loss: 4.4254e-04
# Epoch 5/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.0448e-04 - val_loss: 4.5568e-04
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.9217e-04 - val_loss: 4.5122e-04
# Epoch 7/10
# 4638/4638 [==============================] - 42s 9ms/step - loss: 2.8376e-04 - val_loss: 4.4707e-04
# Epoch 8/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.7468e-04 - val_loss: 4.6959e-04
# Epoch 9/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.7765e-04 - val_loss: 4.3669e-04
# Epoch 10/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.6538e-04 - val_loss: 4.6691e-04
# Iteration: 6
# Epoch 1/10
# 4638/4638 [==============================] - 44s 9ms/step - loss: 6.5347e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 5.5961e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.1992e-04 - val_loss: 5.2150e-04
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.3786e-04 - val_loss: 5.0507e-04
# Epoch 5/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.2133e-04 - val_loss: 5.2932e-04
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.0759e-04 - val_loss: 4.1501e-04
# Epoch 7/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.8781e-04 - val_loss: 4.2297e-04
# Epoch 8/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.9025e-04 - val_loss: 4.3372e-04
# Epoch 9/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.4978e-04 - val_loss: 3.9751e-04
# Epoch 10/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.5717e-04 - val_loss: 4.4727e-04
# Iteration: 7
# Epoch 1/10
# 4638/4638 [==============================] - 44s 9ms/step - loss: 7.3929e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 5.6357e-04 - val_loss: 0.0010
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 4.6893e-04 - val_loss: 5.3181e-04
# Epoch 4/10
# 4638/4638 [==============================] - 39s 9ms/step - loss: 3.3917e-04 - val_loss: 4.9167e-04
# Epoch 5/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.2479e-04 - val_loss: 4.4685e-04
# Epoch 6/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.3322e-04 - val_loss: 4.2481e-04
# Epoch 7/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.0243e-04 - val_loss: 5.0828e-04
# Epoch 8/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.7968e-04 - val_loss: 4.5505e-04
# Epoch 9/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.7092e-04 - val_loss: 4.2289e-04
# Epoch 10/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.4694e-04 - val_loss: 4.1929e-04
# Iteration: 8
# Epoch 1/10
# 4638/4638 [==============================] - 45s 9ms/step - loss: 7.3420e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.6412e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 5.0238e-04 - val_loss: 6.3276e-04
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.9047e-04 - val_loss: 4.5670e-04
# Epoch 5/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.2508e-04 - val_loss: 4.8747e-04
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.3785e-04 - val_loss: 4.3062e-04
# Epoch 7/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.8598e-04 - val_loss: 4.8230e-04
# Epoch 8/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.9628e-04 - val_loss: 5.1301e-04
# Epoch 9/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.8146e-04 - val_loss: 4.3107e-04
# Epoch 10/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.7722e-04 - val_loss: 4.3881e-04
# Iteration: 9
# Epoch 1/10
# 4638/4638 [==============================] - 43s 9ms/step - loss: 6.9253e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 5.3231e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.2686e-04 - val_loss: 5.4625e-04
# Epoch 4/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.5142e-04 - val_loss: 5.0592e-04
# Epoch 5/10
# 4638/4638 [==============================] - 42s 9ms/step - loss: 3.3452e-04 - val_loss: 5.1962e-04
# Epoch 6/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.1620e-04 - val_loss: 5.0282e-04
# Epoch 7/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.9796e-04 - val_loss: 4.6343e-04
# Epoch 8/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.9852e-04 - val_loss: 5.2484e-04
# Epoch 9/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.7136e-04 - val_loss: 4.6140e-04
# Epoch 10/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.7145e-04 - val_loss: 4.9655e-04
# Iteration: 10
# Epoch 1/10
# 4638/4638 [==============================] - 44s 9ms/step - loss: 6.7454e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 39s 9ms/step - loss: 5.6574e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.1239e-04 - val_loss: 8.8388e-04
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.7525e-04 - val_loss: 4.7505e-04
# Epoch 5/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.5326e-04 - val_loss: 6.1744e-04
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.9238e-04 - val_loss: 4.4838e-04
# Epoch 7/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.9945e-04 - val_loss: 4.4307e-04
# Epoch 8/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.0133e-04 - val_loss: 4.2023e-04
# Epoch 9/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.7172e-04 - val_loss: 4.2923e-04
# Epoch 10/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.0052e-04 - val_loss: 4.3657e-04
# Iteration: 11
# Epoch 1/10
# 4638/4638 [==============================] - 44s 9ms/step - loss: 7.0996e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 5.4576e-04 - val_loss: 0.0010
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 4.7270e-04 - val_loss: 5.3299e-04
# Epoch 4/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.6434e-04 - val_loss: 4.8665e-04
# Epoch 5/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.3073e-04 - val_loss: 4.1405e-04
# Epoch 6/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.9113e-04 - val_loss: 5.5186e-04
# Epoch 7/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.8664e-04 - val_loss: 4.2227e-04
# Epoch 8/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.9125e-04 - val_loss: 4.5164e-04
# Epoch 9/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.9441e-04 - val_loss: 4.3279e-04
# Epoch 10/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.5469e-04 - val_loss: 4.0644e-04
# Iteration: 12
# Epoch 1/10
# 4638/4638 [==============================] - 45s 9ms/step - loss: 6.7814e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.4575e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 5.3237e-04 - val_loss: 7.8976e-04
# Epoch 4/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.6628e-04 - val_loss: 4.7425e-04
# Epoch 5/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.2278e-04 - val_loss: 4.5308e-04
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.0171e-04 - val_loss: 5.3894e-04
# Epoch 7/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.9446e-04 - val_loss: 6.3198e-04
# Epoch 8/10
# 4638/4638 [==============================] - 42s 9ms/step - loss: 2.7597e-04 - val_loss: 4.4219e-04
# Epoch 9/10
# 4638/4638 [==============================] - 42s 9ms/step - loss: 2.6484e-04 - val_loss: 4.0798e-04
# Epoch 10/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.5805e-04 - val_loss: 4.6605e-04
# Iteration: 13
# Epoch 1/10
# 4638/4638 [==============================] - 45s 9ms/step - loss: 7.0922e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.6361e-04 - val_loss: 0.0010
# Epoch 3/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 4.9317e-04 - val_loss: 4.7598e-04
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.5851e-04 - val_loss: 4.9692e-04
# Epoch 5/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.9698e-04 - val_loss: 4.6489e-04
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.1040e-04 - val_loss: 4.3692e-04
# Epoch 7/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.8941e-04 - val_loss: 4.5610e-04
# Epoch 8/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.7210e-04 - val_loss: 4.1807e-04
# Epoch 9/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.7737e-04 - val_loss: 4.4404e-04
# Epoch 10/10
# 4638/4638 [==============================] - 42s 9ms/step - loss: 2.4836e-04 - val_loss: 4.4222e-04
# Iteration: 14
# Epoch 1/10
# 4638/4638 [==============================] - 44s 9ms/step - loss: 7.3118e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.2225e-04 - val_loss: 0.0010
# Epoch 3/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 5.1292e-04 - val_loss: 5.5028e-04
# Epoch 4/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.7782e-04 - val_loss: 4.7065e-04
# Epoch 5/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.2477e-04 - val_loss: 4.9306e-04
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.0206e-04 - val_loss: 4.2404e-04
# Epoch 7/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.9890e-04 - val_loss: 4.7049e-04
# Epoch 8/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.9729e-04 - val_loss: 4.2257e-04
# Epoch 9/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.7980e-04 - val_loss: 5.2334e-04
# Epoch 10/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.6384e-04 - val_loss: 5.1343e-04
# Iteration: 15
# Epoch 1/10
# 4638/4638 [==============================] - 45s 9ms/step - loss: 6.8884e-04 - val_loss: 0.0013
# Epoch 2/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.4744e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 4.5675e-04 - val_loss: 6.0893e-04
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.4978e-04 - val_loss: 5.7712e-04
# Epoch 5/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.2730e-04 - val_loss: 5.6992e-04
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.2823e-04 - val_loss: 5.0283e-04
# Epoch 7/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.8232e-04 - val_loss: 4.4258e-04
# Epoch 8/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.8959e-04 - val_loss: 4.7277e-04
# Epoch 9/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.5834e-04 - val_loss: 4.6772e-04
# Epoch 10/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.8771e-04 - val_loss: 3.8769e-04
# Iteration: 16
# Epoch 1/10
# 4638/4638 [==============================] - 44s 9ms/step - loss: 7.0191e-04 - val_loss: 0.0012
# Epoch 2/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 5.6026e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 4.5883e-04 - val_loss: 4.9409e-04
# Epoch 4/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.2282e-04 - val_loss: 4.7089e-04
# Epoch 5/10
# 4638/4638 [==============================] - 42s 9ms/step - loss: 3.1192e-04 - val_loss: 4.6216e-04
# Epoch 6/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.9705e-04 - val_loss: 4.5678e-04
# Epoch 7/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.0235e-04 - val_loss: 4.3634e-04
# Epoch 8/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.7817e-04 - val_loss: 4.2719e-04
# Epoch 9/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.8362e-04 - val_loss: 4.4757e-04
# Epoch 10/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.7303e-04 - val_loss: 4.1208e-04
# Iteration: 17
# Epoch 1/10
# 4638/4638 [==============================] - 44s 9ms/step - loss: 7.0214e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.0574e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.4571e-04 - val_loss: 5.2285e-04
# Epoch 4/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.5118e-04 - val_loss: 4.8637e-04
# Epoch 5/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.0457e-04 - val_loss: 4.8881e-04
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.3190e-04 - val_loss: 4.2413e-04
# Epoch 7/10
# 4638/4638 [==============================] - 42s 9ms/step - loss: 2.8686e-04 - val_loss: 4.0741e-04
# Epoch 8/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.8124e-04 - val_loss: 4.3384e-04
# Epoch 9/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.6696e-04 - val_loss: 4.0117e-04
# Epoch 10/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.5284e-04 - val_loss: 4.0257e-04
# Iteration: 18
# Epoch 1/10
# 4638/4638 [==============================] - 46s 9ms/step - loss: 6.6723e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.5510e-04 - val_loss: 0.0010
# Epoch 3/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 4.7664e-04 - val_loss: 4.9990e-04
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.3311e-04 - val_loss: 5.1880e-04
# Epoch 5/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.0489e-04 - val_loss: 5.9955e-04
# Epoch 6/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.1692e-04 - val_loss: 4.8813e-04
# Epoch 7/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.8229e-04 - val_loss: 5.0066e-04
# Epoch 8/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.7983e-04 - val_loss: 4.6266e-04
# Epoch 9/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.7100e-04 - val_loss: 4.1571e-04
# Epoch 10/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.5726e-04 - val_loss: 4.2765e-04
# Iteration: 19
# Epoch 1/10
# 4638/4638 [==============================] - 45s 9ms/step - loss: 7.3011e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.7373e-04 - val_loss: 0.0010
# Epoch 3/10
# 4638/4638 [==============================] - 42s 9ms/step - loss: 5.0232e-04 - val_loss: 4.8594e-04
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.8796e-04 - val_loss: 5.5447e-04
# Epoch 5/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.1356e-04 - val_loss: 4.6070e-04
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.9388e-04 - val_loss: 4.2953e-04
# Epoch 7/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.7033e-04 - val_loss: 4.7271e-04
# Epoch 8/10
# 4638/4638 [==============================] - 42s 9ms/step - loss: 2.9375e-04 - val_loss: 4.2064e-04
# Epoch 9/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.5692e-04 - val_loss: 4.4893e-04
# Epoch 10/10
# 4638/4638 [==============================] - 42s 9ms/step - loss: 2.6215e-04 - val_loss: 4.1441e-04
# Iteration: 20
# Epoch 1/10
# 4638/4638 [==============================] - 45s 9ms/step - loss: 6.3001e-04 - val_loss: 0.0011
# Epoch 2/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.5346e-04 - val_loss: 0.0011
# Epoch 3/10
# 4638/4638 [==============================] - 42s 9ms/step - loss: 4.8087e-04 - val_loss: 7.0210e-04
# Epoch 4/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.3356e-04 - val_loss: 4.3548e-04
# Epoch 5/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.0273e-04 - val_loss: 4.4418e-04
# Epoch 6/10
# 4638/4638 [==============================] - 42s 9ms/step - loss: 2.9997e-04 - val_loss: 4.2928e-04
# Epoch 7/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.1346e-04 - val_loss: 4.9200e-04
# Epoch 8/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.7017e-04 - val_loss: 4.8925e-04
# Epoch 9/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.8008e-04 - val_loss: 4.5528e-04
# Epoch 10/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.5909e-04 - val_loss: 4.2345e-04
# --------------------------
#
# Starting time: 1613050946.2863736
# Completing time: 1613059187.5923057
# It took -137.3550988674164 minutes to train the model for 20 iterations

# %%
model.save("lstm_model2_2_features_pred_tem_all_pred.hdf5")

# %%
def plot_evaluation():
    #mean square error over iterations
    plt.figure(figsize=(15, 10))
    plt.plot(mse_for_iter1)
    plt.ylabel('mean squared error')
    plt.xlabel('iteration')
    plt.savefig('mse.png', bbox_inches='tight')
    plt.show()
        
    #plot train and validation loss over epochs for each iteration
    fig, axs = plt.subplots(10, 2)
    #axs.set_ylabel('loss')
    #axs.set_xlabel('epoch')
    fig.set_size_inches(18.5, 50)
    for row in range(10):
        for col in range(2):
            index = 2*row + col #index to get loss from training loss and validation loss list
            axs[row, col].plot(train_loss_over_epoch1[index])
            axs[row, col].plot(val_loss_over_epoch1[index])
            axs[row, col].set_title('Iteration(%d)' %(index+1))
            axs[row, col].legend(['train', 'Val'], loc='upper left')            
    plt.savefig('train_val_loss.png', bbox_inches='tight')
    
    #plot predicted value vs actual values from last iteration
    plt.figure(figsize=(15, 10))
    plt.plot(predicted_y_values1_unnor, 'ro', alpha=0.8)
    plt.plot(Y_test_actual, 'bo', alpha=0.1)
    plt.legend(['Predicted values', 'Actual values'], loc='upper right')
    plt.ylabel('Outflow')
    plt.xlabel('nth datapoint')
    plt.savefig('predicted_values_visuals.png', bbox_inches='tight')
    plt.show()
    
#call plot_evaluation function
plot_evaluation()

# %%
mse_for_iter1
# Out:
# [1490.9379242538093,
#  1575.6477153726444,
#  1539.8321789919985,
#  1584.485602859882,
#  1733.680567407962,
#  1650.3355122022263,
#  1572.2979770171314,
#  1629.5340919186704,
#  1800.2834591093733,
#  1531.9878083648591,
#  1539.9953229906573,
#  1765.3747721842433,
#  1687.8130610999956,
#  1919.790601500305,
#  1415.9940507928645,
#  1561.0301336438226,
#  1498.7918143878553,
#  1548.5569885167918,
#  1586.5639571430202,
#  1555.8944473498668]

# %%
print(np.mean(mse_for_iter1))
# Out:
# 1609.4413993553992

# %%
plot_model(model1, show_shapes=True)

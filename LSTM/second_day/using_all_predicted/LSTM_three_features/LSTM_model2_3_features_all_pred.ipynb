# %%
#import modules
import numpy as np
import pandas as pd
import time
from keras import backend as K 
from keras.engine.training import Model
from keras.utils import to_categorical, plot_model
from keras.models import Sequential, load_model
from sklearn.preprocessing import MinMaxScaler
from keras.layers.convolutional import Conv1D, Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers import Dropout, Activation, Flatten
from keras.layers import LSTM, Dense, Input
from keras.optimizers import SGD
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tqdm import tqdm_notebook
from sklearn.metrics import mean_squared_error

# %%
#import data
df = pd.read_csv('./Sub0-RAW.csv')
df.head()
# Out:
#        Dates  Year  Month  Day    Hours  Precipitation  Temperature  Outflow
# 0  10/1/1980  1980     10    1  0:00:00            0.0      102.992      5.0
# 1  10/1/1980  1980     10    1  1:00:00            0.0       97.790      5.0
# 2  10/1/1980  1980     10    1  2:00:00            0.0       92.588      5.0
# 3  10/1/1980  1980     10    1  3:00:00            0.0       87.404      5.0
# 4  10/1/1980  1980     10    1  4:00:00            0.0       85.172      5.0

# %%
#define train and label column
train_cols = ["Precipitation","Temperature","Outflow"]
label_cols = ["Precipitation(t+1)","Temperature(t+1)","Outflow(t+1)"]

# %%
#filter the columns
new_df = df.filter(train_cols, axis=1)

# %%
#Min Max scalr normalizing
xtrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytrain_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
xtest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))
ytest_min_max_scaler = MinMaxScaler(feature_range = (0, 1))

# %%
#function to shift the time_series data for getting labels
def lag_seq(df, n_seq):
    for i in range(n_seq):
        df['Precipitation(t+%d)' %(i+1)] = new_df['Precipitation'].shift(-(i+1))
        df['Temperature(t+%d)' %(i+1)] = new_df['Temperature'].shift(-(i+1))        
        df['Outflow(t+%d)' %(i+1)] = new_df['Outflow'].shift(-(i+1))
    return df

# building timeseries data with given timesteps
def timeseries(X, Y, Y_actual, time_steps, out_steps):
    input_size_0 = X.shape[0] - time_steps
    input_size_1 = X.shape[1]
    output_size_0 = Y.shape[0] - time_steps
    output_size_1 = Y.shape[1]
    X_values = np.zeros((input_size_0, time_steps, input_size_1))
    Y_values = np.zeros((output_size_0, output_size_1))
    Y_values_actual = np.zeros((output_size_0, output_size_1))
    
    for i in tqdm_notebook(range(input_size_0)):
        X_values[i] = X[i:time_steps+i]
        Y_values[i] = Y[time_steps+i-1]
        Y_values_actual[i] = Y_actual[time_steps+i-1]
        
    print("length of time-series i/o",X_values.shape,Y_values.shape)
    return X_values, Y_values, Y_values_actual

#getting data ready for training the model
def data_processing(lag_df):
    #Splitting training and test data
    df_train, df_test = train_test_split(lag_df, train_size=0.8, test_size=0.2, shuffle=False)
    x_train = df_train.loc[:,train_cols].values
    y_train = df_train.loc[:,label_cols].values
    x_test = df_test.loc[:,train_cols].values
    y_test = df_test.loc[:,label_cols].values    
   
    #Normalizing training data
    x_train_nor = xtrain_min_max_scaler.fit_transform(x_train)
    y_train_nor = ytrain_min_max_scaler.fit_transform(y_train)

    # Normalizing test data
    x_test_nor = xtest_min_max_scaler.fit_transform(x_test)
    y_test_nor = ytest_min_max_scaler.fit_transform(y_test)
    
    # Saving actual train and test y_label
    y_train_actual = y_train
    y_test_actual = y_test
    
    return x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual

# %%
#calling function to create lag dataframe
lag_df = lag_seq(new_df, 2)
lag_df.dropna(inplace=True)

# %%
lag_df
# Out:
#         Precipitation  Temperature  ...  Temperature(t+2)  Outflow(t+2)
# 0                 0.0      102.992  ...            92.588           5.0
# 1                 0.0       97.790  ...            87.404           5.0
# 2                 0.0       92.588  ...            85.172           5.0
# 3                 0.0       87.404  ...            82.940           5.0
# 4                 0.0       85.172  ...            80.708           5.0
# ...               ...          ...  ...               ...           ...
# 185537            0.0       50.054  ...            54.284          30.0
# 185538            0.0       52.880  ...            55.670          29.0
# 185539            0.0       54.284  ...            57.074          29.0
# 185540            0.0       55.670  ...            57.056          31.0
# 185541            0.0       57.074  ...            57.020          38.0
#
# [185542 rows x 9 columns]

# %%
#Building timeseries
x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual = data_processing(lag_df)
X_Train, Y_Train, Y_train_actual = timeseries(x_train_nor, y_train_nor, y_train_actual, time_steps=18, out_steps=1)
X_Test, Y_Test, Y_test_actual = timeseries(x_test_nor, y_test_nor, y_test_actual, time_steps=18, out_steps=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=148415.0), HTML(value='')))
# length of time-series i/o (148415, 18, 3) (148415, 3)
# HBox(children=(FloatProgress(value=0.0, max=37091.0), HTML(value='')))
# length of time-series i/o (37091, 18, 3) (37091, 3)

# %%
#Build Model
def make_model(X_Train):
    input_layer = Input(shape=(X_Train.shape[1], X_Train.shape[2]))

    lstm1 = LSTM(units=16, return_sequences=True)(input_layer)
    dropout1 = Dropout(0.2)(lstm1)
    lstm2 = LSTM(units=32, return_sequences=True)(dropout1)
    dropout2 = Dropout(0.2)(lstm2)
    lstm3 = LSTM(units=64)(dropout2)
    dropout3 = Dropout(0.2)(lstm3)

    dense1 = Dense(128, activation='relu')(dropout3)
    dense2 = Dense(64, activation='relu')(dense1)
    output_layer = Dense(3, activation='linear')(dense2)
    
    return Model(inputs=input_layer, outputs=output_layer)

# %%
mse_for_iter = []
train_loss_over_epoch = []
val_loss_over_epoch = []

def run_iteration(no_iter=20, epochs = 10):
    start_time = time.time()
    for iteration in range(no_iter):
        print(f'Iteration: {iteration + 1}')
        K.clear_session()
        model = make_model(X_Train)
        #plot_model(model, show_shapes=True)
        model.compile(optimizer = 'adam', loss = 'mean_squared_error')
        history = model.fit(X_Train, Y_Train, epochs=epochs,
                       validation_data=(X_Test, Y_Test))
        train_loss_over_epoch.append(history.history['loss'])
        val_loss_over_epoch.append(history.history['val_loss'])
        predicted_y_values = model.predict(X_Test)
        predicted_y_values_unnor = ytrain_min_max_scaler.inverse_transform(predicted_y_values)
        mse_for_iter.append(mean_squared_error(predicted_y_values_unnor, Y_test_actual))
               
    end_time = time.time()
    print('--------------------------\n')
    print(f'Starting time: {start_time}')
    print(f'Completing time: {end_time}')
    print(f'It took {(start_time - end_time)/60} minutes to train the model for {no_iter} iterations')
    #return predicted unnormalized values for test set from last iteration 
    return predicted_y_values, predicted_y_values_unnor, model

predicted_y_values, predicted_y_values_unnor, model = run_iteration(1,10)
# Out:
# Iteration: 1
# Epoch 1/10
# 4638/4638 [==============================] - 49s 8ms/step - loss: 0.0025 - val_loss: 2.1612e-04
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.6034e-04 - val_loss: 2.1566e-04
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.2381e-04 - val_loss: 1.4409e-04
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.8607e-04 - val_loss: 1.6697e-04
# Epoch 5/10
# 4638/4638 [==============================] - 36s 8ms/step - loss: 1.6446e-04 - val_loss: 2.3711e-04
# Epoch 6/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.4845e-04 - val_loss: 4.6220e-04
# Epoch 7/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.4152e-04 - val_loss: 6.0789e-04
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 1.3977e-04 - val_loss: 4.5962e-04
# Epoch 9/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.3561e-04 - val_loss: 5.3972e-04
# Epoch 10/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 1.2371e-04 - val_loss: 6.3602e-04
# --------------------------
#
# Starting time: 1613003359.0490613
# Completing time: 1613003753.66216
# It took -6.576884977022806 minutes to train the model for 1 iterations

# %%
#prediction for X_Train values which has to be used to predict another day output
y_train_predict = model.predict(X_Train)

# %%
#define train and label column for day 2
train_cols = ["Precipitation","Temperature","Outflow"]
label_cols = ["Outflow(t+2)"]

# %%
#Building timeseries for day 2
time_steps = 18
x_train_nor, y_train_nor, y_train_actual, x_test_nor, y_test_nor, y_test_actual = data_processing(lag_df)
X_Train, Y_Train, Y_train_actual = timeseries(x_train_nor, y_train_nor, y_train_actual, time_steps=18, out_steps=1)
X_Test, Y_Test, Y_test_actual = timeseries(x_test_nor, y_test_nor, y_test_actual, time_steps=18, out_steps=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=148415.0), HTML(value='')))
# length of time-series i/o (148415, 18, 3) (148415, 1)
# HBox(children=(FloatProgress(value=0.0, max=37091.0), HTML(value='')))
# length of time-series i/o (37091, 18, 3) (37091, 1)

# %%
#preparing timeseries for day2 data
train_input_size_0 = X_Train.shape[0]
test_input_size_0 = X_Test.shape[0]
input_size_2 = X_Train.shape[2]
output_size_0 = Y_Train.shape[0]
output_size_1 = Y_Train.shape[1]
X_Train1 = np.zeros((train_input_size_0, time_steps+1, input_size_2))
X_Test1 = np.zeros((test_input_size_0, time_steps+1, input_size_2))

#replacing last value of each timeseries data with the predicted value
len_data = len(X_Train1)
for i in range (len_data):
    #reshaping y_train_predict to make both values under concatenation of same shape 
    X_Train1[i] = np.concatenate((X_Train[i], y_train_predict[i].reshape(1,3)), axis=0) 
len_data_test = len(X_Test)
for i in range (len_data_test):
    X_Test1[i] = np.concatenate((X_Test[i],predicted_y_values[i].reshape(1,3)), axis=0)

# %%
#Build Model for day 2
def make_model1(X_Train):
    input_layer = Input(shape=(X_Train.shape[1], X_Train.shape[2]))

    lstm1 = LSTM(units=16, return_sequences=True)(input_layer)
    dropout1 = Dropout(0.2)(lstm1)
    lstm2 = LSTM(units=32, return_sequences=True)(dropout1)
    dropout2 = Dropout(0.2)(lstm2)
    lstm3 = LSTM(units=64)(dropout2)
    dropout3 = Dropout(0.2)(lstm3)

    dense1 = Dense(128, activation='relu')(dropout3)
    dense2 = Dense(64, activation='relu')(dense1)
    output_layer = Dense(1, activation='linear')(dense2)
    
    return Model(inputs=input_layer, outputs=output_layer)

# %%
mse_for_iter1 = []
train_loss_over_epoch1 = []
val_loss_over_epoch1 = []
predicted_y_values1_unnors = []
models = []

def run_iteration_model_2(no_iter=20, epochs = 10):
    start_time = time.time()
    for iteration in range(no_iter):
        print(f'Iteration: {iteration + 1}')
        K.clear_session()
        model1 = make_model1(X_Train1)
        #plot_model(model, show_shapes=True)
        model1.compile(optimizer = 'adam', loss = 'mean_squared_error')
        history = model1.fit(X_Train1, Y_Train, epochs=epochs,
                       validation_data=(X_Test1, Y_Test))
        train_loss_over_epoch1.append(history.history['loss'])
        val_loss_over_epoch1.append(history.history['val_loss'])
        predicted_y_values1 = model1.predict(X_Test1)
        predicted_y_values1_unnor = ytrain_min_max_scaler.inverse_transform(predicted_y_values1)
        mse_for_iter1.append(mean_squared_error(predicted_y_values1_unnor, Y_test_actual))
        predicted_y_values1_unnors.append(predicted_y_values1_unnor)
        models.append(model1)
               
    end_time = time.time()
    print('--------------------------\n')
    print(f'Starting time: {start_time}')
    print(f'Completing time: {end_time}')
    print(f'It took {(start_time - end_time)/60} minutes to train the model for {no_iter} iterations')
    #return predicted unnormalized values for test set from last iteration 
    return predicted_y_values1, predicted_y_values1_unnor, model1

predicted_y_values1, predicted_y_values1_unnor, model1 = run_iteration_model_2(20,10)
# Out:
# Iteration: 1
# Epoch 1/10
# 4638/4638 [==============================] - 44s 9ms/step - loss: 2.6557e-04 - val_loss: 8.6546e-05
# Epoch 2/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 7.4491e-05 - val_loss: 5.5612e-05
# Epoch 3/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 5.2991e-05 - val_loss: 4.1077e-05
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 4.3159e-05 - val_loss: 5.6152e-05
# Epoch 5/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 4.5433e-05 - val_loss: 3.2611e-05
# Epoch 6/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.5697e-05 - val_loss: 5.8220e-05
# Epoch 7/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.2237e-05 - val_loss: 2.1411e-05
# Epoch 8/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.8683e-05 - val_loss: 1.9828e-05
# Epoch 9/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.9634e-05 - val_loss: 3.0663e-05
# Epoch 10/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.5928e-05 - val_loss: 2.6569e-05
# Iteration: 2
# Epoch 1/10
# 4638/4638 [==============================] - 42s 8ms/step - loss: 2.5905e-04 - val_loss: 9.5121e-05
# Epoch 2/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 6.0249e-05 - val_loss: 6.8955e-05
# Epoch 3/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 5.7649e-05 - val_loss: 4.1332e-05
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 4.7812e-05 - val_loss: 3.9473e-05
# Epoch 5/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.9741e-05 - val_loss: 4.3126e-05
# Epoch 6/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 4.1280e-05 - val_loss: 7.9068e-05
# Epoch 7/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.4377e-05 - val_loss: 3.5015e-05
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.0434e-05 - val_loss: 1.8587e-05
# Epoch 9/10
# 4638/4638 [==============================] - 39s 9ms/step - loss: 2.5105e-05 - val_loss: 3.9779e-05
# Epoch 10/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.7436e-05 - val_loss: 2.0250e-05
# Iteration: 3
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 2.6039e-04 - val_loss: 1.0336e-04
# Epoch 2/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 7.6090e-05 - val_loss: 4.7530e-05
# Epoch 3/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 5.9069e-05 - val_loss: 9.3737e-05
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 4.9834e-05 - val_loss: 4.1166e-05
# Epoch 5/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.5933e-05 - val_loss: 3.9446e-05
# Epoch 6/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.2450e-05 - val_loss: 2.5656e-05
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.4510e-05 - val_loss: 3.2699e-05
# Epoch 8/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.6395e-05 - val_loss: 5.9004e-05
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.6124e-05 - val_loss: 1.9857e-05
# Epoch 10/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.5207e-05 - val_loss: 4.4431e-05
# Iteration: 4
# Epoch 1/10
# 4638/4638 [==============================] - 42s 8ms/step - loss: 2.4511e-04 - val_loss: 8.6223e-05
# Epoch 2/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 7.0731e-05 - val_loss: 6.7550e-05
# Epoch 3/10
# 4638/4638 [==============================] - 39s 9ms/step - loss: 4.8103e-05 - val_loss: 8.9825e-05
# Epoch 4/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 4.3590e-05 - val_loss: 3.2200e-05
# Epoch 5/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 4.1882e-05 - val_loss: 7.2268e-05
# Epoch 6/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.4373e-05 - val_loss: 2.6080e-05
# Epoch 7/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.4479e-05 - val_loss: 2.4276e-05
# Epoch 8/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.6691e-05 - val_loss: 5.3261e-05
# Epoch 9/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.9622e-05 - val_loss: 2.8191e-05
# Epoch 10/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.8281e-05 - val_loss: 1.9307e-05
# Iteration: 5
# Epoch 1/10
# 4638/4638 [==============================] - 43s 9ms/step - loss: 2.8196e-04 - val_loss: 6.0560e-05
# Epoch 2/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 8.4115e-05 - val_loss: 8.9246e-05
# Epoch 3/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 4.9846e-05 - val_loss: 4.2658e-05
# Epoch 4/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 4.2283e-05 - val_loss: 9.1047e-05
# Epoch 5/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.8783e-05 - val_loss: 4.0919e-05
# Epoch 6/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.4284e-05 - val_loss: 6.1914e-05
# Epoch 7/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.4174e-05 - val_loss: 2.1641e-05
# Epoch 8/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.8108e-05 - val_loss: 1.8185e-05
# Epoch 9/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.7696e-05 - val_loss: 1.8918e-04
# Epoch 10/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.1999e-05 - val_loss: 1.7884e-05
# Iteration: 6
# Epoch 1/10
# 4638/4638 [==============================] - 42s 8ms/step - loss: 2.2633e-04 - val_loss: 1.2126e-04
# Epoch 2/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 8.3943e-05 - val_loss: 5.9449e-05
# Epoch 3/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 5.2222e-05 - val_loss: 3.5651e-05
# Epoch 4/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 4.5504e-05 - val_loss: 2.8430e-05
# Epoch 5/10
# 4638/4638 [==============================] - 39s 9ms/step - loss: 3.7923e-05 - val_loss: 3.3193e-05
# Epoch 6/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.1940e-05 - val_loss: 2.1571e-05
# Epoch 7/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.9056e-05 - val_loss: 3.1809e-05
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.9142e-05 - val_loss: 9.6679e-05
# Epoch 9/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.9368e-05 - val_loss: 3.0092e-05
# Epoch 10/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.8726e-05 - val_loss: 3.3356e-05
# Iteration: 7
# Epoch 1/10
# 4638/4638 [==============================] - 41s 8ms/step - loss: 2.2599e-04 - val_loss: 9.2151e-05
# Epoch 2/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 7.1811e-05 - val_loss: 6.6486e-05
# Epoch 3/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 4.6688e-05 - val_loss: 4.5640e-05
# Epoch 4/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 4.5250e-05 - val_loss: 3.4613e-05
# Epoch 5/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.8487e-05 - val_loss: 3.6690e-05
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.2729e-05 - val_loss: 2.4695e-05
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.7023e-05 - val_loss: 3.4407e-05
# Epoch 8/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.6917e-05 - val_loss: 1.9750e-05
# Epoch 9/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.8022e-05 - val_loss: 5.4755e-05
# Epoch 10/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.8466e-05 - val_loss: 2.9358e-05
# Iteration: 8
# Epoch 1/10
# 4638/4638 [==============================] - 43s 9ms/step - loss: 2.6525e-04 - val_loss: 1.3433e-04
# Epoch 2/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 6.8719e-05 - val_loss: 6.5964e-05
# Epoch 3/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 5.2607e-05 - val_loss: 4.0797e-05
# Epoch 4/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 4.2337e-05 - val_loss: 3.7897e-05
# Epoch 5/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.6058e-05 - val_loss: 5.0786e-05
# Epoch 6/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 3.9615e-05 - val_loss: 2.6919e-05
# Epoch 7/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.9586e-05 - val_loss: 4.0140e-05
# Epoch 8/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.6340e-05 - val_loss: 2.5838e-05
# Epoch 9/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.6203e-05 - val_loss: 3.4185e-05
# Epoch 10/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.2682e-05 - val_loss: 3.1753e-05
# Iteration: 9
# Epoch 1/10
# 4638/4638 [==============================] - 42s 8ms/step - loss: 2.8032e-04 - val_loss: 9.6855e-05
# Epoch 2/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 7.4607e-05 - val_loss: 6.0688e-05
# Epoch 3/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 5.2606e-05 - val_loss: 4.0005e-05
# Epoch 4/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 5.1212e-05 - val_loss: 3.3071e-05
# Epoch 5/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.8259e-05 - val_loss: 5.3692e-05
# Epoch 6/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.5574e-05 - val_loss: 2.8610e-05
# Epoch 7/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.0749e-05 - val_loss: 2.1626e-05
# Epoch 8/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.8243e-05 - val_loss: 2.2011e-05
# Epoch 9/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.4450e-05 - val_loss: 2.6002e-05
# Epoch 10/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.3628e-05 - val_loss: 2.6948e-05
# Iteration: 10
# Epoch 1/10
# 4638/4638 [==============================] - 43s 9ms/step - loss: 2.5344e-04 - val_loss: 8.7032e-05
# Epoch 2/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 7.8346e-05 - val_loss: 6.9168e-05
# Epoch 3/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 5.1233e-05 - val_loss: 5.1652e-05
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.1838e-05 - val_loss: 3.8300e-05
# Epoch 5/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 4.1469e-05 - val_loss: 2.7288e-05
# Epoch 6/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.7380e-05 - val_loss: 2.5636e-05
# Epoch 7/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.0740e-05 - val_loss: 2.8084e-05
# Epoch 8/10
# 4638/4638 [==============================] - 37s 8ms/step - loss: 2.8713e-05 - val_loss: 2.6989e-05
# Epoch 9/10
# 4638/4638 [==============================] - 39s 9ms/step - loss: 3.7299e-05 - val_loss: 3.8647e-05
# Epoch 10/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.6807e-05 - val_loss: 1.9343e-05
# Iteration: 11
# Epoch 1/10
# 4638/4638 [==============================] - 43s 9ms/step - loss: 2.4415e-04 - val_loss: 7.5632e-05
# Epoch 2/10
# 4638/4638 [==============================] - 39s 9ms/step - loss: 7.4119e-05 - val_loss: 5.3492e-05
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 4.8660e-05 - val_loss: 4.1006e-05
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 4.3967e-05 - val_loss: 3.0889e-05
# Epoch 5/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.4524e-05 - val_loss: 2.6946e-05
# Epoch 6/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.9783e-05 - val_loss: 2.4110e-05
# Epoch 7/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.9375e-05 - val_loss: 4.6098e-05
# Epoch 8/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.6413e-05 - val_loss: 1.1515e-04
# Epoch 9/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.6517e-05 - val_loss: 2.8261e-05
# Epoch 10/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.5177e-05 - val_loss: 2.3367e-05
# Iteration: 12
# Epoch 1/10
# 4638/4638 [==============================] - 43s 9ms/step - loss: 2.4293e-04 - val_loss: 7.2224e-05
# Epoch 2/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 7.4851e-05 - val_loss: 4.5447e-05
# Epoch 3/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 4.7856e-05 - val_loss: 1.1361e-04
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 4.7323e-05 - val_loss: 3.7317e-05
# Epoch 5/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 4.6012e-05 - val_loss: 5.2502e-05
# Epoch 6/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.7465e-05 - val_loss: 2.7645e-05
# Epoch 7/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.2747e-05 - val_loss: 2.2038e-05
# Epoch 8/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.7707e-05 - val_loss: 1.8617e-05
# Epoch 9/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 2.6326e-05 - val_loss: 1.9220e-05
# Epoch 10/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.4721e-05 - val_loss: 1.7628e-05
# Iteration: 13
# Epoch 1/10
# 4638/4638 [==============================] - 42s 8ms/step - loss: 2.2601e-04 - val_loss: 7.5524e-05
# Epoch 2/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 8.4075e-05 - val_loss: 9.8238e-05
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.5822e-05 - val_loss: 4.1285e-05
# Epoch 4/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 4.4830e-05 - val_loss: 3.0222e-05
# Epoch 5/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 4.3748e-05 - val_loss: 2.8240e-05
# Epoch 6/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.8563e-05 - val_loss: 4.7533e-05
# Epoch 7/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 3.2330e-05 - val_loss: 2.9285e-05
# Epoch 8/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.5723e-05 - val_loss: 2.2154e-05
# Epoch 9/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.6600e-05 - val_loss: 2.1965e-05
# Epoch 10/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.5582e-05 - val_loss: 4.4299e-05
# Iteration: 14
# Epoch 1/10
# 4638/4638 [==============================] - 43s 9ms/step - loss: 3.0035e-04 - val_loss: 1.1360e-04
# Epoch 2/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 8.4044e-05 - val_loss: 4.9138e-05
# Epoch 3/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 5.3316e-05 - val_loss: 3.8259e-05
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 4.2092e-05 - val_loss: 2.7880e-05
# Epoch 5/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.8675e-05 - val_loss: 2.8455e-05
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.7653e-05 - val_loss: 3.0745e-05
# Epoch 7/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.6584e-05 - val_loss: 1.9319e-05
# Epoch 8/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.8757e-05 - val_loss: 2.4252e-05
# Epoch 9/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.5224e-05 - val_loss: 2.1326e-05
# Epoch 10/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.6551e-05 - val_loss: 3.5270e-05
# Iteration: 15
# Epoch 1/10
# 4638/4638 [==============================] - 46s 9ms/step - loss: 2.9148e-04 - val_loss: 8.7283e-05
# Epoch 2/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 7.8495e-05 - val_loss: 5.2547e-05
# Epoch 3/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 5.3859e-05 - val_loss: 3.9533e-05
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.4288e-05 - val_loss: 3.1248e-05
# Epoch 5/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.8913e-05 - val_loss: 2.9569e-05
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.8106e-05 - val_loss: 3.1708e-05
# Epoch 7/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.0523e-05 - val_loss: 4.1227e-05
# Epoch 8/10
# 4638/4638 [==============================] - 39s 9ms/step - loss: 3.0142e-05 - val_loss: 4.4339e-05
# Epoch 9/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.3978e-05 - val_loss: 3.1230e-05
# Epoch 10/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.7887e-05 - val_loss: 4.4229e-05
# Iteration: 16
# Epoch 1/10
# 4638/4638 [==============================] - 43s 9ms/step - loss: 2.6545e-04 - val_loss: 1.2109e-04
# Epoch 2/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 7.5360e-05 - val_loss: 6.0966e-05
# Epoch 3/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 5.8281e-05 - val_loss: 4.6874e-05
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 4.8298e-05 - val_loss: 3.4816e-05
# Epoch 5/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 4.5571e-05 - val_loss: 2.9988e-05
# Epoch 6/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.9345e-05 - val_loss: 2.8532e-05
# Epoch 7/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.5771e-05 - val_loss: 6.2589e-05
# Epoch 8/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.4416e-05 - val_loss: 2.4433e-05
# Epoch 9/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.8594e-05 - val_loss: 8.0844e-05
# Epoch 10/10
# 4638/4638 [==============================] - 39s 9ms/step - loss: 2.9040e-05 - val_loss: 2.3880e-05
# Iteration: 17
# Epoch 1/10
# 4638/4638 [==============================] - 44s 9ms/step - loss: 2.4223e-04 - val_loss: 7.9212e-05
# Epoch 2/10
# 4638/4638 [==============================] - 42s 9ms/step - loss: 7.1560e-05 - val_loss: 5.7839e-05
# Epoch 3/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 5.4574e-05 - val_loss: 3.7655e-05
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 5.2241e-05 - val_loss: 7.5478e-05
# Epoch 5/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.8326e-05 - val_loss: 4.9643e-05
# Epoch 6/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.6037e-05 - val_loss: 2.7126e-05
# Epoch 7/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.8921e-05 - val_loss: 4.0557e-05
# Epoch 8/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.1826e-05 - val_loss: 2.0226e-05
# Epoch 9/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.1604e-05 - val_loss: 2.3028e-05
# Epoch 10/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.7565e-05 - val_loss: 5.6934e-05
# Iteration: 18
# Epoch 1/10
# 4638/4638 [==============================] - 45s 9ms/step - loss: 2.3339e-04 - val_loss: 6.7323e-05
# Epoch 2/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 7.3170e-05 - val_loss: 4.7989e-05
# Epoch 3/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 6.1910e-05 - val_loss: 4.2187e-05
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 4.2773e-05 - val_loss: 3.4115e-05
# Epoch 5/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 4.1017e-05 - val_loss: 2.7675e-05
# Epoch 6/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 3.2283e-05 - val_loss: 2.6212e-05
# Epoch 7/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.2006e-05 - val_loss: 2.0868e-05
# Epoch 8/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.5942e-05 - val_loss: 2.1488e-05
# Epoch 9/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.9017e-05 - val_loss: 1.7246e-05
# Epoch 10/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.5377e-05 - val_loss: 2.1678e-05
# Iteration: 19
# Epoch 1/10
# 4638/4638 [==============================] - 42s 8ms/step - loss: 3.1944e-04 - val_loss: 7.0437e-05
# Epoch 2/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 7.3446e-05 - val_loss: 6.6824e-05
# Epoch 3/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 5.6472e-05 - val_loss: 4.6210e-05
# Epoch 4/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 5.0649e-05 - val_loss: 3.6252e-05
# Epoch 5/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.4294e-05 - val_loss: 3.6401e-05
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.6411e-05 - val_loss: 2.5200e-05
# Epoch 7/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.0341e-05 - val_loss: 2.0443e-05
# Epoch 8/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.2003e-05 - val_loss: 4.7193e-05
# Epoch 9/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 2.4697e-05 - val_loss: 2.5034e-05
# Epoch 10/10
# 4638/4638 [==============================] - 41s 9ms/step - loss: 2.4556e-05 - val_loss: 2.1159e-05
# Iteration: 20
# Epoch 1/10
# 4638/4638 [==============================] - 43s 9ms/step - loss: 3.0352e-04 - val_loss: 7.2655e-05
# Epoch 2/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 8.8831e-05 - val_loss: 6.2885e-05
# Epoch 3/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 6.7190e-05 - val_loss: 4.1440e-05
# Epoch 4/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 4.5428e-05 - val_loss: 1.1033e-04
# Epoch 5/10
# 4638/4638 [==============================] - 38s 8ms/step - loss: 4.1907e-05 - val_loss: 3.0936e-05
# Epoch 6/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.6989e-05 - val_loss: 4.6579e-05
# Epoch 7/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.0006e-05 - val_loss: 2.6747e-05
# Epoch 8/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 3.4330e-05 - val_loss: 1.5479e-05
# Epoch 9/10
# 4638/4638 [==============================] - 40s 9ms/step - loss: 3.0001e-05 - val_loss: 2.3286e-05
# Epoch 10/10
# 4638/4638 [==============================] - 39s 8ms/step - loss: 2.6139e-05 - val_loss: 2.8974e-05
# --------------------------
#
# Starting time: 1613003767.6051598
# Completing time: 1613011729.311772
# It took -132.69511020580927 minutes to train the model for 20 iterations

# %%
model1.save("lstm_model2_3_features_all_pred.hdf5")

# %%
def plot_evaluation():
    #mean square error over iterations
    plt.figure(figsize=(15, 10))
    plt.plot(mse_for_iter1)
    plt.ylabel('mean squared error')
    plt.xlabel('iteration')
    plt.savefig('mse.png', bbox_inches='tight')
    plt.show()
        
    #plot train and validation loss over epochs for each iteration
    fig, axs = plt.subplots(10, 2)
    #axs.set_ylabel('loss')
    #axs.set_xlabel('epoch')
    fig.set_size_inches(18.5, 50)
    for row in range(10):
        for col in range(2):
            index = 2*row + col #index to get loss from training loss and validation loss list
            axs[row, col].plot(train_loss_over_epoch1[index])
            axs[row, col].plot(val_loss_over_epoch1[index])
            axs[row, col].set_title('Iteration(%d)' %(index+1))
            axs[row, col].legend(['train', 'Val'], loc='upper left')            
    plt.savefig('train_val_loss.png', bbox_inches='tight')
    
    #plot predicted value vs actual values from last iteration
    plt.figure(figsize=(15, 10))
    plt.plot(predicted_y_values1_unnor, 'bo', alpha=0.8)
    plt.plot(Y_test_actual, 'ro', alpha=0.1)
    plt.legend(['Predicted values', 'Actual values'], loc='upper right')
    plt.ylabel('Outflow')
    plt.xlabel('nth datapoint')
    plt.savefig('predicted_values_visuals.png', bbox_inches='tight')
    plt.show()
    
#call plot_evaluation function
plot_evaluation()

# %%
mse_for_iter1
# Out:
# [147.34350051005154,
#  84.79303678388982,
#  255.35629488755987,
#  81.87535371338058,
#  96.62561776637826,
#  138.60107020169946,
#  137.27330191716555,
#  171.58666668791068,
#  88.81865594813466,
#  112.51309753327308,
#  148.99752284584974,
#  112.39023600154431,
#  197.21975083968832,
#  117.61371189741647,
#  235.02669770474694,
#  66.57477879395553,
#  295.78007934297204,
#  68.21241070403855,
#  92.71813830098372,
#  164.80320925563475]

# %%
print(np.mean(mse_for_iter1))
# Out:
# 140.70615658181367

# %%
plot_model(model1, show_shapes=True)
